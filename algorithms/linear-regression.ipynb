# %% [markdown]
# # Régression Linéaire
#
# [![Index](https://img.shields.io/badge/Index-blue)](../index.ipynb)
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/digillia/Digillia-Colab/blob/main/algorithms/linear-regression.ipynb)
#
# La régression est largement utilisée en statistiques et en science des données pour la modélisation, la prédiction et la compréhension des relations entre des variables, dans des domaines tels que l'économie, la biologie, la finance et bien d'autres.
#
# La régression linéaire permet de modéliser la relation entre une variable dépendante (ou cible) et plusieurs variables indépendantes (ou caractéristiques) en supposant une relation linéaire entre elles. L'objectif est de trouver un modèle linéaire qui minimise l'écart entre les valeurs prédites et les valeurs observées de la variable dépendante.
#
# En régression linéaire multivariée, l'équation prend la forme : $Y = b_0 + b_1X_1 + b_2X_2 + ... + b_nX_n$, où $Y$ représente la variable dépendante, $X_1, X_2, ..., X_n$ sont les variables indépendantes, et $b_0, b_1, b_2, ..., b_n$ sont les coefficients à estimer. Ces coefficients déterminent la contribution de chaque variable indépendante à la prédiction de la variable dépendante.
#
# [![Wikipedia](https://img.shields.io/badge/Wikipedia-lightgrey)](https://en.wikipedia.org/wiki/Linear_regression)

# %%
# Supprimer les commentaires pour installer (requirements.txt)
# !pip3 install -q -U numpy
# !pip3 install -q -U pandas
# !pip3 install -q -U matplotlib
# !pip3 install -q -U scipy
# !pip3 install -q -U statsmodels
# !pip3 install -q -U scikit-learn
# !pip3 install -q -U jax
# !pip3 install -q -U torch
# !pip3 install -q -U tensorflow

# %% [markdown]
# ## Données
#
# Création d'un jeu de données synthétiques:

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

random_state = 42

# Create features and labels
X, y = make_regression(n_samples=100, n_features=2, n_targets=1, noise=2.0, random_state=random_state)

# Create training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# Check shapes
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (80, 2) (20, 2) (80,) (20,)

# %% [markdown]
# Visualisation:

# %%
from matplotlib import pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='train')
ax.scatter(X_test[:,0], X_test[:,1], y_test, marker='o', c='b', label='test')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
plt.show()

# %% [markdown]
# Autres données pour visualisation 3D du plan de regression linéaire:

# %%
import numpy as np

# Data for 3D visualization
x1_range = np.linspace(min(X[:, 0]), max(X[:, 0]), 40)
x2_range = np.linspace(min(X[:, 1]), max(X[:, 1]), 40)
x1_values, x2_values = np.meshgrid(x1_range, x2_range)
X_surface = np.column_stack((x1_values.ravel(), x2_values.ravel()))
X_surface
# Out:
# array([[-2.6197451 , -1.98756891],
#        [-2.50420841, -1.98756891],
#        [-2.38867172, -1.98756891],
#        ...,
#        [ 1.65511252,  2.72016917],
#        [ 1.77064921,  2.72016917],
#        [ 1.8861859 ,  2.72016917]])

# %% [markdown]
# ## Régression Linéaire Univariée avec SciPy
#
# > SciPy ne supporte pas la régression multivariée
#
# Docs: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
from scipy.stats import linregress

# linregress du package SciPy ne supporte pas la régression multivariée
# result = linregress(X_train, y_train)

# Deux regressions univariées comme ci-dessous, ne sont pas équivalentes à une regression multivariée (plan multidimensionnel).
# La suite permet seulement d'illustrer un exemple de régression univariée (droite dans un plan).

result0 = linregress(X_train[:,0], y_train)
print(result0)

result1 = linregress(X_train[:,1], y_train)
print(result1)
# Out:
# LinregressResult(slope=np.float64(92.98819197619855), intercept=np.float64(1.285422546227835), rvalue=np.float64(0.7470341322548782), pvalue=np.float64(1.7625012111659697e-15), stderr=np.float64(9.369614334260381), intercept_stderr=np.float64(8.255903002280558))
# LinregressResult(slope=np.float64(79.2081101654435), intercept=np.float64(-12.08164666005461), rvalue=np.float64(0.7129199556487509), pvalue=np.float64(1.1863604632825853e-13), stderr=np.float64(8.82168641024559), intercept_stderr=np.float64(8.60160523568881))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
ax1.scatter(X_train[:,0], y_train, c='r', alpha=0.5)
ax1.plot(X_test[:,0], result0.slope * X_test[:,0] + result0.intercept, c='b', alpha=0.5)
ax1.set(title='Feature 1', xlabel='X1', ylabel='y')
ax2.scatter(X_train[:,1], y_train, c='r', alpha=0.5)
ax2.plot(X_test[:,1], result1.slope * X_test[:,1] + result1.intercept, c='b', alpha=0.5)
ax2.set(title='Feature 2', xlabel='X2', ylabel='y')
plt.show()

# %% [markdown]
# # Régression Linéaire Multivariée avec StatsModels
#
# Docs: https://www.statsmodels.org/dev/generated/statsmodels.regression.linear_model.OLS.html

# %%
import statsmodels.api as sm

# Add constant for intercept
X_train_ = sm.add_constant(X_train)
X_test_ = sm.add_constant(X_test)

# Train and predict
model = sm.OLS(y_train, X_train_).fit()
y_pred = model.predict(X_test_) 

# Show summary
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.070e+05
# Date:                Thu, 12 Dec 2024   Prob (F-statistic):          2.49e-133
# Time:                        17:34:29   Log-Likelihood:                -171.10
# No. Observations:                  80   AIC:                             348.2
# Df Residuals:                      77   BIC:                             355.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0132      0.237      0.056      0.956      -0.459       0.485
# x1            87.4519      0.270    324.398      0.000      86.915      87.989
# x2            73.9953      0.241    307.519      0.000      73.516      74.474
# ==============================================================================
# Omnibus:                        4.408   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                3.662
# Skew:                           0.412   Prob(JB):                        0.160
# Kurtosis:                       3.649   Cond. No.                         1.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_surface_ = sm.add_constant(X_surface)
y_surface = model.predict(X_surface_)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec SciKit-Learn
#
# Docs: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
from sklearn.linear_model import LinearRegression

# Fit the regressor
model = LinearRegression().fit(X_train, y_train)
print(model.coef_, model.intercept_)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# [87.45188282 73.99534523] 0.013190960728634238
# Mean squared error: 6.19
# Coefficient of determination: 1.00

# %%
y_surface = model.predict(X_surface)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec Jax
#
# Docs: https://jax.readthedocs.io/en/latest/

# %%
from jax import grad, jit
import jax.numpy as jnp

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

# Loss function based on mean squared error (mse)
def loss(w,b,X,y):
  pred = X.dot(w) + b
  return ((pred-y)**2).mean()

# Initialize weights with zeros
Weights = jnp.zeros((X_train.shape[1],1))
bias = 0.

# Learning rate and epochs
l_rate = 0.01
n_iter = 3000

# Gradient functions wrapped with jit function for faster processing
gradW = jit(grad(loss, argnums=0))
gradb = jit(grad(loss, argnums=1))

# Training loop
for _ in range(n_iter):
  dW = gradW(Weights, bias, X_train, y_train_)
  db = gradb(Weights, bias, X_train, y_train_)
  # print(loss(Weights, bias, X_train, y_train_))
  Weights -= dW * l_rate
  bias -= db * l_rate

print(Weights, bias)

# Predictions
y_pred = X_test.dot(Weights) + bias

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# [[87.45162]
#  [73.99556]] 0.0131549835
# Mean squared error: 6.18
# Coefficient of determination: 1.00

# %%
y_surface = X_surface.dot(Weights) + bias
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec PyTorch
#
# Docs: https://pytorch.org/docs/stable/index.html

# %%
import torch
from torch.autograd import Variable

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

class TorchLR(torch.nn.Module):
    def __init__(self, inputSize, outputSize):
        super(TorchLR, self).__init__()
        self.linear = torch.nn.Linear(inputSize, outputSize, dtype=torch.float64)

    def forward(self, x):
        out = self.linear(x)
        return out
    
# Learning rate and epochs
l_rate = 0.001 
n_iter = 3000

inputDim = X.shape[1]   # takes variable 'x' 
outputDim = 1  # takes variable 'y'
model = TorchLR(inputDim, outputDim)
if torch.cuda.is_available():
    model.cuda()

criterion = torch.nn.MSELoss() 
optimizer = torch.optim.SGD(model.parameters(), lr=l_rate)

# Training loop
for epoch in range(n_iter):
    # Converting inputs and labels to Variable
    if torch.cuda.is_available():
        inputs = Variable(torch.from_numpy(X_train).cuda())
        labels = Variable(torch.from_numpy(y_train_).cuda())
    else:
        inputs = Variable(torch.from_numpy(X_train))
        labels = Variable(torch.from_numpy(y_train_))

    print(inputs.dtype, labels.dtype) 

    # Clear gradient buffers because we don't want any gradient from previous epoch to carry forward, dont want to cummulate gradients
    optimizer.zero_grad()

    # get output from the model, given the inputs
    outputs = model(inputs)

    # get loss for the predicted output
    loss = criterion(outputs, labels)
    
    # get gradients w.r.t to parameters
    loss.backward()

    # update parameters
    optimizer.step()

    print('epoch {}, loss {}'.format(epoch, loss.item()))

# Predictions
with torch.no_grad(): # we don't need gradients in the testing phase
    if torch.cuda.is_available():
        y_pred = model(Variable(torch.from_numpy(X_test).cuda())).cpu().data.numpy()
    else:
        y_pred = model(Variable(torch.from_numpy(X_test))).data.numpy()

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# torch.float64 torch.float64
# epoch 0, loss 11797.2810644507
# torch.float64 torch.float64
# epoch 1, loss 11753.684943359709
# torch.float64 torch.float64
# epoch 2, loss 11710.253228406897
# torch.float64 torch.float64
# epoch 3, loss 11666.985289306731
# torch.float64 torch.float64
# epoch 4, loss 11623.880498222574
# torch.float64 torch.float64
# epoch 5, loss 11580.938229757096
# torch.float64 torch.float64
# epoch 6, loss 11538.15786094267
# torch.float64 torch.float64
# epoch 7, loss 11495.538771231837
# torch.float64 torch.float64
# epoch 8, loss 11453.080342487807
# torch.float64 torch.float64
# epoch 9, loss 11410.78195897498
# torch.float64 torch.float64
# epoch 10, loss 11368.64300734953
# torch.float64 torch.float64
# epoch 11, loss 11326.662876650007
# torch.float64 torch.float64
# epoch 12, loss 11284.840958287976
# torch.float64 torch.float64
# epoch 13, loss 11243.17664603871
# torch.float64 torch.float64
# epoch 14, loss 11201.669336031895
# torch.float64 torch.float64
# epoch 15, loss 11160.318426742402
# torch.float64 torch.float64
# epoch 16, loss 11119.123318981072
# torch.float64 torch.float64
# epoch 17, loss 11078.083415885538
# torch.float64 torch.float64
# epoch 18, loss 11037.1981229111
# torch.float64 torch.float64
# epoch 19, loss 10996.466847821623
# torch.float64 torch.float64
# epoch 20, loss 10955.889000680474
# torch.float64 torch.float64
# epoch 21, loss 10915.463993841491
# torch.float64 torch.float64
# epoch 22, loss 10875.191241940007
# torch.float64 torch.float64
# epoch 23, loss 10835.07016188387
# torch.float64 torch.float64
# epoch 24, loss 10795.100172844552
# torch.float64 torch.float64
# epoch 25, loss 10755.280696248235
# torch.float64 torch.float64
# epoch 26, loss 10715.611155766988
# torch.float64 torch.float64
# epoch 27, loss 10676.090977309937
# torch.float64 torch.float64
# epoch 28, loss 10636.719589014485
# torch.float64 torch.float64
# epoch 29, loss 10597.49642123758
# torch.float64 torch.float64
# epoch 30, loss 10558.420906546984
# torch.float64 torch.float64
# epoch 31, loss 10519.492479712626
# torch.float64 torch.float64
# epoch 32, loss 10480.710577697933
# torch.float64 torch.float64
# epoch 33, loss 10442.074639651237
# torch.float64 torch.float64
# epoch 34, loss 10403.584106897208
# torch.float64 torch.float64
# epoch 35, loss 10365.238422928294
# torch.float64 torch.float64
# epoch 36, loss 10327.037033396238
# torch.float64 torch.float64
# epoch 37, loss 10288.97938610359
# torch.float64 torch.float64
# epoch 38, loss 10251.06493099529
# torch.float64 torch.float64
# epoch 39, loss 10213.293120150232
# torch.float64 torch.float64
# epoch 40, loss 10175.663407772925
# torch.float64 torch.float64
# epoch 41, loss 10138.175250185126
# torch.float64 torch.float64
# epoch 42, loss 10100.828105817562
# torch.float64 torch.float64
# epoch 43, loss 10063.621435201641
# torch.float64 torch.float64
# epoch 44, loss 10026.554700961215
# torch.float64 torch.float64
# epoch 45, loss 9989.627367804367
# torch.float64 torch.float64
# epoch 46, loss 9952.838902515257
# torch.float64 torch.float64
# epoch 47, loss 9916.188773945958
# torch.float64 torch.float64
# epoch 48, loss 9879.67645300836
# torch.float64 torch.float64
# epoch 49, loss 9843.301412666084
# torch.float64 torch.float64
# epoch 50, loss 9807.063127926438
# torch.float64 torch.float64
# epoch 51, loss 9770.961075832403
# torch.float64 torch.float64
# epoch 52, loss 9734.99473545466
# torch.float64 torch.float64
# epoch 53, loss 9699.16358788362
# torch.float64 torch.float64
# epoch 54, loss 9663.467116221527
# torch.float64 torch.float64
# epoch 55, loss 9627.904805574552
# torch.float64 torch.float64
# epoch 56, loss 9592.476143044942
# torch.float64 torch.float64
# epoch 57, loss 9557.180617723203
# torch.float64 torch.float64
# epoch 58, loss 9522.017720680295
# torch.float64 torch.float64
# epoch 59, loss 9486.986944959863
# torch.float64 torch.float64
# epoch 60, loss 9452.08778557053
# torch.float64 torch.float64
# epoch 61, loss 9417.319739478162
# torch.float64 torch.float64
# epoch 62, loss 9382.682305598215
# torch.float64 torch.float64
# epoch 63, loss 9348.17498478809
# torch.float64 torch.float64
# epoch 64, loss 9313.79727983952
# torch.float64 torch.float64
# epoch 65, loss 9279.548695470992
# torch.float64 torch.float64
# epoch 66, loss 9245.428738320186
# torch.float64 torch.float64
# epoch 67, loss 9211.436916936469
# torch.float64 torch.float64
# epoch 68, loss 9177.572741773389
# torch.float64 torch.float64
# epoch 69, loss 9143.83572518122
# torch.float64 torch.float64
# epoch 70, loss 9110.225381399528
# torch.float64 torch.float64
# epoch 71, loss 9076.741226549766
# torch.float64 torch.float64
# epoch 72, loss 9043.38277862791
# torch.float64 torch.float64
# epoch 73, loss 9010.149557497098
# torch.float64 torch.float64
# epoch 74, loss 8977.041084880322
# torch.float64 torch.float64
# epoch 75, loss 8944.056884353146
# torch.float64 torch.float64
# epoch 76, loss 8911.196481336443
# torch.float64 torch.float64
# epoch 77, loss 8878.459403089162
# torch.float64 torch.float64
# epoch 78, loss 8845.845178701138
# torch.float64 torch.float64
# epoch 79, loss 8813.353339085908
# torch.float64 torch.float64
# epoch 80, loss 8780.98341697358
# torch.float64 torch.float64
# epoch 81, loss 8748.7349469037
# torch.float64 torch.float64
# epoch 82, loss 8716.607465218181
# torch.float64 torch.float64
# epoch 83, loss 8684.600510054239
# torch.float64 torch.float64
# epoch 84, loss 8652.713621337352
# torch.float64 torch.float64
# epoch 85, loss 8620.94634077427
# torch.float64 torch.float64
# epoch 86, loss 8589.298211846031
# torch.float64 torch.float64
# epoch 87, loss 8557.768779801012
# torch.float64 torch.float64
# epoch 88, loss 8526.357591648015
# torch.float64 torch.float64
# epoch 89, loss 8495.064196149364
# torch.float64 torch.float64
# epoch 90, loss 8463.888143814042
# torch.float64 torch.float64
# epoch 91, loss 8432.828986890856
# torch.float64 torch.float64
# epoch 92, loss 8401.886279361623
# torch.float64 torch.float64
# epoch 93, loss 8371.059576934378
# torch.float64 torch.float64
# epoch 94, loss 8340.34843703663
# torch.float64 torch.float64
# epoch 95, loss 8309.752418808604
# torch.float64 torch.float64
# epoch 96, loss 8279.27108309657
# torch.float64 torch.float64
# epoch 97, loss 8248.903992446136
# torch.float64 torch.float64
# epoch 98, loss 8218.650711095612
# torch.float64 torch.float64
# epoch 99, loss 8188.510804969376
# torch.float64 torch.float64
# epoch 100, loss 8158.483841671279
# torch.float64 torch.float64
# epoch 101, loss 8128.569390478068
# torch.float64 torch.float64
# epoch 102, loss 8098.767022332836
# torch.float64 torch.float64
# epoch 103, loss 8069.076309838507
# torch.float64 torch.float64
# epoch 104, loss 8039.496827251334
# torch.float64 torch.float64
# epoch 105, loss 8010.028150474432
# torch.float64 torch.float64
# epoch 106, loss 7980.669857051331
# torch.float64 torch.float64
# epoch 107, loss 7951.421526159558
# torch.float64 torch.float64
# epoch 108, loss 7922.282738604239
# torch.float64 torch.float64
# epoch 109, loss 7893.2530768117385
# torch.float64 torch.float64
# epoch 110, loss 7864.332124823306
# torch.float64 torch.float64
# epoch 111, loss 7835.5194682887595
# torch.float64 torch.float64
# epoch 112, loss 7806.814694460203
# torch.float64 torch.float64
# epoch 113, loss 7778.217392185739
# torch.float64 torch.float64
# epoch 114, loss 7749.727151903246
# torch.float64 torch.float64
# epoch 115, loss 7721.343565634132
# torch.float64 torch.float64
# epoch 116, loss 7693.066226977168
# torch.float64 torch.float64
# epoch 117, loss 7664.8947311022985
# torch.float64 torch.float64
# epoch 118, loss 7636.828674744504
# torch.float64 torch.float64
# epoch 119, loss 7608.867656197675
# torch.float64 torch.float64
# epoch 120, loss 7581.0112753085195
# torch.float64 torch.float64
# epoch 121, loss 7553.259133470482
# torch.float64 torch.float64
# epoch 122, loss 7525.610833617704
# torch.float64 torch.float64
# epoch 123, loss 7498.065980218986
# torch.float64 torch.float64
# epoch 124, loss 7470.624179271797
# torch.float64 torch.float64
# epoch 125, loss 7443.285038296293
# torch.float64 torch.float64
# epoch 126, loss 7416.048166329357
# torch.float64 torch.float64
# epoch 127, loss 7388.913173918673
# torch.float64 torch.float64
# epoch 128, loss 7361.879673116823
# torch.float64 torch.float64
# epoch 129, loss 7334.947277475391
# torch.float64 torch.float64
# epoch 130, loss 7308.115602039112
# torch.float64 torch.float64
# epoch 131, loss 7281.38426334003
# torch.float64 torch.float64
# epoch 132, loss 7254.752879391681
# torch.float64 torch.float64
# epoch 133, loss 7228.221069683308
# torch.float64 torch.float64
# epoch 134, loss 7201.7884551740835
# torch.float64 torch.float64
# epoch 135, loss 7175.454658287374
# torch.float64 torch.float64
# epoch 136, loss 7149.219302904999
# torch.float64 torch.float64
# epoch 137, loss 7123.082014361551
# torch.float64 torch.float64
# epoch 138, loss 7097.0424194387015
# torch.float64 torch.float64
# epoch 139, loss 7071.100146359555
# torch.float64 torch.float64
# epoch 140, loss 7045.254824783001
# torch.float64 torch.float64
# epoch 141, loss 7019.506085798121
# torch.float64 torch.float64
# epoch 142, loss 6993.853561918586
# torch.float64 torch.float64
# epoch 143, loss 6968.296887077096
# torch.float64 torch.float64
# epoch 144, loss 6942.835696619828
# torch.float64 torch.float64
# epoch 145, loss 6917.4696273009195
# torch.float64 torch.float64
# epoch 146, loss 6892.19831727696
# torch.float64 torch.float64
# epoch 147, loss 6867.021406101519
# torch.float64 torch.float64
# epoch 148, loss 6841.9385347196785
# torch.float64 torch.float64
# epoch 149, loss 6816.949345462608
# torch.float64 torch.float64
# epoch 150, loss 6792.0534820421335
# torch.float64 torch.float64
# epoch 151, loss 6767.250589545356
# torch.float64 torch.float64
# epoch 152, loss 6742.5403144292795
# torch.float64 torch.float64
# epoch 153, loss 6717.922304515445
# torch.float64 torch.float64
# epoch 154, loss 6693.396208984617
# torch.float64 torch.float64
# epoch 155, loss 6668.961678371465
# torch.float64 torch.float64
# epoch 156, loss 6644.6183645592755
# torch.float64 torch.float64
# epoch 157, loss 6620.365920774688
# torch.float64 torch.float64
# epoch 158, loss 6596.204001582448
# torch.float64 torch.float64
# epoch 159, loss 6572.132262880172
# torch.float64 torch.float64
# epoch 160, loss 6548.150361893155
# torch.float64 torch.float64
# epoch 161, loss 6524.257957169176
# torch.float64 torch.float64
# epoch 162, loss 6500.454708573339
# torch.float64 torch.float64
# epoch 163, loss 6476.7402772829255
# torch.float64 torch.float64
# epoch 164, loss 6453.114325782272
# torch.float64 torch.float64
# epoch 165, loss 6429.5765178576685
# torch.float64 torch.float64
# epoch 166, loss 6406.1265185922675
# torch.float64 torch.float64
# epoch 167, loss 6382.763994361031
# torch.float64 torch.float64
# epoch 168, loss 6359.488612825675
# torch.float64 torch.float64
# epoch 169, loss 6336.300042929659
# torch.float64 torch.float64
# epoch 170, loss 6313.197954893172
# torch.float64 torch.float64
# epoch 171, loss 6290.182020208153
# torch.float64 torch.float64
# epoch 172, loss 6267.2519116333215
# torch.float64 torch.float64
# epoch 173, loss 6244.407303189243
# torch.float64 torch.float64
# epoch 174, loss 6221.647870153394
# torch.float64 torch.float64
# epoch 175, loss 6198.973289055257
# torch.float64 torch.float64
# epoch 176, loss 6176.38323767144
# torch.float64 torch.float64
# epoch 177, loss 6153.877395020799
# torch.float64 torch.float64
# epoch 178, loss 6131.455441359602
# torch.float64 torch.float64
# epoch 179, loss 6109.117058176693
# torch.float64 torch.float64
# epoch 180, loss 6086.861928188679
# torch.float64 torch.float64
# epoch 181, loss 6064.689735335143
# torch.float64 torch.float64
# epoch 182, loss 6042.600164773876
# torch.float64 torch.float64
# epoch 183, loss 6020.592902876113
# torch.float64 torch.float64
# epoch 184, loss 5998.667637221809
# torch.float64 torch.float64
# epoch 185, loss 5976.8240565949145
# torch.float64 torch.float64
# epoch 186, loss 5955.061850978684
# torch.float64 torch.float64
# epoch 187, loss 5933.3807115509935
# torch.float64 torch.float64
# epoch 188, loss 5911.780330679685
# torch.float64 torch.float64
# epoch 189, loss 5890.260401917914
# torch.float64 torch.float64
# epoch 190, loss 5868.820619999538
# torch.float64 torch.float64
# epoch 191, loss 5847.460680834505
# torch.float64 torch.float64
# epoch 192, loss 5826.180281504262
# torch.float64 torch.float64
# epoch 193, loss 5804.979120257196
# torch.float64 torch.float64
# epoch 194, loss 5783.856896504069
# torch.float64 torch.float64
# epoch 195, loss 5762.813310813499
# torch.float64 torch.float64
# epoch 196, loss 5741.848064907435
# torch.float64 torch.float64
# epoch 197, loss 5720.96086165666
# torch.float64 torch.float64
# epoch 198, loss 5700.151405076316
# torch.float64 torch.float64
# epoch 199, loss 5679.419400321434
# torch.float64 torch.float64
# epoch 200, loss 5658.764553682496
# torch.float64 torch.float64
# epoch 201, loss 5638.186572581004
# torch.float64 torch.float64
# epoch 202, loss 5617.685165565073
# torch.float64 torch.float64
# epoch 203, loss 5597.26004230503
# torch.float64 torch.float64
# epoch 204, loss 5576.910913589054
# torch.float64 torch.float64
# epoch 205, loss 5556.637491318802
# torch.float64 torch.float64
# epoch 206, loss 5536.43948850508
# torch.float64 torch.float64
# epoch 207, loss 5516.316619263509
# torch.float64 torch.float64
# epoch 208, loss 5496.268598810229
# torch.float64 torch.float64
# epoch 209, loss 5476.295143457603
# torch.float64 torch.float64
# epoch 210, loss 5456.395970609941
# torch.float64 torch.float64
# epoch 211, loss 5436.570798759253
# torch.float64 torch.float64
# epoch 212, loss 5416.819347481001
# torch.float64 torch.float64
# epoch 213, loss 5397.1413374298845
# torch.float64 torch.float64
# epoch 214, loss 5377.536490335622
# torch.float64 torch.float64
# epoch 215, loss 5358.00452899878
# torch.float64 torch.float64
# epoch 216, loss 5338.54517728658
# torch.float64 torch.float64
# epoch 217, loss 5319.158160128758
# torch.float64 torch.float64
# epoch 218, loss 5299.843203513416
# torch.float64 torch.float64
# epoch 219, loss 5280.600034482899
# torch.float64 torch.float64
# epoch 220, loss 5261.42838112969
# torch.float64 torch.float64
# epoch 221, loss 5242.327972592316
# torch.float64 torch.float64
# epoch 222, loss 5223.298539051276
# torch.float64 torch.float64
# epoch 223, loss 5204.339811724976
# torch.float64 torch.float64
# epoch 224, loss 5185.451522865691
# torch.float64 torch.float64
# epoch 225, loss 5166.633405755536
# torch.float64 torch.float64
# epoch 226, loss 5147.885194702454
# torch.float64 torch.float64
# epoch 227, loss 5129.206625036219
# torch.float64 torch.float64
# epoch 228, loss 5110.597433104456
# torch.float64 torch.float64
# epoch 229, loss 5092.057356268682
# torch.float64 torch.float64
# epoch 230, loss 5073.586132900353
# torch.float64 torch.float64
# epoch 231, loss 5055.183502376926
# torch.float64 torch.float64
# epoch 232, loss 5036.84920507795
# torch.float64 torch.float64
# epoch 233, loss 5018.582982381158
# torch.float64 torch.float64
# epoch 234, loss 5000.384576658582
# torch.float64 torch.float64
# epoch 235, loss 4982.253731272679
# torch.float64 torch.float64
# epoch 236, loss 4964.190190572483
# torch.float64 torch.float64
# epoch 237, loss 4946.193699889749
# torch.float64 torch.float64
# epoch 238, loss 4928.264005535141
# torch.float64 torch.float64
# epoch 239, loss 4910.400854794412
# torch.float64 torch.float64
# epoch 240, loss 4892.603995924609
# torch.float64 torch.float64
# epoch 241, loss 4874.873178150299
# torch.float64 torch.float64
# epoch 242, loss 4857.20815165979
# torch.float64 torch.float64
# epoch 243, loss 4839.608667601394
# torch.float64 torch.float64
# epoch 244, loss 4822.074478079676
# torch.float64 torch.float64
# epoch 245, loss 4804.605336151742
# torch.float64 torch.float64
# epoch 246, loss 4787.2009958235285
# torch.float64 torch.float64
# epoch 247, loss 4769.861212046109
# torch.float64 torch.float64
# epoch 248, loss 4752.585740712015
# torch.float64 torch.float64
# epoch 249, loss 4735.374338651573
# torch.float64 torch.float64
# epoch 250, loss 4718.226763629258
# torch.float64 torch.float64
# epoch 251, loss 4701.142774340052
# torch.float64 torch.float64
# epoch 252, loss 4684.12213040583
# torch.float64 torch.float64
# epoch 253, loss 4667.164592371749
# torch.float64 torch.float64
# epoch 254, loss 4650.269921702653
# torch.float64 torch.float64
# epoch 255, loss 4633.437880779505
# torch.float64 torch.float64
# epoch 256, loss 4616.668232895812
# torch.float64 torch.float64
# epoch 257, loss 4599.960742254081
# torch.float64 torch.float64
# epoch 258, loss 4583.315173962279
# torch.float64 torch.float64
# epoch 259, loss 4566.731294030314
# torch.float64 torch.float64
# epoch 260, loss 4550.208869366525
# torch.float64 torch.float64
# epoch 261, loss 4533.747667774185
# torch.float64 torch.float64
# epoch 262, loss 4517.347457948027
# torch.float64 torch.float64
# epoch 263, loss 4501.008009470768
# torch.float64 torch.float64
# epoch 264, loss 4484.729092809661
# torch.float64 torch.float64
# epoch 265, loss 4468.510479313052
# torch.float64 torch.float64
# epoch 266, loss 4452.351941206956
# torch.float64 torch.float64
# epoch 267, loss 4436.253251591645
# torch.float64 torch.float64
# epoch 268, loss 4420.21418443824
# torch.float64 torch.float64
# epoch 269, loss 4404.234514585338
# torch.float64 torch.float64
# epoch 270, loss 4388.3140177356245
# torch.float64 torch.float64
# epoch 271, loss 4372.452470452526
# torch.float64 torch.float64
# epoch 272, loss 4356.649650156856
# torch.float64 torch.float64
# epoch 273, loss 4340.905335123486
# torch.float64 torch.float64
# epoch 274, loss 4325.219304478021
# torch.float64 torch.float64
# epoch 275, loss 4309.591338193494
# torch.float64 torch.float64
# epoch 276, loss 4294.021217087077
# torch.float64 torch.float64
# epoch 277, loss 4278.508722816788
# torch.float64 torch.float64
# epoch 278, loss 4263.053637878235
# torch.float64 torch.float64
# epoch 279, loss 4247.655745601351
# torch.float64 torch.float64
# epoch 280, loss 4232.314830147157
# torch.float64 torch.float64
# epoch 281, loss 4217.03067650453
# torch.float64 torch.float64
# epoch 282, loss 4201.803070486984
# torch.float64 torch.float64
# epoch 283, loss 4186.631798729471
# torch.float64 torch.float64
# epoch 284, loss 4171.5166486851795
# torch.float64 torch.float64
# epoch 285, loss 4156.45740862236
# torch.float64 torch.float64
# epoch 286, loss 4141.453867621165
# torch.float64 torch.float64
# epoch 287, loss 4126.505815570478
# torch.float64 torch.float64
# epoch 288, loss 4111.61304316479
# torch.float64 torch.float64
# epoch 289, loss 4096.7753419010505
# torch.float64 torch.float64
# epoch 290, loss 4081.992504075566
# torch.float64 torch.float64
# epoch 291, loss 4067.2643227808853
# torch.float64 torch.float64
# epoch 292, loss 4052.590591902711
# torch.float64 torch.float64
# epoch 293, loss 4037.9711061168127
# torch.float64 torch.float64
# epoch 294, loss 4023.405660885967
# torch.float64 torch.float64
# epoch 295, loss 4008.894052456889
# torch.float64 torch.float64
# epoch 296, loss 3994.436077857198
# torch.float64 torch.float64
# epoch 297, loss 3980.0315348923805
# torch.float64 torch.float64
# epoch 298, loss 3965.6802221427656
# torch.float64 torch.float64
# epoch 299, loss 3951.3819389605205
# torch.float64 torch.float64
# epoch 300, loss 3937.1364854666535
# torch.float64 torch.float64
# epoch 301, loss 3922.9436625480243
# torch.float64 torch.float64
# epoch 302, loss 3908.8032718543727
# torch.float64 torch.float64
# epoch 303, loss 3894.715115795356
# torch.float64 torch.float64
# epoch 304, loss 3880.678997537597
# torch.float64 torch.float64
# epoch 305, loss 3866.6947210017506
# torch.float64 torch.float64
# epoch 306, loss 3852.7620908595663
# torch.float64 torch.float64
# epoch 307, loss 3838.880912530983
# torch.float64 torch.float64
# epoch 308, loss 3825.0509921812163
# torch.float64 torch.float64
# epoch 309, loss 3811.2721367178688
# torch.float64 torch.float64
# epoch 310, loss 3797.5441537880497
# torch.float64 torch.float64
# epoch 311, loss 3783.866851775501
# torch.float64 torch.float64
# epoch 312, loss 3770.24003979774
# torch.float64 torch.float64
# epoch 313, loss 3756.663527703211
# torch.float64 torch.float64
# epoch 314, loss 3743.137126068449
# torch.float64 torch.float64
# epoch 315, loss 3729.6606461952533
# torch.float64 torch.float64
# epoch 316, loss 3716.2339001078735
# torch.float64 torch.float64
# epoch 317, loss 3702.856700550206
# torch.float64 torch.float64
# epoch 318, loss 3689.528860983
# torch.float64 torch.float64
# epoch 319, loss 3676.250195581078
# torch.float64 torch.float64
# epoch 320, loss 3663.020519230563
# torch.float64 torch.float64
# epoch 321, loss 3649.839647526118
# torch.float64 torch.float64
# epoch 322, loss 3636.7073967682036
# torch.float64 torch.float64
# epoch 323, loss 3623.623583960331
# torch.float64 torch.float64
# epoch 324, loss 3610.588026806339
# torch.float64 torch.float64
# epoch 325, loss 3597.6005437076774
# torch.float64 torch.float64
# epoch 326, loss 3584.660953760698
# torch.float64 torch.float64
# epoch 327, loss 3571.7690767539657
# torch.float64 torch.float64
# epoch 328, loss 3558.924733165563
# torch.float64 torch.float64
# epoch 329, loss 3546.127744160426
# torch.float64 torch.float64
# epoch 330, loss 3533.377931587673
# torch.float64 torch.float64
# epoch 331, loss 3520.6751179779576
# torch.float64 torch.float64
# epoch 332, loss 3508.019126540819
# torch.float64 torch.float64
# epoch 333, loss 3495.4097811620522
# torch.float64 torch.float64
# epoch 334, loss 3482.8469064010887
# torch.float64 torch.float64
# epoch 335, loss 3470.330327488379
# torch.float64 torch.float64
# epoch 336, loss 3457.8598703227944
# torch.float64 torch.float64
# epoch 337, loss 3445.435361469032
# torch.float64 torch.float64
# epoch 338, loss 3433.0566281550373
# torch.float64 torch.float64
# epoch 339, loss 3420.723498269433
# torch.float64 torch.float64
# epoch 340, loss 3408.43580035895
# torch.float64 torch.float64
# epoch 341, loss 3396.193363625885
# torch.float64 torch.float64
# epoch 342, loss 3383.9960179255568
# torch.float64 torch.float64
# epoch 343, loss 3371.8435937637732
# torch.float64 torch.float64
# epoch 344, loss 3359.7359222943087
# torch.float64 torch.float64
# epoch 345, loss 3347.672835316397
# torch.float64 torch.float64
# epoch 346, loss 3335.6541652722262
# torch.float64 torch.float64
# epoch 347, loss 3323.679745244449
# torch.float64 torch.float64
# epoch 348, loss 3311.749408953698
# torch.float64 torch.float64
# epoch 349, loss 3299.8629907561162
# torch.float64 torch.float64
# epoch 350, loss 3288.0203256408918
# torch.float64 torch.float64
# epoch 351, loss 3276.2212492278077
# torch.float64 torch.float64
# epoch 352, loss 3264.465597764797
# torch.float64 torch.float64
# epoch 353, loss 3252.7532081255067
# torch.float64 torch.float64
# epoch 354, loss 3241.083917806879
# torch.float64 torch.float64
# epoch 355, loss 3229.457564926729
# torch.float64 torch.float64
# epoch 356, loss 3217.8739882213476
# torch.float64 torch.float64
# epoch 357, loss 3206.3330270431006
# torch.float64 torch.float64
# epoch 358, loss 3194.8345213580415
# torch.float64 torch.float64
# epoch 359, loss 3183.3783117435364
# torch.float64 torch.float64
# epoch 360, loss 3171.9642393858967
# torch.float64 torch.float64
# epoch 361, loss 3160.5921460780187
# torch.float64 torch.float64
# epoch 362, loss 3149.2618742170357
# torch.float64 torch.float64
# epoch 363, loss 3137.973266801978
# torch.float64 torch.float64
# epoch 364, loss 3126.7261674314373
# torch.float64 torch.float64
# epoch 365, loss 3115.520420301253
# torch.float64 torch.float64
# epoch 366, loss 3104.3558702021937
# torch.float64 torch.float64
# epoch 367, loss 3093.2323625176546
# torch.float64 torch.float64
# epoch 368, loss 3082.1497432213628
# torch.float64 torch.float64
# epoch 369, loss 3071.1078588750925
# torch.float64 torch.float64
# epoch 370, loss 3060.1065566263883
# torch.float64 torch.float64
# epoch 371, loss 3049.1456842062967
# torch.float64 torch.float64
# epoch 372, loss 3038.2250899271053
# torch.float64 torch.float64
# epoch 373, loss 3027.3446226800975
# torch.float64 torch.float64
# epoch 374, loss 3016.5041319333063
# torch.float64 torch.float64
# epoch 375, loss 3005.7034677292845
# torch.float64 torch.float64
# epoch 376, loss 2994.9424806828815
# torch.float64 torch.float64
# epoch 377, loss 2984.221021979024
# torch.float64 torch.float64
# epoch 378, loss 2973.538943370516
# torch.float64 torch.float64
# epoch 379, loss 2962.896097175836
# torch.float64 torch.float64
# epoch 380, loss 2952.2923362769493
# torch.float64 torch.float64
# epoch 381, loss 2941.727514117129
# torch.float64 torch.float64
# epoch 382, loss 2931.2014846987813
# torch.float64 torch.float64
# epoch 383, loss 2920.7141025812844
# torch.float64 torch.float64
# epoch 384, loss 2910.2652228788297
# torch.float64 torch.float64
# epoch 385, loss 2899.8547012582812
# torch.float64 torch.float64
# epoch 386, loss 2889.4823939370317
# torch.float64 torch.float64
# epoch 387, loss 2879.1481576808756
# torch.float64 torch.float64
# epoch 388, loss 2868.8518498018866
# torch.float64 torch.float64
# epoch 389, loss 2858.5933281563052
# torch.float64 torch.float64
# epoch 390, loss 2848.372451142431
# torch.float64 torch.float64
# epoch 391, loss 2838.1890776985315
# torch.float64 torch.float64
# epoch 392, loss 2828.0430673007477
# torch.float64 torch.float64
# epoch 393, loss 2817.9342799610176
# torch.float64 torch.float64
# epoch 394, loss 2807.8625762250017
# torch.float64 torch.float64
# epoch 395, loss 2797.8278171700204
# torch.float64 torch.float64
# epoch 396, loss 2787.8298644029974
# torch.float64 torch.float64
# epoch 397, loss 2777.868580058411
# torch.float64 torch.float64
# epoch 398, loss 2767.9438267962564
# torch.float64 torch.float64
# epoch 399, loss 2758.0554678000103
# torch.float64 torch.float64
# epoch 400, loss 2748.2033667746095
# torch.float64 torch.float64
# epoch 401, loss 2738.3873879444336
# torch.float64 torch.float64
# epoch 402, loss 2728.6073960512986
# torch.float64 torch.float64
# epoch 403, loss 2718.8632563524534
# torch.float64 torch.float64
# epoch 404, loss 2709.154834618589
# torch.float64 torch.float64
# epoch 405, loss 2699.4819971318548
# torch.float64 torch.float64
# epoch 406, loss 2689.8446106838783
# torch.float64 torch.float64
# epoch 407, loss 2680.2425425738
# torch.float64 torch.float64
# epoch 408, loss 2670.675660606308
# torch.float64 torch.float64
# epoch 409, loss 2661.143833089688
# torch.float64 torch.float64
# epoch 410, loss 2651.646928833872
# torch.float64 torch.float64
# epoch 411, loss 2642.1848171485044
# torch.float64 torch.float64
# epoch 412, loss 2632.757367841009
# torch.float64 torch.float64
# epoch 413, loss 2623.364451214664
# torch.float64 torch.float64
# epoch 414, loss 2614.005938066689
# torch.float64 torch.float64
# epoch 415, loss 2604.681699686335
# torch.float64 torch.float64
# epoch 416, loss 2595.391607852981
# torch.float64 torch.float64
# epoch 417, loss 2586.1355348342454
# torch.float64 torch.float64
# epoch 418, loss 2576.913353384097
# torch.float64 torch.float64
# epoch 419, loss 2567.724936740972
# torch.float64 torch.float64
# epoch 420, loss 2558.570158625913
# torch.float64 torch.float64
# epoch 421, loss 2549.4488932406935
# torch.float64 torch.float64
# epoch 422, loss 2540.361015265969
# torch.float64 torch.float64
# epoch 423, loss 2531.3063998594216
# torch.float64 torch.float64
# epoch 424, loss 2522.284922653923
# torch.float64 torch.float64
# epoch 425, loss 2513.296459755695
# torch.float64 torch.float64
# epoch 426, loss 2504.3408877424836
# torch.float64 torch.float64
# epoch 427, loss 2495.4180836617375
# torch.float64 torch.float64
# epoch 428, loss 2486.5279250287945
# torch.float64 torch.float64
# epoch 429, loss 2477.670289825074
# torch.float64 torch.float64
# epoch 430, loss 2468.8450564962795
# torch.float64 torch.float64
# epoch 431, loss 2460.052103950603
# torch.float64 torch.float64
# epoch 432, loss 2451.2913115569418
# torch.float64 torch.float64
# epoch 433, loss 2442.5625591431185
# torch.float64 torch.float64
# epoch 434, loss 2433.8657269941095
# torch.float64 torch.float64
# epoch 435, loss 2425.2006958502816
# torch.float64 torch.float64
# epoch 436, loss 2416.5673469056333
# torch.float64 torch.float64
# epoch 437, loss 2407.9655618060415
# torch.float64 torch.float64
# epoch 438, loss 2399.395222647522
# torch.float64 torch.float64
# epoch 439, loss 2390.8562119744875
# torch.float64 torch.float64
# epoch 440, loss 2382.3484127780202
# torch.float64 torch.float64
# epoch 441, loss 2373.871708494147
# torch.float64 torch.float64
# epoch 442, loss 2365.4259830021215
# torch.float64 torch.float64
# epoch 443, loss 2357.0111206227166
# torch.float64 torch.float64
# epoch 444, loss 2348.627006116515
# torch.float64 torch.float64
# epoch 445, loss 2340.2735246822185
# torch.float64 torch.float64
# epoch 446, loss 2331.950561954957
# torch.float64 torch.float64
# epoch 447, loss 2323.658004004598
# torch.float64 torch.float64
# epoch 448, loss 2315.395737334077
# torch.float64 torch.float64
# epoch 449, loss 2307.163648877722
# torch.float64 torch.float64
# epoch 450, loss 2298.9616259995937
# torch.float64 torch.float64
# epoch 451, loss 2290.789556491823
# torch.float64 torch.float64
# epoch 452, loss 2282.647328572965
# torch.float64 torch.float64
# epoch 453, loss 2274.5348308863477
# torch.float64 torch.float64
# epoch 454, loss 2266.45195249844
# torch.float64 torch.float64
# epoch 455, loss 2258.3985828972154
# torch.float64 torch.float64
# epoch 456, loss 2250.374611990532
# torch.float64 torch.float64
# epoch 457, loss 2242.3799301045046
# torch.float64 torch.float64
# epoch 458, loss 2234.4144279818997
# torch.float64 torch.float64
# epoch 459, loss 2226.4779967805252
# torch.float64 torch.float64
# epoch 460, loss 2218.57052807163
# torch.float64 torch.float64
# epoch 461, loss 2210.6919138383128
# torch.float64 torch.float64
# epoch 462, loss 2202.8420464739293
# torch.float64 torch.float64
# epoch 463, loss 2195.0208187805165
# torch.float64 torch.float64
# epoch 464, loss 2187.2281239672116
# torch.float64 torch.float64
# epoch 465, loss 2179.463855648687
# torch.float64 torch.float64
# epoch 466, loss 2171.727907843583
# torch.float64 torch.float64
# epoch 467, loss 2164.0201749729554
# torch.float64 torch.float64
# epoch 468, loss 2156.340551858721
# torch.float64 torch.float64
# epoch 469, loss 2148.6889337221123
# torch.float64 torch.float64
# epoch 470, loss 2141.0652161821426
# torch.float64 torch.float64
# epoch 471, loss 2133.469295254067
# torch.float64 torch.float64
# epoch 472, loss 2125.9010673478624
# torch.float64 torch.float64
# epoch 473, loss 2118.360429266699
# torch.float64 torch.float64
# epoch 474, loss 2110.8472782054314
# torch.float64 torch.float64
# epoch 475, loss 2103.3615117490867
# torch.float64 torch.float64
# epoch 476, loss 2095.903027871361
# torch.float64 torch.float64
# epoch 477, loss 2088.4717249331225
# torch.float64 torch.float64
# epoch 478, loss 2081.067501680919
# torch.float64 torch.float64
# epoch 479, loss 2073.6902572454956
# torch.float64 torch.float64
# epoch 480, loss 2066.33989114031
# torch.float64 torch.float64
# epoch 481, loss 2059.0163032600603
# torch.float64 torch.float64
# epoch 482, loss 2051.7193938792166
# torch.float64 torch.float64
# epoch 483, loss 2044.449063650561
# torch.float64 torch.float64
# epoch 484, loss 2037.2052136037237
# torch.float64 torch.float64
# epoch 485, loss 2029.9877451437394
# torch.float64 torch.float64
# epoch 486, loss 2022.796560049596
# torch.float64 torch.float64
# epoch 487, loss 2015.6315604727977
# torch.float64 torch.float64
# epoch 488, loss 2008.4926489359284
# torch.float64 torch.float64
# epoch 489, loss 2001.379728331224
# torch.float64 torch.float64
# epoch 490, loss 1994.2927019191507
# torch.float64 torch.float64
# epoch 491, loss 1987.2314733269832
# torch.float64 torch.float64
# epoch 492, loss 1980.195946547397
# torch.float64 torch.float64
# epoch 493, loss 1973.1860259370583
# torch.float64 torch.float64
# epoch 494, loss 1966.2016162152242
# torch.float64 torch.float64
# epoch 495, loss 1959.2426224623475
# torch.float64 torch.float64
# epoch 496, loss 1952.3089501186848
# torch.float64 torch.float64
# epoch 497, loss 1945.4005049829132
# torch.float64 torch.float64
# epoch 498, loss 1938.5171932107496
# torch.float64 torch.float64
# epoch 499, loss 1931.6589213135776
# torch.float64 torch.float64
# epoch 500, loss 1924.8255961570787
# torch.float64 torch.float64
# epoch 501, loss 1918.0171249598661
# torch.float64 torch.float64
# epoch 502, loss 1911.2334152921321
# torch.float64 torch.float64
# epoch 503, loss 1904.4743750742887
# torch.float64 torch.float64
# epoch 504, loss 1897.739912575627
# torch.float64 torch.float64
# epoch 505, loss 1891.0299364129671
# torch.float64 torch.float64
# epoch 506, loss 1884.3443555493286
# torch.float64 torch.float64
# epoch 507, loss 1877.6830792925944
# torch.float64 torch.float64
# epoch 508, loss 1871.0460172941832
# torch.float64 torch.float64
# epoch 509, loss 1864.4330795477326
# torch.float64 torch.float64
# epoch 510, loss 1857.8441763877775
# torch.float64 torch.float64
# epoch 511, loss 1851.279218488442
# torch.float64 torch.float64
# epoch 512, loss 1844.7381168621323
# torch.float64 torch.float64
# epoch 513, loss 1838.2207828582366
# torch.float64 torch.float64
# epoch 514, loss 1831.7271281618275
# torch.float64 torch.float64
# epoch 515, loss 1825.2570647923724
# torch.float64 torch.float64
# epoch 516, loss 1818.8105051024463
# torch.float64 torch.float64
# epoch 517, loss 1812.3873617764525
# torch.float64 torch.float64
# epoch 518, loss 1805.9875478293459
# torch.float64 torch.float64
# epoch 519, loss 1799.6109766053619
# torch.float64 torch.float64
# epoch 520, loss 1793.2575617767488
# torch.float64 torch.float64
# epoch 521, loss 1786.9272173425118
# torch.float64 torch.float64
# epoch 522, loss 1780.6198576271515
# torch.float64 torch.float64
# epoch 523, loss 1774.3353972794146
# torch.float64 torch.float64
# epoch 524, loss 1768.0737512710486
# torch.float64 torch.float64
# epoch 525, loss 1761.834834895558
# torch.float64 torch.float64
# epoch 526, loss 1755.61856376697
# torch.float64 torch.float64
# epoch 527, loss 1749.424853818601
# torch.float64 torch.float64
# epoch 528, loss 1743.253621301829
# torch.float64 torch.float64
# epoch 529, loss 1737.1047827848743
# torch.float64 torch.float64
# epoch 530, loss 1730.9782551515775
# torch.float64 torch.float64
# epoch 531, loss 1724.8739556001915
# torch.float64 torch.float64
# epoch 532, loss 1718.7918016421686
# torch.float64 torch.float64
# epoch 533, loss 1712.7317111009602
# torch.float64 torch.float64
# epoch 534, loss 1706.6936021108183
# torch.float64 torch.float64
# epoch 535, loss 1700.677393115599
# torch.float64 torch.float64
# epoch 536, loss 1694.6830028675759
# torch.float64 torch.float64
# epoch 537, loss 1688.7103504262523
# torch.float64 torch.float64
# epoch 538, loss 1682.7593551571845
# torch.float64 torch.float64
# epoch 539, loss 1676.8299367308027
# torch.float64 torch.float64
# epoch 540, loss 1670.922015121243
# torch.float64 torch.float64
# epoch 541, loss 1665.0355106051793
# torch.float64 torch.float64
# epoch 542, loss 1659.1703437606607
# torch.float64 torch.float64
# epoch 543, loss 1653.3264354659564
# torch.float64 torch.float64
# epoch 544, loss 1647.5037068984013
# torch.float64 torch.float64
# epoch 545, loss 1641.7020795332471
# torch.float64 torch.float64
# epoch 546, loss 1635.9214751425202
# torch.float64 torch.float64
# epoch 547, loss 1630.1618157938804
# torch.float64 torch.float64
# epoch 548, loss 1624.4230238494852
# torch.float64 torch.float64
# epoch 549, loss 1618.705021964864
# torch.float64 torch.float64
# epoch 550, loss 1613.0077330877848
# torch.float64 torch.float64
# epoch 551, loss 1607.3310804571381
# torch.float64 torch.float64
# epoch 552, loss 1601.6749876018155
# torch.float64 torch.float64
# epoch 553, loss 1596.0393783395998
# torch.float64 torch.float64
# epoch 554, loss 1590.4241767760534
# torch.float64 torch.float64
# epoch 555, loss 1584.8293073034158
# torch.float64 torch.float64
# epoch 556, loss 1579.2546945995014
# torch.float64 torch.float64
# epoch 557, loss 1573.700263626606
# torch.float64 torch.float64
# epoch 558, loss 1568.165939630413
# torch.float64 torch.float64
# epoch 559, loss 1562.6516481389065
# torch.float64 torch.float64
# epoch 560, loss 1557.1573149612896
# torch.float64 torch.float64
# epoch 561, loss 1551.6828661869024
# torch.float64 torch.float64
# epoch 562, loss 1546.22822818415
# torch.float64 torch.float64
# epoch 563, loss 1540.7933275994305
# torch.float64 torch.float64
# epoch 564, loss 1535.378091356069
# torch.float64 torch.float64
# epoch 565, loss 1529.9824466532543
# torch.float64 torch.float64
# epoch 566, loss 1524.6063209649826
# torch.float64 torch.float64
# epoch 567, loss 1519.2496420390016
# torch.float64 torch.float64
# epoch 568, loss 1513.912337895761
# torch.float64 torch.float64
# epoch 569, loss 1508.5943368273674
# torch.float64 torch.float64
# epoch 570, loss 1503.2955673965414
# torch.float64 torch.float64
# epoch 571, loss 1498.01595843558
# torch.float64 torch.float64
# epoch 572, loss 1492.7554390453238
# torch.float64 torch.float64
# epoch 573, loss 1487.5139385941256
# torch.float64 torch.float64
# epoch 574, loss 1482.291386716826
# torch.float64 torch.float64
# epoch 575, loss 1477.0877133137317
# torch.float64 torch.float64
# epoch 576, loss 1471.9028485495967
# torch.float64 torch.float64
# epoch 577, loss 1466.7367228526089
# torch.float64 torch.float64
# epoch 578, loss 1461.5892669133802
# torch.float64 torch.float64
# epoch 579, loss 1456.4604116839407
# torch.float64 torch.float64
# epoch 580, loss 1451.3500883767367
# torch.float64 torch.float64
# epoch 581, loss 1446.2582284636323
# torch.float64 torch.float64
# epoch 582, loss 1441.1847636749144
# torch.float64 torch.float64
# epoch 583, loss 1436.1296259983042
# torch.float64 torch.float64
# epoch 584, loss 1431.0927476779677
# torch.float64 torch.float64
# epoch 585, loss 1426.0740612135373
# torch.float64 torch.float64
# epoch 586, loss 1421.073499359127
# torch.float64 torch.float64
# epoch 587, loss 1416.0909951223625
# torch.float64 torch.float64
# epoch 588, loss 1411.1264817634067
# torch.float64 torch.float64
# epoch 589, loss 1406.1798927939944
# torch.float64 torch.float64
# epoch 590, loss 1401.251161976466
# torch.float64 torch.float64
# epoch 591, loss 1396.3402233228085
# torch.float64 torch.float64
# epoch 592, loss 1391.4470110937013
# torch.float64 torch.float64
# epoch 593, loss 1386.571459797559
# torch.float64 torch.float64
# epoch 594, loss 1381.7135041895863
# torch.float64 torch.float64
# epoch 595, loss 1376.8730792708307
# torch.float64 torch.float64
# epoch 596, loss 1372.0501202872429
# torch.float64 torch.float64
# epoch 597, loss 1367.2445627287361
# torch.float64 torch.float64
# epoch 598, loss 1362.4563423282543
# torch.float64 torch.float64
# epoch 599, loss 1357.6853950608395
# torch.float64 torch.float64
# epoch 600, loss 1352.9316571427055
# torch.float64 torch.float64
# epoch 601, loss 1348.1950650303156
# torch.float64 torch.float64
# epoch 602, loss 1343.4755554194612
# torch.float64 torch.float64
# epoch 603, loss 1338.7730652443463
# torch.float64 torch.float64
# epoch 604, loss 1334.0875316766728
# torch.float64 torch.float64
# epoch 605, loss 1329.4188921247344
# torch.float64 torch.float64
# epoch 606, loss 1324.7670842325092
# torch.float64 torch.float64
# epoch 607, loss 1320.1320458787563
# torch.float64 torch.float64
# epoch 608, loss 1315.5137151761205
# torch.float64 torch.float64
# epoch 609, loss 1310.9120304702342
# torch.float64 torch.float64
# epoch 610, loss 1306.3269303388256
# torch.float64 torch.float64
# epoch 611, loss 1301.758353590833
# torch.float64 torch.float64
# epoch 612, loss 1297.2062392655178
# torch.float64 torch.float64
# epoch 613, loss 1292.6705266315835
# torch.float64 torch.float64
# epoch 614, loss 1288.1511551862977
# torch.float64 torch.float64
# epoch 615, loss 1283.6480646546192
# torch.float64 torch.float64
# epoch 616, loss 1279.1611949883236
# torch.float64 torch.float64
# epoch 617, loss 1274.690486365138
# torch.float64 torch.float64
# epoch 618, loss 1270.2358791878773
# torch.float64 torch.float64
# epoch 619, loss 1265.7973140835802
# torch.float64 torch.float64
# epoch 620, loss 1261.3747319026527
# torch.float64 torch.float64
# epoch 621, loss 1256.9680737180151
# torch.float64 torch.float64
# epoch 622, loss 1252.5772808242493
# torch.float64 torch.float64
# epoch 623, loss 1248.2022947367516
# torch.float64 torch.float64
# epoch 624, loss 1243.843057190888
# torch.float64 torch.float64
# epoch 625, loss 1239.4995101411532
# torch.float64 torch.float64
# epoch 626, loss 1235.171595760333
# torch.float64 torch.float64
# epoch 627, loss 1230.859256438668
# torch.float64 torch.float64
# epoch 628, loss 1226.562434783024
# torch.float64 torch.float64
# epoch 629, loss 1222.2810736160623
# torch.float64 torch.float64
# epoch 630, loss 1218.0151159754164
# torch.float64 torch.float64
# epoch 631, loss 1213.764505112868
# torch.float64 torch.float64
# epoch 632, loss 1209.5291844935284
# torch.float64 torch.float64
# epoch 633, loss 1205.3090977950274
# torch.float64 torch.float64
# epoch 634, loss 1201.1041889066935
# torch.float64 torch.float64
# epoch 635, loss 1196.9144019287507
# torch.float64 torch.float64
# epoch 636, loss 1192.7396811715103
# torch.float64 torch.float64
# epoch 637, loss 1188.5799711545683
# torch.float64 torch.float64
# epoch 638, loss 1184.4352166060048
# torch.float64 torch.float64
# epoch 639, loss 1180.3053624615875
# torch.float64 torch.float64
# epoch 640, loss 1176.1903538639801
# torch.float64 torch.float64
# epoch 641, loss 1172.0901361619485
# torch.float64 torch.float64
# epoch 642, loss 1168.004654909575
# torch.float64 torch.float64
# epoch 643, loss 1163.9338558654745
# torch.float64 torch.float64
# epoch 644, loss 1159.877684992012
# torch.float64 torch.float64
# epoch 645, loss 1155.8360884545245
# torch.float64 torch.float64
# epoch 646, loss 1151.8090126205452
# torch.float64 torch.float64
# epoch 647, loss 1147.7964040590323
# torch.float64 torch.float64
# epoch 648, loss 1143.7982095395985
# torch.float64 torch.float64
# epoch 649, loss 1139.8143760317448
# torch.float64 torch.float64
# epoch 650, loss 1135.8448507040978
# torch.float64 torch.float64
# epoch 651, loss 1131.8895809236485
# torch.float64 torch.float64
# epoch 652, loss 1127.9485142549954
# torch.float64 torch.float64
# epoch 653, loss 1124.0215984595884
# torch.float64 torch.float64
# epoch 654, loss 1120.1087814949792
# torch.float64 torch.float64
# epoch 655, loss 1116.2100115140718
# torch.float64 torch.float64
# epoch 656, loss 1112.3252368643753
# torch.float64 torch.float64
# epoch 657, loss 1108.4544060872624
# torch.float64 torch.float64
# epoch 658, loss 1104.59746791723
# torch.float64 torch.float64
# epoch 659, loss 1100.7543712811594
# torch.float64 torch.float64
# epoch 660, loss 1096.925065297584
# torch.float64 torch.float64
# epoch 661, loss 1093.1094992759583
# torch.float64 torch.float64
# epoch 662, loss 1089.3076227159258
# torch.float64 torch.float64
# epoch 663, loss 1085.5193853065978
# torch.float64 torch.float64
# epoch 664, loss 1081.7447369258257
# torch.float64 torch.float64
# epoch 665, loss 1077.983627639484
# torch.float64 torch.float64
# epoch 666, loss 1074.236007700752
# torch.float64 torch.float64
# epoch 667, loss 1070.501827549399
# torch.float64 torch.float64
# epoch 668, loss 1066.7810378110714
# torch.float64 torch.float64
# epoch 669, loss 1063.0735892965845
# torch.float64 torch.float64
# epoch 670, loss 1059.3794330012158
# torch.float64 torch.float64
# epoch 671, loss 1055.6985201040018
# torch.float64 torch.float64
# epoch 672, loss 1052.0308019670363
# torch.float64 torch.float64
# epoch 673, loss 1048.3762301347717
# torch.float64 torch.float64
# epoch 674, loss 1044.734756333325
# torch.float64 torch.float64
# epoch 675, loss 1041.1063324697839
# torch.float64 torch.float64
# epoch 676, loss 1037.4909106315158
# torch.float64 torch.float64
# epoch 677, loss 1033.8884430854819
# torch.float64 torch.float64
# epoch 678, loss 1030.298882277551
# torch.float64 torch.float64
# epoch 679, loss 1026.7221808318186
# torch.float64 torch.float64
# epoch 680, loss 1023.1582915499259
# torch.float64 torch.float64
# epoch 681, loss 1019.6071674103835
# torch.float64 torch.float64
# epoch 682, loss 1016.0687615678966
# torch.float64 torch.float64
# epoch 683, loss 1012.5430273526947
# torch.float64 torch.float64
# epoch 684, loss 1009.0299182698609
# torch.float64 torch.float64
# epoch 685, loss 1005.5293879986657
# torch.float64 torch.float64
# epoch 686, loss 1002.0413903919034
# torch.float64 torch.float64
# epoch 687, loss 998.5658794752302
# torch.float64 torch.float64
# epoch 688, loss 995.1028094465058
# torch.float64 torch.float64
# epoch 689, loss 991.6521346751372
# torch.float64 torch.float64
# epoch 690, loss 988.2138097014238
# torch.float64 torch.float64
# epoch 691, loss 984.7877892359083
# torch.float64 torch.float64
# epoch 692, loss 981.3740281587254
# torch.float64 torch.float64
# epoch 693, loss 977.9724815189572
# torch.float64 torch.float64
# epoch 694, loss 974.5831045339897
# torch.float64 torch.float64
# epoch 695, loss 971.2058525888709
# torch.float64 torch.float64
# epoch 696, loss 967.8406812356714
# torch.float64 torch.float64
# epoch 697, loss 964.4875461928493
# torch.float64 torch.float64
# epoch 698, loss 961.1464033446166
# torch.float64 torch.float64
# epoch 699, loss 957.8172087403051
# torch.float64 torch.float64
# epoch 700, loss 954.4999185937424
# torch.float64 torch.float64
# epoch 701, loss 951.1944892826205
# torch.float64 torch.float64
# epoch 702, loss 947.9008773478739
# torch.float64 torch.float64
# epoch 703, loss 944.6190394930585
# torch.float64 torch.float64
# epoch 704, loss 941.3489325837315
# torch.float64 torch.float64
# epoch 705, loss 938.0905136468336
# torch.float64 torch.float64
# epoch 706, loss 934.8437398700764
# torch.float64 torch.float64
# epoch 707, loss 931.6085686013294
# torch.float64 torch.float64
# epoch 708, loss 928.3849573480093
# torch.float64 torch.float64
# epoch 709, loss 925.1728637764747
# torch.float64 torch.float64
# epoch 710, loss 921.9722457114189
# torch.float64 torch.float64
# epoch 711, loss 918.7830611352689
# torch.float64 torch.float64
# epoch 712, loss 915.6052681875829
# torch.float64 torch.float64
# epoch 713, loss 912.4388251644552
# torch.float64 torch.float64
# epoch 714, loss 909.2836905179171
# torch.float64 torch.float64
# epoch 715, loss 906.1398228553468
# torch.float64 torch.float64
# epoch 716, loss 903.0071809388752
# torch.float64 torch.float64
# epoch 717, loss 899.8857236847987
# torch.float64 torch.float64
# epoch 718, loss 896.7754101629929
# torch.float64 torch.float64
# epoch 719, loss 893.6761995963267
# torch.float64 torch.float64
# epoch 720, loss 890.5880513600808
# torch.float64 torch.float64
# epoch 721, loss 887.5109249813693
# torch.float64 torch.float64
# epoch 722, loss 884.4447801385597
# torch.float64 torch.float64
# epoch 723, loss 881.389576660699
# torch.float64 torch.float64
# epoch 724, loss 878.3452745269412
# torch.float64 torch.float64
# epoch 725, loss 875.311833865974
# torch.float64 torch.float64
# epoch 726, loss 872.2892149554522
# torch.float64 torch.float64
# epoch 727, loss 869.277378221431
# torch.float64 torch.float64
# epoch 728, loss 866.2762842377988
# torch.float64 torch.float64
# epoch 729, loss 863.2858937257199
# torch.float64 torch.float64
# epoch 730, loss 860.3061675530698
# torch.float64 torch.float64
# epoch 731, loss 857.337066733881
# torch.float64 torch.float64
# epoch 732, loss 854.3785524277837
# torch.float64 torch.float64
# epoch 733, loss 851.430585939456
# torch.float64 torch.float64
# epoch 734, loss 848.4931287180696
# torch.float64 torch.float64
# epoch 735, loss 845.5661423567419
# torch.float64 torch.float64
# epoch 736, loss 842.6495885919887
# torch.float64 torch.float64
# epoch 737, loss 839.7434293031781
# torch.float64 torch.float64
# epoch 738, loss 836.8476265119895
# torch.float64 torch.float64
# epoch 739, loss 833.9621423818704
# torch.float64 torch.float64
# epoch 740, loss 831.0869392174994
# torch.float64 torch.float64
# epoch 741, loss 828.221979464249
# torch.float64 torch.float64
# epoch 742, loss 825.3672257076507
# torch.float64 torch.float64
# epoch 743, loss 822.5226406728619
# torch.float64 torch.float64
# epoch 744, loss 819.6881872241368
# torch.float64 torch.float64
# epoch 745, loss 816.863828364297
# torch.float64 torch.float64
# epoch 746, loss 814.0495272342047
# torch.float64 torch.float64
# epoch 747, loss 811.2452471122397
# torch.float64 torch.float64
# epoch 748, loss 808.4509514137756
# torch.float64 torch.float64
# epoch 749, loss 805.6666036906596
# torch.float64 torch.float64
# epoch 750, loss 802.8921676306952
# torch.float64 torch.float64
# epoch 751, loss 800.1276070571245
# torch.float64 torch.float64
# epoch 752, loss 797.3728859281143
# torch.float64 torch.float64
# epoch 753, loss 794.6279683362443
# torch.float64 torch.float64
# epoch 754, loss 791.8928185079963
# torch.float64 torch.float64
# epoch 755, loss 789.1674008032453
# torch.float64 torch.float64
# epoch 756, loss 786.4516797147528
# torch.float64 torch.float64
# epoch 757, loss 783.7456198676641
# torch.float64 torch.float64
# epoch 758, loss 781.049186019003
# torch.float64 torch.float64
# epoch 759, loss 778.3623430571733
# torch.float64 torch.float64
# epoch 760, loss 775.6850560014598
# torch.float64 torch.float64
# epoch 761, loss 773.0172900015299
# torch.float64 torch.float64
# epoch 762, loss 770.35901033694
# torch.float64 torch.float64
# epoch 763, loss 767.7101824166431
# torch.float64 torch.float64
# epoch 764, loss 765.0707717784962
# torch.float64 torch.float64
# epoch 765, loss 762.4407440887719
# torch.float64 torch.float64
# epoch 766, loss 759.8200651416712
# torch.float64 torch.float64
# epoch 767, loss 757.2087008588376
# torch.float64 torch.float64
# epoch 768, loss 754.6066172888738
# torch.float64 torch.float64
# epoch 769, loss 752.0137806068606
# torch.float64 torch.float64
# epoch 770, loss 749.4301571138756
# torch.float64 torch.float64
# ...
# epoch 2747, loss 5.650733609846017
# torch.float64 torch.float64
# epoch 2748, loss 5.6465291109464655
# torch.float64 torch.float64
# epoch 2749, loss 5.642337158530464
# torch.float64 torch.float64
# epoch 2750, loss 5.638157714425233
# torch.float64 torch.float64
# epoch 2751, loss 5.633990740576784
# torch.float64 torch.float64
# epoch 2752, loss 5.629836199049651
# torch.float64 torch.float64
# epoch 2753, loss 5.625694052026427
# torch.float64 torch.float64
# epoch 2754, loss 5.621564261807457
# torch.float64 torch.float64
# epoch 2755, loss 5.6174467908103605
# torch.float64 torch.float64
# epoch 2756, loss 5.613341601569745
# torch.float64 torch.float64
# epoch 2757, loss 5.609248656736844
# torch.float64 torch.float64
# epoch 2758, loss 5.60516791907909
# torch.float64 torch.float64
# epoch 2759, loss 5.6010993514796885
# torch.float64 torch.float64
# epoch 2760, loss 5.597042916937423
# torch.float64 torch.float64
# epoch 2761, loss 5.592998578566094
# torch.float64 torch.float64
# epoch 2762, loss 5.588966299594317
# torch.float64 torch.float64
# epoch 2763, loss 5.5849460433650195
# torch.float64 torch.float64
# epoch 2764, loss 5.580937773335175
# torch.float64 torch.float64
# epoch 2765, loss 5.576941453075356
# torch.float64 torch.float64
# epoch 2766, loss 5.572957046269451
# torch.float64 torch.float64
# epoch 2767, loss 5.568984516714282
# torch.float64 torch.float64
# epoch 2768, loss 5.565023828319181
# torch.float64 torch.float64
# epoch 2769, loss 5.5610749451057035
# torch.float64 torch.float64
# epoch 2770, loss 5.557137831207216
# torch.float64 torch.float64
# epoch 2771, loss 5.553212450868655
# torch.float64 torch.float64
# epoch 2772, loss 5.549298768445961
# torch.float64 torch.float64
# epoch 2773, loss 5.545396748405951
# torch.float64 torch.float64
# epoch 2774, loss 5.541506355325811
# torch.float64 torch.float64
# epoch 2775, loss 5.537627553892827
# torch.float64 torch.float64
# epoch 2776, loss 5.533760308903948
# torch.float64 torch.float64
# epoch 2777, loss 5.52990458526558
# torch.float64 torch.float64
# epoch 2778, loss 5.526060347993033
# torch.float64 torch.float64
# epoch 2779, loss 5.522227562210346
# torch.float64 torch.float64
# epoch 2780, loss 5.518406193149909
# torch.float64 torch.float64
# epoch 2781, loss 5.514596206152065
# torch.float64 torch.float64
# epoch 2782, loss 5.510797566664773
# torch.float64 torch.float64
# epoch 2783, loss 5.507010240243332
# torch.float64 torch.float64
# epoch 2784, loss 5.503234192549918
# torch.float64 torch.float64
# epoch 2785, loss 5.499469389353434
# torch.float64 torch.float64
# epoch 2786, loss 5.495715796528897
# torch.float64 torch.float64
# epoch 2787, loss 5.491973380057383
# torch.float64 torch.float64
# epoch 2788, loss 5.488242106025483
# torch.float64 torch.float64
# epoch 2789, loss 5.484521940625081
# torch.float64 torch.float64
# epoch 2790, loss 5.480812850153013
# torch.float64 torch.float64
# epoch 2791, loss 5.477114801010633
# torch.float64 torch.float64
# epoch 2792, loss 5.473427759703604
# torch.float64 torch.float64
# epoch 2793, loss 5.46975169284151
# torch.float64 torch.float64
# epoch 2794, loss 5.466086567137462
# torch.float64 torch.float64
# epoch 2795, loss 5.462432349407901
# torch.float64 torch.float64
# epoch 2796, loss 5.458789006572205
# torch.float64 torch.float64
# epoch 2797, loss 5.455156505652311
# torch.float64 torch.float64
# epoch 2798, loss 5.45153481377243
# torch.float64 torch.float64
# epoch 2799, loss 5.447923898158849
# torch.float64 torch.float64
# epoch 2800, loss 5.444323726139269
# torch.float64 torch.float64
# epoch 2801, loss 5.4407342651429165
# torch.float64 torch.float64
# epoch 2802, loss 5.437155482699842
# torch.float64 torch.float64
# epoch 2803, loss 5.433587346440851
# torch.float64 torch.float64
# epoch 2804, loss 5.430029824097041
# torch.float64 torch.float64
# epoch 2805, loss 5.426482883499557
# torch.float64 torch.float64
# epoch 2806, loss 5.422946492579244
# torch.float64 torch.float64
# epoch 2807, loss 5.419420619366335
# torch.float64 torch.float64
# epoch 2808, loss 5.4159052319901395
# torch.float64 torch.float64
# epoch 2809, loss 5.412400298678692
# torch.float64 torch.float64
# epoch 2810, loss 5.408905787758523
# torch.float64 torch.float64
# epoch 2811, loss 5.405421667654268
# torch.float64 torch.float64
# epoch 2812, loss 5.40194790688833
# torch.float64 torch.float64
# epoch 2813, loss 5.398484474080731
# torch.float64 torch.float64
# epoch 2814, loss 5.3950313379486055
# torch.float64 torch.float64
# epoch 2815, loss 5.391588467305988
# torch.float64 torch.float64
# epoch 2816, loss 5.38815583106349
# torch.float64 torch.float64
# epoch 2817, loss 5.384733398228034
# torch.float64 torch.float64
# epoch 2818, loss 5.381321137902469
# torch.float64 torch.float64
# epoch 2819, loss 5.377919019285319
# torch.float64 torch.float64
# epoch 2820, loss 5.374527011670498
# torch.float64 torch.float64
# epoch 2821, loss 5.371145084446921
# torch.float64 torch.float64
# epoch 2822, loss 5.367773207098312
# torch.float64 torch.float64
# epoch 2823, loss 5.3644113492028
# torch.float64 torch.float64
# epoch 2824, loss 5.36105948043268
# torch.float64 torch.float64
# epoch 2825, loss 5.357717570554156
# torch.float64 torch.float64
# epoch 2826, loss 5.354385589426922
# torch.float64 torch.float64
# epoch 2827, loss 5.351063507003937
# torch.float64 torch.float64
# epoch 2828, loss 5.347751293331159
# torch.float64 torch.float64
# epoch 2829, loss 5.344448918547181
# torch.float64 torch.float64
# epoch 2830, loss 5.3411563528829875
# torch.float64 torch.float64
# epoch 2831, loss 5.337873566661654
# torch.float64 torch.float64
# epoch 2832, loss 5.334600530298006
# torch.float64 torch.float64
# epoch 2833, loss 5.3313372142984345
# torch.float64 torch.float64
# epoch 2834, loss 5.328083589260484
# torch.float64 torch.float64
# epoch 2835, loss 5.324839625872614
# torch.float64 torch.float64
# epoch 2836, loss 5.3216052949139465
# torch.float64 torch.float64
# epoch 2837, loss 5.318380567253949
# torch.float64 torch.float64
# epoch 2838, loss 5.315165413852112
# torch.float64 torch.float64
# epoch 2839, loss 5.311959805757705
# torch.float64 torch.float64
# epoch 2840, loss 5.308763714109525
# torch.float64 torch.float64
# epoch 2841, loss 5.305577110135475
# torch.float64 torch.float64
# epoch 2842, loss 5.302399965152482
# torch.float64 torch.float64
# epoch 2843, loss 5.299232250566071
# torch.float64 torch.float64
# epoch 2844, loss 5.296073937870105
# torch.float64 torch.float64
# epoch 2845, loss 5.292924998646549
# torch.float64 torch.float64
# epoch 2846, loss 5.2897854045651655
# torch.float64 torch.float64
# epoch 2847, loss 5.286655127383194
# torch.float64 torch.float64
# epoch 2848, loss 5.2835341389452255
# torch.float64 torch.float64
# epoch 2849, loss 5.280422411182647
# torch.float64 torch.float64
# epoch 2850, loss 5.2773199161136874
# torch.float64 torch.float64
# epoch 2851, loss 5.274226625842934
# torch.float64 torch.float64
# epoch 2852, loss 5.27114251256109
# torch.float64 torch.float64
# epoch 2853, loss 5.268067548544776
# torch.float64 torch.float64
# epoch 2854, loss 5.2650017061561725
# torch.float64 torch.float64
# epoch 2855, loss 5.261944957842802
# torch.float64 torch.float64
# epoch 2856, loss 5.25889727613728
# torch.float64 torch.float64
# epoch 2857, loss 5.2558586336569375
# torch.float64 torch.float64
# epoch 2858, loss 5.252829003103656
# torch.float64 torch.float64
# epoch 2859, loss 5.2498083572635625
# torch.float64 torch.float64
# epoch 2860, loss 5.246796669006811
# torch.float64 torch.float64
# epoch 2861, loss 5.2437939112872
# torch.float64 torch.float64
# epoch 2862, loss 5.240800057142057
# torch.float64 torch.float64
# epoch 2863, loss 5.237815079691837
# torch.float64 torch.float64
# epoch 2864, loss 5.23483895213996
# torch.float64 torch.float64
# epoch 2865, loss 5.2318716477724925
# torch.float64 torch.float64
# epoch 2866, loss 5.228913139957922
# torch.float64 torch.float64
# epoch 2867, loss 5.2259634021468475
# torch.float64 torch.float64
# epoch 2868, loss 5.223022407871764
# torch.float64 torch.float64
# epoch 2869, loss 5.220090130746793
# torch.float64 torch.float64
# epoch 2870, loss 5.217166544467405
# torch.float64 torch.float64
# epoch 2871, loss 5.214251622810264
# torch.float64 torch.float64
# epoch 2872, loss 5.211345339632748
# torch.float64 torch.float64
# epoch 2873, loss 5.208447668872895
# torch.float64 torch.float64
# epoch 2874, loss 5.205558584549114
# torch.float64 torch.float64
# epoch 2875, loss 5.202678060759886
# torch.float64 torch.float64
# epoch 2876, loss 5.199806071683489
# torch.float64 torch.float64
# epoch 2877, loss 5.196942591577817
# torch.float64 torch.float64
# epoch 2878, loss 5.194087594780091
# torch.float64 torch.float64
# epoch 2879, loss 5.191241055706618
# torch.float64 torch.float64
# epoch 2880, loss 5.188402948852493
# torch.float64 torch.float64
# epoch 2881, loss 5.185573248791443
# torch.float64 torch.float64
# epoch 2882, loss 5.182751930175478
# torch.float64 torch.float64
# epoch 2883, loss 5.179938967734752
# torch.float64 torch.float64
# epoch 2884, loss 5.177134336277196
# torch.float64 torch.float64
# epoch 2885, loss 5.174338010688421
# torch.float64 torch.float64
# epoch 2886, loss 5.171549965931253
# torch.float64 torch.float64
# epoch 2887, loss 5.168770177045776
# torch.float64 torch.float64
# epoch 2888, loss 5.165998619148804
# torch.float64 torch.float64
# epoch 2889, loss 5.163235267433846
# torch.float64 torch.float64
# epoch 2890, loss 5.160480097170722
# torch.float64 torch.float64
# epoch 2891, loss 5.15773308370549
# torch.float64 torch.float64
# epoch 2892, loss 5.154994202459983
# torch.float64 torch.float64
# epoch 2893, loss 5.152263428931787
# torch.float64 torch.float64
# epoch 2894, loss 5.149540738693816
# torch.float64 torch.float64
# epoch 2895, loss 5.146826107394241
# torch.float64 torch.float64
# epoch 2896, loss 5.144119510756122
# torch.float64 torch.float64
# epoch 2897, loss 5.141420924577249
# torch.float64 torch.float64
# epoch 2898, loss 5.13873032472987
# torch.float64 torch.float64
# epoch 2899, loss 5.136047687160482
# torch.float64 torch.float64
# epoch 2900, loss 5.133372987889549
# torch.float64 torch.float64
# epoch 2901, loss 5.1307062030113695
# torch.float64 torch.float64
# epoch 2902, loss 5.128047308693688
# torch.float64 torch.float64
# epoch 2903, loss 5.125396281177595
# torch.float64 torch.float64
# epoch 2904, loss 5.1227530967772665
# torch.float64 torch.float64
# epoch 2905, loss 5.120117731879669
# torch.float64 torch.float64
# epoch 2906, loss 5.117490162944461
# torch.float64 torch.float64
# epoch 2907, loss 5.114870366503603
# torch.float64 torch.float64
# epoch 2908, loss 5.112258319161275
# torch.float64 torch.float64
# epoch 2909, loss 5.109653997593517
# torch.float64 torch.float64
# epoch 2910, loss 5.1070573785481255
# torch.float64 torch.float64
# epoch 2911, loss 5.1044684388443615
# torch.float64 torch.float64
# epoch 2912, loss 5.101887155372688
# torch.float64 torch.float64
# epoch 2913, loss 5.0993135050946465
# torch.float64 torch.float64
# epoch 2914, loss 5.096747465042557
# torch.float64 torch.float64
# epoch 2915, loss 5.094189012319335
# torch.float64 torch.float64
# epoch 2916, loss 5.0916381240982345
# torch.float64 torch.float64
# epoch 2917, loss 5.089094777622627
# torch.float64 torch.float64
# epoch 2918, loss 5.0865589502058555
# torch.float64 torch.float64
# epoch 2919, loss 5.084030619230871
# torch.float64 torch.float64
# epoch 2920, loss 5.081509762150179
# torch.float64 torch.float64
# epoch 2921, loss 5.078996356485497
# torch.float64 torch.float64
# epoch 2922, loss 5.076490379827602
# torch.float64 torch.float64
# epoch 2923, loss 5.0739918098360475
# torch.float64 torch.float64
# epoch 2924, loss 5.0715006242390555
# torch.float64 torch.float64
# epoch 2925, loss 5.069016800833175
# torch.float64 torch.float64
# epoch 2926, loss 5.0665403174831605
# torch.float64 torch.float64
# epoch 2927, loss 5.064071152121747
# torch.float64 torch.float64
# epoch 2928, loss 5.061609282749319
# torch.float64 torch.float64
# epoch 2929, loss 5.059154687433905
# torch.float64 torch.float64
# epoch 2930, loss 5.056707344310789
# torch.float64 torch.float64
# epoch 2931, loss 5.054267231582379
# torch.float64 torch.float64
# epoch 2932, loss 5.051834327517973
# torch.float64 torch.float64
# epoch 2933, loss 5.049408610453544
# torch.float64 torch.float64
# epoch 2934, loss 5.046990058791598
# torch.float64 torch.float64
# epoch 2935, loss 5.04457865100081
# torch.float64 torch.float64
# epoch 2936, loss 5.042174365615962
# torch.float64 torch.float64
# epoch 2937, loss 5.039777181237751
# torch.float64 torch.float64
# epoch 2938, loss 5.037387076532417
# torch.float64 torch.float64
# epoch 2939, loss 5.0350040302316845
# torch.float64 torch.float64
# epoch 2940, loss 5.032628021132475
# torch.float64 torch.float64
# epoch 2941, loss 5.030259028096806
# torch.float64 torch.float64
# epoch 2942, loss 5.027897030051445
# torch.float64 torch.float64
# epoch 2943, loss 5.025542005987832
# torch.float64 torch.float64
# epoch 2944, loss 5.02319393496177
# torch.float64 torch.float64
# epoch 2945, loss 5.02085279609334
# torch.float64 torch.float64
# epoch 2946, loss 5.018518568566604
# torch.float64 torch.float64
# epoch 2947, loss 5.016191231629382
# torch.float64 torch.float64
# epoch 2948, loss 5.013870764593184
# torch.float64 torch.float64
# epoch 2949, loss 5.011557146832898
# torch.float64 torch.float64
# epoch 2950, loss 5.009250357786617
# torch.float64 torch.float64
# epoch 2951, loss 5.006950376955444
# torch.float64 torch.float64
# epoch 2952, loss 5.004657183903345
# torch.float64 torch.float64
# epoch 2953, loss 5.002370758256808
# torch.float64 torch.float64
# epoch 2954, loss 5.000091079704864
# torch.float64 torch.float64
# epoch 2955, loss 4.9978181279986575
# torch.float64 torch.float64
# epoch 2956, loss 4.995551882951444
# torch.float64 torch.float64
# epoch 2957, loss 4.9932923244382454
# torch.float64 torch.float64
# epoch 2958, loss 4.991039432395792
# torch.float64 torch.float64
# epoch 2959, loss 4.9887931868222095
# torch.float64 torch.float64
# epoch 2960, loss 4.986553567776939
# torch.float64 torch.float64
# epoch 2961, loss 4.984320555380387
# torch.float64 torch.float64
# epoch 2962, loss 4.9820941298139285
# torch.float64 torch.float64
# epoch 2963, loss 4.979874271319583
# torch.float64 torch.float64
# epoch 2964, loss 4.977660960199844
# torch.float64 torch.float64
# epoch 2965, loss 4.975454176817545
# torch.float64 torch.float64
# epoch 2966, loss 4.973253901595568
# torch.float64 torch.float64
# epoch 2967, loss 4.971060115016781
# torch.float64 torch.float64
# epoch 2968, loss 4.968872797623783
# torch.float64 torch.float64
# epoch 2969, loss 4.966691930018661
# torch.float64 torch.float64
# epoch 2970, loss 4.964517492862916
# torch.float64 torch.float64
# epoch 2971, loss 4.962349466877233
# torch.float64 torch.float64
# epoch 2972, loss 4.96018783284123
# torch.float64 torch.float64
# epoch 2973, loss 4.95803257159338
# torch.float64 torch.float64
# epoch 2974, loss 4.955883664030788
# torch.float64 torch.float64
# epoch 2975, loss 4.953741091108931
# torch.float64 torch.float64
# epoch 2976, loss 4.9516048338415874
# torch.float64 torch.float64
# epoch 2977, loss 4.949474873300639
# torch.float64 torch.float64
# epoch 2978, loss 4.947351190615754
# torch.float64 torch.float64
# epoch 2979, loss 4.94523376697443
# torch.float64 torch.float64
# epoch 2980, loss 4.9431225836215775
# torch.float64 torch.float64
# epoch 2981, loss 4.941017621859542
# torch.float64 torch.float64
# epoch 2982, loss 4.9389188630478005
# torch.float64 torch.float64
# epoch 2983, loss 4.9368262886028305
# torch.float64 torch.float64
# epoch 2984, loss 4.9347398799979105
# torch.float64 torch.float64
# epoch 2985, loss 4.932659618762924
# torch.float64 torch.float64
# epoch 2986, loss 4.930585486484264
# torch.float64 torch.float64
# epoch 2987, loss 4.928517464804597
# torch.float64 torch.float64
# epoch 2988, loss 4.926455535422656
# torch.float64 torch.float64
# epoch 2989, loss 4.9243996800930985
# torch.float64 torch.float64
# epoch 2990, loss 4.922349880626373
# torch.float64 torch.float64
# epoch 2991, loss 4.920306118888467
# torch.float64 torch.float64
# epoch 2992, loss 4.918268376800825
# torch.float64 torch.float64
# epoch 2993, loss 4.916236636340045
# torch.float64 torch.float64
# epoch 2994, loss 4.914210879537833
# torch.float64 torch.float64
# epoch 2995, loss 4.912191088480784
# torch.float64 torch.float64
# epoch 2996, loss 4.910177245310174
# torch.float64 torch.float64
# epoch 2997, loss 4.90816933222186
# torch.float64 torch.float64
# epoch 2998, loss 4.906167331466055
# torch.float64 torch.float64
# epoch 2999, loss 4.90417122534714
# Mean squared error: 6.57
# Coefficient of determination: 1.00

# %%
with torch.no_grad(): # we don't need gradients in the testing phase
    if torch.cuda.is_available():
        y_surface = model(Variable(torch.from_numpy(X_surface).cuda())).cpu().data.numpy()
    else:
        y_surface = model(Variable(torch.from_numpy(X_surface))).data.numpy()
    # print(y_pred)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec Tensorflow
#
# Docs:
# - https://www.tensorflow.org/api_docs
# - https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb

# %%
from distutils.version import LooseVersion
from keras import __version__ as version
import pandas as pd
import tensorflow as tf

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

l_rate=0.01
n_iter=500
batch_size=2

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=1))
optimizer = None
if LooseVersion(version) >= LooseVersion('3'):
    optimizer = tf.keras.optimizers.Adam(learning_rate=l_rate)
else:
    optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=l_rate)
model.compile(
    optimizer=optimizer,
    loss="mean_squared_error",
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )
history = model.fit(x=X_train, y=y_train, batch_size=batch_size, epochs=n_iter)
trained_weight = model.get_weights()[0]
trained_bias = model.get_weights()[1]
epochs = history.epoch
hist = pd.DataFrame(history.history)
rmse = hist["root_mean_squared_error"]

y_pred = model.predict(X_test)

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# Epoch 1/500
# /var/folders/2q/_q3vgn0d217gj990kgxmz3dm0000gn/T/ipykernel_51358/3193410709.py:17: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(version) >= LooseVersion('3'):
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 13145.4209 - root_mean_squared_error: 114.2633
# Epoch 2/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 483us/step - loss: 11191.1865 - root_mean_squared_error: 105.3870
# Epoch 3/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 13138.3838 - root_mean_squared_error: 114.4013
# Epoch 4/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 10213.2480 - root_mean_squared_error: 100.4932
# Epoch 5/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 12518.4014 - root_mean_squared_error: 111.6992
# Epoch 6/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 9850.1895 - root_mean_squared_error: 98.3227
# Epoch 7/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 12659.9727 - root_mean_squared_error: 111.4966
# Epoch 8/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 12236.8701 - root_mean_squared_error: 110.4872
# Epoch 9/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 10038.7920 - root_mean_squared_error: 99.8536
# Epoch 10/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 11218.2207 - root_mean_squared_error: 105.7516
# Epoch 11/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 10308.7969 - root_mean_squared_error: 100.7605
# Epoch 12/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 10279.3135 - root_mean_squared_error: 101.2517
# Epoch 13/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 10297.0439 - root_mean_squared_error: 100.9285
# Epoch 14/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 10523.6787 - root_mean_squared_error: 102.3907
# Epoch 15/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 10389.3389 - root_mean_squared_error: 101.1795
# Epoch 16/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 9690.6689 - root_mean_squared_error: 98.0340
# Epoch 17/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 10787.9580 - root_mean_squared_error: 103.6462
# Epoch 18/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 12044.0684 - root_mean_squared_error: 109.3825
# Epoch 19/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 9733.2598 - root_mean_squared_error: 98.4842
# Epoch 20/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 10762.3701 - root_mean_squared_error: 103.2196
# Epoch 21/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 9569.0703 - root_mean_squared_error: 96.0977
# Epoch 22/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 10276.2129 - root_mean_squared_error: 101.1818
# Epoch 23/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 9258.3760 - root_mean_squared_error: 96.0825
# Epoch 24/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 10377.0625 - root_mean_squared_error: 101.6775
# Epoch 25/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 8958.8682 - root_mean_squared_error: 93.4943
# Epoch 26/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 9848.0234 - root_mean_squared_error: 99.1200
# Epoch 27/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 10239.2275 - root_mean_squared_error: 101.0250
# Epoch 28/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 7745.0723 - root_mean_squared_error: 87.7365
# Epoch 29/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 9558.2861 - root_mean_squared_error: 97.6008
# Epoch 30/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 7824.1289 - root_mean_squared_error: 87.9623
# Epoch 31/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 9923.7646 - root_mean_squared_error: 99.4304
# Epoch 32/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 10038.2637 - root_mean_squared_error: 100.0870
# Epoch 33/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 9306.1885 - root_mean_squared_error: 96.3046
# Epoch 34/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 8491.0352 - root_mean_squared_error: 91.9536
# Epoch 35/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 9882.7344 - root_mean_squared_error: 99.1616
# Epoch 36/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 9342.6943 - root_mean_squared_error: 96.5069
# Epoch 37/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 8998.1523 - root_mean_squared_error: 94.7139
# Epoch 38/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 10223.2998 - root_mean_squared_error: 100.8581
# Epoch 39/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - loss: 10928.9658 - root_mean_squared_error: 104.2198
# Epoch 40/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 7963.3535 - root_mean_squared_error: 87.3202
# Epoch 41/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 7012.9160 - root_mean_squared_error: 83.2576
# Epoch 42/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 7726.3374 - root_mean_squared_error: 87.2218
# Epoch 43/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 9152.5781 - root_mean_squared_error: 95.4555
# Epoch 44/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 8682.4102 - root_mean_squared_error: 93.1063
# Epoch 45/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 9370.9053 - root_mean_squared_error: 95.7298
# Epoch 46/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 10192.2881 - root_mean_squared_error: 100.5264
# Epoch 47/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 9248.5703 - root_mean_squared_error: 95.8905
# Epoch 48/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 9148.3477 - root_mean_squared_error: 95.4500
# Epoch 49/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 7104.8623 - root_mean_squared_error: 83.7889
# Epoch 50/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 7576.2690 - root_mean_squared_error: 86.9083
# Epoch 51/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 9405.1260 - root_mean_squared_error: 96.7195
# Epoch 52/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 8420.4834 - root_mean_squared_error: 91.6388
# Epoch 53/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 7187.9502 - root_mean_squared_error: 84.5031
# Epoch 54/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 7590.8896 - root_mean_squared_error: 86.7198
# Epoch 55/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 8711.2031 - root_mean_squared_error: 92.6530
# Epoch 56/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 6773.9404 - root_mean_squared_error: 81.6102
# Epoch 57/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 7426.8564 - root_mean_squared_error: 85.6289
# Epoch 58/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 8734.4795 - root_mean_squared_error: 93.1813
# Epoch 59/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 8197.5068 - root_mean_squared_error: 90.4310
# Epoch 60/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 8833.0996 - root_mean_squared_error: 93.8673
# Epoch 61/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - loss: 7688.9048 - root_mean_squared_error: 87.3207
# Epoch 62/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 5723.8130 - root_mean_squared_error: 74.2539
# Epoch 63/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 7004.6387 - root_mean_squared_error: 83.5798
# Epoch 64/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 5799.1206 - root_mean_squared_error: 75.2424
# Epoch 65/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 6454.8535 - root_mean_squared_error: 80.1598
# Epoch 66/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 6752.3213 - root_mean_squared_error: 81.9278
# Epoch 67/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 8333.2275 - root_mean_squared_error: 90.8595
# Epoch 68/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 6484.1084 - root_mean_squared_error: 80.1897
# Epoch 69/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 6092.5391 - root_mean_squared_error: 76.6497
# Epoch 70/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 7012.3530 - root_mean_squared_error: 83.0541
# Epoch 71/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 7763.2427 - root_mean_squared_error: 87.5026
# Epoch 72/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 7162.4692 - root_mean_squared_error: 84.4869
# Epoch 73/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 7513.4639 - root_mean_squared_error: 86.1088
# Epoch 74/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 7860.7397 - root_mean_squared_error: 88.1739
# Epoch 75/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 5989.9609 - root_mean_squared_error: 76.7177
# Epoch 76/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 6461.6685 - root_mean_squared_error: 80.3038
# Epoch 77/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 7772.5068 - root_mean_squared_error: 87.8804
# Epoch 78/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 7419.8887 - root_mean_squared_error: 85.9787
# Epoch 79/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 6376.3506 - root_mean_squared_error: 79.6975
# Epoch 80/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 6301.6943 - root_mean_squared_error: 79.3294
# Epoch 81/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 6156.4727 - root_mean_squared_error: 77.9706
# Epoch 82/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 7719.3203 - root_mean_squared_error: 87.3024
# Epoch 83/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 7661.7407 - root_mean_squared_error: 86.5227
# Epoch 84/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 6360.8394 - root_mean_squared_error: 79.5501
# Epoch 85/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 5108.2153 - root_mean_squared_error: 71.0017
# Epoch 86/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 6178.7915 - root_mean_squared_error: 78.2263
# Epoch 87/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 5821.7344 - root_mean_squared_error: 76.0054
# Epoch 88/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 4824.3066 - root_mean_squared_error: 67.4882
# Epoch 89/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 6844.3516 - root_mean_squared_error: 82.1913
# Epoch 90/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 6675.0708 - root_mean_squared_error: 81.4285
# Epoch 91/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 6979.3608 - root_mean_squared_error: 83.3060
# Epoch 92/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 5664.1162 - root_mean_squared_error: 74.9900
# Epoch 93/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 6308.3110 - root_mean_squared_error: 79.2690
# Epoch 94/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 5812.5039 - root_mean_squared_error: 76.0935
# Epoch 95/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 4741.9102 - root_mean_squared_error: 68.2757
# Epoch 96/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 5130.2607 - root_mean_squared_error: 71.3518
# Epoch 97/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 4723.8066 - root_mean_squared_error: 68.1170
# Epoch 98/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 5142.4634 - root_mean_squared_error: 70.9924
# Epoch 99/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 6341.4609 - root_mean_squared_error: 79.4503
# Epoch 100/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 6120.8857 - root_mean_squared_error: 77.9023
# Epoch 101/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 6317.5820 - root_mean_squared_error: 79.2723
# Epoch 102/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 5545.7827 - root_mean_squared_error: 74.3145
# Epoch 103/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 5289.9956 - root_mean_squared_error: 72.1736
# Epoch 104/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 5116.7808 - root_mean_squared_error: 71.3333
# Epoch 105/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 5719.6582 - root_mean_squared_error: 75.5241
# Epoch 106/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 5210.0010 - root_mean_squared_error: 72.0885
# Epoch 107/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 5379.4082 - root_mean_squared_error: 73.2867
# Epoch 108/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 4322.6045 - root_mean_squared_error: 65.3975
# Epoch 109/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 5564.8340 - root_mean_squared_error: 74.4788
# Epoch 110/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 4769.4116 - root_mean_squared_error: 68.7867
# Epoch 111/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 5290.9307 - root_mean_squared_error: 72.5613
# Epoch 112/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 4674.0610 - root_mean_squared_error: 67.7349
# Epoch 113/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 4506.6377 - root_mean_squared_error: 66.9414
# Epoch 114/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 5056.5244 - root_mean_squared_error: 70.9800
# Epoch 115/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 4490.9375 - root_mean_squared_error: 66.6278
# Epoch 116/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 4027.9692 - root_mean_squared_error: 63.2961
# Epoch 117/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 5541.8340 - root_mean_squared_error: 74.2299
# Epoch 118/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 3799.4634 - root_mean_squared_error: 60.8067
# Epoch 119/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4609.8516 - root_mean_squared_error: 67.7362
# Epoch 120/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 4274.7764 - root_mean_squared_error: 65.0374
# Epoch 121/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 4034.2734 - root_mean_squared_error: 63.2469
# Epoch 122/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 4872.7080 - root_mean_squared_error: 69.5926
# Epoch 123/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 5050.8828 - root_mean_squared_error: 70.8239
# Epoch 124/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4982.5122 - root_mean_squared_error: 70.3972
# Epoch 125/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 3800.5415 - root_mean_squared_error: 60.7214
# Epoch 126/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 4161.8677 - root_mean_squared_error: 63.7125
# Epoch 127/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 4171.3984 - root_mean_squared_error: 64.5019
# Epoch 128/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 4426.4658 - root_mean_squared_error: 66.2500
# Epoch 129/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 4167.3940 - root_mean_squared_error: 64.5123
# Epoch 130/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 4229.9771 - root_mean_squared_error: 64.8127
# Epoch 131/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 3625.5718 - root_mean_squared_error: 59.9891
# Epoch 132/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - loss: 4982.7529 - root_mean_squared_error: 70.2271
# Epoch 133/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 3039.5701 - root_mean_squared_error: 54.3764
# Epoch 134/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 3890.4216 - root_mean_squared_error: 62.2621
# Epoch 135/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 3789.6211 - root_mean_squared_error: 61.1840
# Epoch 136/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 3961.2546 - root_mean_squared_error: 62.8329
# Epoch 137/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 3361.7202 - root_mean_squared_error: 56.8549
# Epoch 138/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 4285.8296 - root_mean_squared_error: 65.3829
# Epoch 139/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 3442.4705 - root_mean_squared_error: 58.5691
# Epoch 140/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 4126.3066 - root_mean_squared_error: 63.9478
# Epoch 141/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 3409.6746 - root_mean_squared_error: 58.2556
# Epoch 142/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 4158.7368 - root_mean_squared_error: 63.9745
# Epoch 143/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 3395.3047 - root_mean_squared_error: 58.1868
# Epoch 144/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 3165.8250 - root_mean_squared_error: 56.1134
# Epoch 145/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 4478.9824 - root_mean_squared_error: 65.9032
# Epoch 146/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4385.0278 - root_mean_squared_error: 65.8615
# Epoch 147/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 3268.8008 - root_mean_squared_error: 57.0033
# Epoch 148/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 2921.5754 - root_mean_squared_error: 53.8722
# Epoch 149/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 2999.5242 - root_mean_squared_error: 54.6196
# Epoch 150/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 3201.7708 - root_mean_squared_error: 56.2734
# Epoch 151/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 3908.0886 - root_mean_squared_error: 62.0777
# Epoch 152/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 2729.9646 - root_mean_squared_error: 51.9365
# Epoch 153/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 3409.4763 - root_mean_squared_error: 58.1063
# Epoch 154/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 3839.9934 - root_mean_squared_error: 61.8663
# Epoch 155/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 2972.8403 - root_mean_squared_error: 54.4139
# Epoch 156/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 3113.3875 - root_mean_squared_error: 55.5555
# Epoch 157/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 3231.4705 - root_mean_squared_error: 56.5370
# Epoch 158/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 3396.8506 - root_mean_squared_error: 58.1344
# Epoch 159/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 3419.0183 - root_mean_squared_error: 57.9001
# Epoch 160/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 2846.5945 - root_mean_squared_error: 53.2307
# Epoch 161/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 3000.4927 - root_mean_squared_error: 54.6229
# Epoch 162/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 3084.8303 - root_mean_squared_error: 55.4546
# Epoch 163/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 2850.6328 - root_mean_squared_error: 53.3403
# Epoch 164/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 2777.2090 - root_mean_squared_error: 52.1749
# Epoch 165/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 2781.9197 - root_mean_squared_error: 52.6098
# Epoch 166/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 2785.9143 - root_mean_squared_error: 52.5276
# Epoch 167/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 3109.7004 - root_mean_squared_error: 55.6459
# Epoch 168/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 2681.0413 - root_mean_squared_error: 51.6364
# Epoch 169/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 517us/step - loss: 2998.4360 - root_mean_squared_error: 54.6494
# Epoch 170/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 2888.8535 - root_mean_squared_error: 53.6626
# Epoch 171/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 2284.5190 - root_mean_squared_error: 47.7225
# Epoch 172/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 2978.1050 - root_mean_squared_error: 54.2094
# Epoch 173/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 2260.2725 - root_mean_squared_error: 47.4183
# Epoch 174/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 3344.3169 - root_mean_squared_error: 57.4909
# Epoch 175/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 2402.7363 - root_mean_squared_error: 48.5740
# Epoch 176/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 2193.7654 - root_mean_squared_error: 46.7020
# Epoch 177/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 2826.4856 - root_mean_squared_error: 52.8436
# Epoch 178/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 2476.5681 - root_mean_squared_error: 49.5074
# Epoch 179/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 2151.0352 - root_mean_squared_error: 46.1846
# Epoch 180/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 2294.9353 - root_mean_squared_error: 47.7329
# Epoch 181/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 2391.8992 - root_mean_squared_error: 48.8172
# Epoch 182/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 2517.6172 - root_mean_squared_error: 50.0770
# Epoch 183/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 2114.8718 - root_mean_squared_error: 45.8429
# Epoch 184/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 2396.6838 - root_mean_squared_error: 48.8488
# Epoch 185/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 2397.4609 - root_mean_squared_error: 48.8753
# Epoch 186/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 1939.2341 - root_mean_squared_error: 43.8698
# Epoch 187/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 2482.4248 - root_mean_squared_error: 49.3306
# Epoch 188/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 2184.0510 - root_mean_squared_error: 46.4997
# Epoch 189/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 1680.6727 - root_mean_squared_error: 40.6658
# Epoch 190/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 2276.8130 - root_mean_squared_error: 47.5929
# Epoch 191/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 2142.7498 - root_mean_squared_error: 46.2010
# Epoch 192/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 2046.7118 - root_mean_squared_error: 44.8931
# Epoch 193/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 2198.8599 - root_mean_squared_error: 46.7191
# Epoch 194/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 1815.0638 - root_mean_squared_error: 42.2888
# Epoch 195/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 1878.9724 - root_mean_squared_error: 42.9058
# Epoch 196/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 1910.4460 - root_mean_squared_error: 43.6005
# Epoch 197/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 1519.2207 - root_mean_squared_error: 38.8631
# Epoch 198/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 2057.8340 - root_mean_squared_error: 45.1866
# Epoch 199/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 1607.5416 - root_mean_squared_error: 39.9922
# Epoch 200/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 1562.9413 - root_mean_squared_error: 39.3593
# Epoch 201/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 1586.5035 - root_mean_squared_error: 39.7587
# Epoch 202/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 1600.6479 - root_mean_squared_error: 39.8899
# Epoch 203/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 1425.4445 - root_mean_squared_error: 37.4133
# Epoch 204/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 1849.1415 - root_mean_squared_error: 42.8977
# Epoch 205/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 1516.8947 - root_mean_squared_error: 38.6617
# Epoch 206/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 1928.7838 - root_mean_squared_error: 43.7758
# Epoch 207/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 1894.1943 - root_mean_squared_error: 43.3427
# Epoch 208/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 1799.3119 - root_mean_squared_error: 42.2384
# Epoch 209/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 1709.5352 - root_mean_squared_error: 41.2315
# Epoch 210/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 1402.2244 - root_mean_squared_error: 37.2528
# Epoch 211/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 1440.8164 - root_mean_squared_error: 37.9124
# Epoch 212/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 1527.4194 - root_mean_squared_error: 38.9949
# Epoch 213/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 1438.0809 - root_mean_squared_error: 37.8479
# Epoch 214/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 1161.4482 - root_mean_squared_error: 33.9125
# Epoch 215/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 1372.5508 - root_mean_squared_error: 36.9660
# Epoch 216/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 1405.3562 - root_mean_squared_error: 37.3710
# Epoch 217/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 1521.9012 - root_mean_squared_error: 38.8484
# Epoch 218/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 1214.6000 - root_mean_squared_error: 34.7613
# Epoch 219/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 1419.6221 - root_mean_squared_error: 37.5569
# Epoch 220/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 1356.2507 - root_mean_squared_error: 36.7229
# Epoch 221/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 1295.1368 - root_mean_squared_error: 35.9249
# Epoch 222/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 1135.0685 - root_mean_squared_error: 33.6407
# Epoch 223/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 1133.2864 - root_mean_squared_error: 33.4125
# Epoch 224/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 1437.5601 - root_mean_squared_error: 37.7302
# Epoch 225/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 1117.1970 - root_mean_squared_error: 33.2845
# Epoch 226/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 1372.2963 - root_mean_squared_error: 36.5408
# Epoch 227/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 1100.8326 - root_mean_squared_error: 33.0120
# Epoch 228/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 1100.1228 - root_mean_squared_error: 32.9875
# Epoch 229/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 1348.2897 - root_mean_squared_error: 36.5457
# Epoch 230/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 1060.8289 - root_mean_squared_error: 32.3008
# Epoch 231/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 1085.0518 - root_mean_squared_error: 32.8963
# Epoch 232/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 1173.3395 - root_mean_squared_error: 34.1516
# Epoch 233/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 967.2206 - root_mean_squared_error: 31.0409
# Epoch 234/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 833.1241 - root_mean_squared_error: 28.5719
# Epoch 235/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 871.4342 - root_mean_squared_error: 29.4636
# Epoch 236/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 1207.8665 - root_mean_squared_error: 34.3620
# Epoch 237/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 1018.6819 - root_mean_squared_error: 31.8628
# Epoch 238/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 916.9587 - root_mean_squared_error: 29.8864
# Epoch 239/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 742.6072 - root_mean_squared_error: 26.7886
# Epoch 240/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 952.6423 - root_mean_squared_error: 30.8119
# Epoch 241/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 920.1527 - root_mean_squared_error: 30.2643
# Epoch 242/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 847.1464 - root_mean_squared_error: 28.9655
# Epoch 243/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 857.6450 - root_mean_squared_error: 29.2347
# Epoch 244/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 806.5424 - root_mean_squared_error: 28.3126
# Epoch 245/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 925.9365 - root_mean_squared_error: 30.3344
# Epoch 246/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 782.0494 - root_mean_squared_error: 27.7823
# Epoch 247/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 835.6133 - root_mean_squared_error: 28.8287
# Epoch 248/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 883.2164 - root_mean_squared_error: 29.5322
# Epoch 249/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 691.5168 - root_mean_squared_error: 26.1946
# Epoch 250/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 630.6654 - root_mean_squared_error: 24.9195
# Epoch 251/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 851.6921 - root_mean_squared_error: 29.1323
# Epoch 252/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 713.2663 - root_mean_squared_error: 26.6298
# Epoch 253/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 839.9178 - root_mean_squared_error: 28.7773
# Epoch 254/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 870.4188 - root_mean_squared_error: 29.3940
# Epoch 255/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 654.6710 - root_mean_squared_error: 25.5469
# Epoch 256/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 725.5531 - root_mean_squared_error: 26.8498
# Epoch 257/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 551.3589 - root_mean_squared_error: 23.0482
# Epoch 258/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 461.4139 - root_mean_squared_error: 21.0884
# Epoch 259/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 641.4132 - root_mean_squared_error: 25.2488
# Epoch 260/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 500.7469 - root_mean_squared_error: 21.9385
# Epoch 261/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 475.5269 - root_mean_squared_error: 21.4277
# Epoch 262/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 571.0219 - root_mean_squared_error: 23.8763
# Epoch 263/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 694.7078 - root_mean_squared_error: 26.1973
# Epoch 264/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 543us/step - loss: 465.5575 - root_mean_squared_error: 21.4237
# Epoch 265/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 569.6951 - root_mean_squared_error: 23.8200
# Epoch 266/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 491.8404 - root_mean_squared_error: 22.1218
# Epoch 267/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 535.2449 - root_mean_squared_error: 23.0281
# Epoch 268/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 518.3644 - root_mean_squared_error: 22.6840
# Epoch 269/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 573.4103 - root_mean_squared_error: 23.9230
# Epoch 270/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 463.1329 - root_mean_squared_error: 21.4355
# Epoch 271/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 500.3069 - root_mean_squared_error: 22.3151
# Epoch 272/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 453.5254 - root_mean_squared_error: 21.2829
# Epoch 273/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 432.5931 - root_mean_squared_error: 20.7482
# Epoch 274/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 440.6768 - root_mean_squared_error: 20.9490
# Epoch 275/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 407.7672 - root_mean_squared_error: 20.1121
# Epoch 276/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 454.8552 - root_mean_squared_error: 21.2414
# Epoch 277/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 452.4294 - root_mean_squared_error: 21.2206
# Epoch 278/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 474.4972 - root_mean_squared_error: 21.7080
# Epoch 279/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 384.7122 - root_mean_squared_error: 19.5367
# Epoch 280/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 408.7538 - root_mean_squared_error: 20.1683
# Epoch 281/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 355.3876 - root_mean_squared_error: 18.6809
# Epoch 282/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 356.8462 - root_mean_squared_error: 18.7792
# Epoch 283/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 396.1836 - root_mean_squared_error: 19.8499
# Epoch 284/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 327.1182 - root_mean_squared_error: 17.9602
# Epoch 285/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 366.2581 - root_mean_squared_error: 19.0495
# Epoch 286/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 262.2995 - root_mean_squared_error: 16.0659
# Epoch 287/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 328.0853 - root_mean_squared_error: 18.0288
# Epoch 288/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 366.6452 - root_mean_squared_error: 19.0672
# Epoch 289/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 355.3063 - root_mean_squared_error: 18.7329
# Epoch 290/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 299.3908 - root_mean_squared_error: 17.1992
# Epoch 291/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 319.0978 - root_mean_squared_error: 17.8244
# Epoch 292/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 262.3721 - root_mean_squared_error: 16.1571
# Epoch 293/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 306.4186 - root_mean_squared_error: 17.3628
# Epoch 294/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 249.2484 - root_mean_squared_error: 15.7048
# Epoch 295/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 269.2305 - root_mean_squared_error: 16.3279
# Epoch 296/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 223.5559 - root_mean_squared_error: 14.9062
# Epoch 297/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 199.5614 - root_mean_squared_error: 14.0770
# Epoch 298/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 203.4403 - root_mean_squared_error: 14.2140
# Epoch 299/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 213.9082 - root_mean_squared_error: 14.5499
# Epoch 300/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 177.2368 - root_mean_squared_error: 13.1104
# Epoch 301/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 190.8324 - root_mean_squared_error: 13.7724
# Epoch 302/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 234.3535 - root_mean_squared_error: 15.2375
# Epoch 303/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 191.1040 - root_mean_squared_error: 13.6913
# Epoch 304/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 190.3712 - root_mean_squared_error: 13.6842
# Epoch 305/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 190.1330 - root_mean_squared_error: 13.7240
# Epoch 306/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 173.6020 - root_mean_squared_error: 13.0845
# Epoch 307/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 174.1774 - root_mean_squared_error: 13.1736
# Epoch 308/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 169.1503 - root_mean_squared_error: 12.9928
# Epoch 309/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 182.0114 - root_mean_squared_error: 13.4610
# Epoch 310/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 132.1779 - root_mean_squared_error: 11.3053
# Epoch 311/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 127.5336 - root_mean_squared_error: 11.1619
# Epoch 312/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 160.3806 - root_mean_squared_error: 12.6429
# Epoch 313/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 152.1508 - root_mean_squared_error: 12.3153
# Epoch 314/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 122.9528 - root_mean_squared_error: 11.0320
# Epoch 315/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 153.9096 - root_mean_squared_error: 12.3439
# Epoch 316/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 122.1316 - root_mean_squared_error: 11.0156
# Epoch 317/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 128.5133 - root_mean_squared_error: 11.2774
# Epoch 318/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 159.1616 - root_mean_squared_error: 12.5228
# Epoch 319/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 146.4347 - root_mean_squared_error: 11.9991
# Epoch 320/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 110.0610 - root_mean_squared_error: 10.4634
# Epoch 321/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 118.7016 - root_mean_squared_error: 10.8437
# Epoch 322/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 94.4616 - root_mean_squared_error: 9.6627
# Epoch 323/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 129.6355 - root_mean_squared_error: 11.3451
# Epoch 324/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 90.5370 - root_mean_squared_error: 9.4655
# Epoch 325/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 101.2751 - root_mean_squared_error: 10.0413
# Epoch 326/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 77.9406 - root_mean_squared_error: 8.7747
# Epoch 327/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 86.6316 - root_mean_squared_error: 9.2383
# Epoch 328/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 92.9762 - root_mean_squared_error: 9.6166
# Epoch 329/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 56.6344 - root_mean_squared_error: 7.4349
# Epoch 330/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 57.2031 - root_mean_squared_error: 7.3903
# Epoch 331/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 64.4863 - root_mean_squared_error: 7.8768
# Epoch 332/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 76.8282 - root_mean_squared_error: 8.6993
# Epoch 333/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 71.1591 - root_mean_squared_error: 8.4225
# Epoch 334/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 62.5186 - root_mean_squared_error: 7.8963
# Epoch 335/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 74.5203 - root_mean_squared_error: 8.5337
# Epoch 336/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 48.9998 - root_mean_squared_error: 6.8561
# Epoch 337/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 67.7674 - root_mean_squared_error: 8.2089
# Epoch 338/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 60.8304 - root_mean_squared_error: 7.7008
# Epoch 339/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 58.0926 - root_mean_squared_error: 7.5707
# Epoch 340/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 36.2376 - root_mean_squared_error: 5.8778
# Epoch 341/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 44.9644 - root_mean_squared_error: 6.6100
# Epoch 342/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 38.9170 - root_mean_squared_error: 6.1735
# Epoch 343/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 40.2218 - root_mean_squared_error: 6.3247
# Epoch 344/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 49.6629 - root_mean_squared_error: 7.0110
# Epoch 345/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 44.3272 - root_mean_squared_error: 6.6328
# Epoch 346/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 35.8323 - root_mean_squared_error: 5.9657
# Epoch 347/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 38.7181 - root_mean_squared_error: 6.2047
# Epoch 348/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 39.8996 - root_mean_squared_error: 6.2855
# Epoch 349/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 28.7519 - root_mean_squared_error: 5.2925
# Epoch 350/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 30.8796 - root_mean_squared_error: 5.5461
# Epoch 351/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 28.4238 - root_mean_squared_error: 5.2834
# Epoch 352/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 25.0245 - root_mean_squared_error: 4.9179
# Epoch 353/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 27.9196 - root_mean_squared_error: 5.2690
# Epoch 354/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 26.8219 - root_mean_squared_error: 5.1571
# Epoch 355/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 29.5317 - root_mean_squared_error: 5.4188
# Epoch 356/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 18.7602 - root_mean_squared_error: 4.1704
# Epoch 357/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 18.6630 - root_mean_squared_error: 4.2875
# Epoch 358/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 20.4842 - root_mean_squared_error: 4.4901
# Epoch 359/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 17.4326 - root_mean_squared_error: 4.1483
# Epoch 360/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 21.3750 - root_mean_squared_error: 4.5941
# Epoch 361/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - loss: 18.8887 - root_mean_squared_error: 4.3365
# Epoch 362/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 14.6412 - root_mean_squared_error: 3.7861
# Epoch 363/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 13.1875 - root_mean_squared_error: 3.5558
# Epoch 364/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 13.7888 - root_mean_squared_error: 3.6238
# Epoch 365/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 12.8842 - root_mean_squared_error: 3.5502
# Epoch 366/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 12.5620 - root_mean_squared_error: 3.5207
# Epoch 367/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 15.3042 - root_mean_squared_error: 3.8749
# Epoch 368/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 13.3499 - root_mean_squared_error: 3.6219
# Epoch 369/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 11.0145 - root_mean_squared_error: 3.3047
# Epoch 370/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 12.0387 - root_mean_squared_error: 3.4364
# Epoch 371/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 8.9152 - root_mean_squared_error: 2.9371
# Epoch 372/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 10.2997 - root_mean_squared_error: 3.1952
# Epoch 373/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 7.5075 - root_mean_squared_error: 2.6533
# Epoch 374/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 11.0043 - root_mean_squared_error: 3.2647
# Epoch 375/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 10.3920 - root_mean_squared_error: 3.2054
# Epoch 376/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 9.2103 - root_mean_squared_error: 3.0301
# Epoch 377/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 8.9505 - root_mean_squared_error: 2.9431
# Epoch 378/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 359us/step - loss: 6.8777 - root_mean_squared_error: 2.6077
# Epoch 379/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 8.8974 - root_mean_squared_error: 2.9429
# Epoch 380/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 7.3031 - root_mean_squared_error: 2.6943
# Epoch 381/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 7.3638 - root_mean_squared_error: 2.7019
# Epoch 382/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 5.8046 - root_mean_squared_error: 2.3862
# Epoch 383/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 6.3083 - root_mean_squared_error: 2.4710
# Epoch 384/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 6.8252 - root_mean_squared_error: 2.6065
# Epoch 385/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 6.9554 - root_mean_squared_error: 2.6302
# Epoch 386/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 5.6557 - root_mean_squared_error: 2.3739
# Epoch 387/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 5.7525 - root_mean_squared_error: 2.3831
# Epoch 388/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 6.3734 - root_mean_squared_error: 2.5080
# Epoch 389/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 6.0479 - root_mean_squared_error: 2.4447
# Epoch 390/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 5.5086 - root_mean_squared_error: 2.3407
# Epoch 391/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 5.8509 - root_mean_squared_error: 2.4126
# Epoch 392/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 5.0480 - root_mean_squared_error: 2.2437
# Epoch 393/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 4.7626 - root_mean_squared_error: 2.1698
# Epoch 394/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 5.0157 - root_mean_squared_error: 2.2345
# Epoch 395/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4.6604 - root_mean_squared_error: 2.1474
# Epoch 396/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 4.9196 - root_mean_squared_error: 2.2093
# Epoch 397/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 5.3441 - root_mean_squared_error: 2.3060
# Epoch 398/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 4.7956 - root_mean_squared_error: 2.1811
# Epoch 399/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 3.9960 - root_mean_squared_error: 1.9814
# Epoch 400/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 4.7991 - root_mean_squared_error: 2.1681
# Epoch 401/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 4.0071 - root_mean_squared_error: 1.9911
# Epoch 402/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 3.5698 - root_mean_squared_error: 1.8581
# Epoch 403/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 4.2009 - root_mean_squared_error: 2.0395
# Epoch 404/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 6.5752 - root_mean_squared_error: 2.5187
# Epoch 405/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 5.2255 - root_mean_squared_error: 2.2788
# Epoch 406/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 4.4435 - root_mean_squared_error: 2.1035
# Epoch 407/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 4.7531 - root_mean_squared_error: 2.1724
# Epoch 408/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 4.3668 - root_mean_squared_error: 2.0559
# Epoch 409/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 4.9246 - root_mean_squared_error: 2.2169
# Epoch 410/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 4.5611 - root_mean_squared_error: 2.1297
# Epoch 411/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 4.2352 - root_mean_squared_error: 2.0409
# Epoch 412/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 5.8901 - root_mean_squared_error: 2.3706
# Epoch 413/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 4.7153 - root_mean_squared_error: 2.1552
# Epoch 414/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4.5235 - root_mean_squared_error: 2.1105
# Epoch 415/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 4.4054 - root_mean_squared_error: 2.0798
# Epoch 416/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 4.5028 - root_mean_squared_error: 2.1186
# Epoch 417/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 5.2025 - root_mean_squared_error: 2.2615
# Epoch 418/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 3.0108 - root_mean_squared_error: 1.7149
# Epoch 419/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 6.0743 - root_mean_squared_error: 2.3982
# Epoch 420/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 4.2352 - root_mean_squared_error: 2.0445
# Epoch 421/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 4.2759 - root_mean_squared_error: 2.0592
# Epoch 422/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 3.8305 - root_mean_squared_error: 1.9542
# Epoch 423/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 4.1886 - root_mean_squared_error: 2.0378
# Epoch 424/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 4.0735 - root_mean_squared_error: 1.9986
# Epoch 425/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 3.2355 - root_mean_squared_error: 1.7615
# Epoch 426/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 5.0512 - root_mean_squared_error: 2.2409
# Epoch 427/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 3.3992 - root_mean_squared_error: 1.8362
# Epoch 428/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 3.0886 - root_mean_squared_error: 1.7345
# Epoch 429/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 4.2269 - root_mean_squared_error: 2.0436
# Epoch 430/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 4.6056 - root_mean_squared_error: 2.1330
# Epoch 431/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 5.7772 - root_mean_squared_error: 2.3808
# Epoch 432/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 4.3524 - root_mean_squared_error: 2.0727
# Epoch 433/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 3.7889 - root_mean_squared_error: 1.9379
# Epoch 434/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 3.6200 - root_mean_squared_error: 1.8897
# Epoch 435/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 3.7481 - root_mean_squared_error: 1.9253
# Epoch 436/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 4.3702 - root_mean_squared_error: 2.0863
# Epoch 437/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 3.6293 - root_mean_squared_error: 1.8793
# Epoch 438/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 4.9353 - root_mean_squared_error: 2.2058
# Epoch 439/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 5.4306 - root_mean_squared_error: 2.2979
# Epoch 440/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 4.0375 - root_mean_squared_error: 2.0031
# Epoch 441/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 4.4471 - root_mean_squared_error: 2.1054
# Epoch 442/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 3.6642 - root_mean_squared_error: 1.8903
# Epoch 443/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 3.8362 - root_mean_squared_error: 1.9494
# Epoch 444/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 4.0486 - root_mean_squared_error: 1.9953
# Epoch 445/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 4.1222 - root_mean_squared_error: 2.0211
# Epoch 446/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 4.2535 - root_mean_squared_error: 2.0586
# Epoch 447/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 3.5071 - root_mean_squared_error: 1.8628
# Epoch 448/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 3.7910 - root_mean_squared_error: 1.9391
# Epoch 449/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 3.7502 - root_mean_squared_error: 1.9165
# Epoch 450/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 4.2635 - root_mean_squared_error: 2.0386
# Epoch 451/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 4.0488 - root_mean_squared_error: 1.9921
# Epoch 452/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 4.4980 - root_mean_squared_error: 2.1152
# Epoch 453/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 4.4099 - root_mean_squared_error: 2.0938
# Epoch 454/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 4.4040 - root_mean_squared_error: 2.0720
# Epoch 455/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 3.3384 - root_mean_squared_error: 1.8129
# Epoch 456/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 4.4687 - root_mean_squared_error: 2.1077
# Epoch 457/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 4.1541 - root_mean_squared_error: 2.0264
# Epoch 458/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 3.7501 - root_mean_squared_error: 1.9306
# Epoch 459/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 7.1177 - root_mean_squared_error: 2.5881
# Epoch 460/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 4.1652 - root_mean_squared_error: 2.0337
# Epoch 461/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 3.2837 - root_mean_squared_error: 1.7812
# Epoch 462/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 4.5062 - root_mean_squared_error: 2.1127
# Epoch 463/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 3.8412 - root_mean_squared_error: 1.9548
# Epoch 464/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 3.4959 - root_mean_squared_error: 1.8231
# Epoch 465/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 3.9676 - root_mean_squared_error: 1.9767
# Epoch 466/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 5.2551 - root_mean_squared_error: 2.2827
# Epoch 467/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4.4194 - root_mean_squared_error: 2.0834
# Epoch 468/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 4.6606 - root_mean_squared_error: 2.1497
# Epoch 469/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 4.2980 - root_mean_squared_error: 2.0704
# Epoch 470/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 3.5917 - root_mean_squared_error: 1.8884
# Epoch 471/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 3.3082 - root_mean_squared_error: 1.8089
# Epoch 472/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 4.2530 - root_mean_squared_error: 2.0430
# Epoch 473/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 3.6663 - root_mean_squared_error: 1.8924
# Epoch 474/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 3.7549 - root_mean_squared_error: 1.9337
# Epoch 475/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 4.3369 - root_mean_squared_error: 2.0714
# Epoch 476/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 4.7413 - root_mean_squared_error: 2.1683
# Epoch 477/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 3.9448 - root_mean_squared_error: 1.9817
# Epoch 478/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 4.4060 - root_mean_squared_error: 2.0929
# Epoch 479/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 3.6962 - root_mean_squared_error: 1.9166
# Epoch 480/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 3.7681 - root_mean_squared_error: 1.9337
# Epoch 481/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 4.2298 - root_mean_squared_error: 2.0512
# Epoch 482/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 4.0553 - root_mean_squared_error: 2.0077
# Epoch 483/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 4.1004 - root_mean_squared_error: 2.0009
# Epoch 484/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step - loss: 3.6869 - root_mean_squared_error: 1.8797
# Epoch 485/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 3.5268 - root_mean_squared_error: 1.8696
# Epoch 486/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 3.5521 - root_mean_squared_error: 1.8761
# Epoch 487/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 3.4555 - root_mean_squared_error: 1.8460
# Epoch 488/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 3.1497 - root_mean_squared_error: 1.7541
# Epoch 489/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 2.9294 - root_mean_squared_error: 1.6628
# Epoch 490/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 4.5169 - root_mean_squared_error: 2.1228
# Epoch 491/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 3.2300 - root_mean_squared_error: 1.7879
# Epoch 492/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 4.3610 - root_mean_squared_error: 2.0784
# Epoch 493/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 3.8560 - root_mean_squared_error: 1.9255
# Epoch 494/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 4.3504 - root_mean_squared_error: 2.0632
# Epoch 495/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 5.3181 - root_mean_squared_error: 2.2985
# Epoch 496/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 3.7619 - root_mean_squared_error: 1.9274
# Epoch 497/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 3.8627 - root_mean_squared_error: 1.9570
# Epoch 498/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 4.3452 - root_mean_squared_error: 2.0805
# Epoch 499/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 3.9465 - root_mean_squared_error: 1.9770
# Epoch 500/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 4.7187 - root_mean_squared_error: 2.1649
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Mean squared error: 6.19
# Coefficient of determination: 1.00

# %%
y_surface = model.predict(X_surface)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 276us/step
