# %% [markdown]
# # Régression Linéaire
#
# [![Index](https://img.shields.io/badge/Index-blue)](../index.ipynb)
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/digillia/Digillia-Colab/blob/main/algorithms/linear-regression.ipynb)
#
# La régression est largement utilisée en statistiques et en science des données pour la modélisation, la prédiction et la compréhension des relations entre des variables, dans des domaines tels que l'économie, la biologie, la finance et bien d'autres.
#
# La régression linéaire permet de modéliser la relation entre une variable dépendante (ou cible) et plusieurs variables indépendantes (ou caractéristiques) en supposant une relation linéaire entre elles. L'objectif est de trouver un modèle linéaire qui minimise l'écart entre les valeurs prédites et les valeurs observées de la variable dépendante.
#
# En régression linéaire multivariée, l'équation prend la forme : $Y = b_0 + b_1X_1 + b_2X_2 + ... + b_nX_n$, où $Y$ représente la variable dépendante, $X_1, X_2, ..., X_n$ sont les variables indépendantes, et $b_0, b_1, b_2, ..., b_n$ sont les coefficients à estimer. Ces coefficients déterminent la contribution de chaque variable indépendante à la prédiction de la variable dépendante.
#
# [![Wikipedia](https://img.shields.io/badge/Wikipedia-lightgrey)](https://en.wikipedia.org/wiki/Linear_regression)

# %%
# Supprimer les commentaires pour installer (requirements.txt)
# !pip3 install -q -U numpy
# !pip3 install -q -U pandas
# !pip3 install -q -U matplotlib
# !pip3 install -q -U scipy
# !pip3 install -q -U statsmodels
# !pip3 install -q -U scikit-learn
# !pip3 install -q -U "jax[cpu]"
# !pip3 install -q -U torch
# !pip3 install -q -U tensorflow

# %% [markdown]
# ## Données
#
# Création d'un jeu de données synthétiques:

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

random_state = 42

# Create features and labels
X, y = make_regression(n_samples=100, n_features=2, n_targets=1, noise=2.0, random_state=random_state)

# Create training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# Check shapes
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (80, 2) (20, 2) (80,) (20,)

# %% [markdown]
# Visualisation:

# %%
from matplotlib import pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='train')
ax.scatter(X_test[:,0], X_test[:,1], y_test, marker='o', c='b', label='test')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
plt.show()

# %% [markdown]
# Autres données pour visualisation 3D du plan de regression linéaire:

# %%
import numpy as np

# Data for 3D visualization
x1_range = np.linspace(min(X[:, 0]), max(X[:, 0]), 40)
x2_range = np.linspace(min(X[:, 1]), max(X[:, 1]), 40)
x1_values, x2_values = np.meshgrid(x1_range, x2_range)
X_surface = np.column_stack((x1_values.ravel(), x2_values.ravel()))
X_surface
# Out:
# array([[-2.6197451 , -1.98756891],
#        [-2.50420841, -1.98756891],
#        [-2.38867172, -1.98756891],
#        ...,
#        [ 1.65511252,  2.72016917],
#        [ 1.77064921,  2.72016917],
#        [ 1.8861859 ,  2.72016917]])

# %% [markdown]
# ## Régression Linéaire Univariée avec SciPy
#
# > SciPy ne supporte pas la régression multivariée
#
# Docs: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
from scipy.stats import linregress

# linregress du package SciPy ne supporte pas la régression multivariée
# result = linregress(X_train, y_train)

# Deux regressions univariées comme ci-dessous, ne sont pas équivalentes à une regression multivariée (plan multidimensionnel).
# La suite permet seulement d'illustrer un exemple de régression univariée (droite dans un plan).

result0 = linregress(X_train[:,0], y_train)
print(result0)

result1 = linregress(X_train[:,1], y_train)
print(result1)
# Out:
# LinregressResult(slope=92.98819197619855, intercept=1.2854225462278386, rvalue=0.7470341322548784, pvalue=1.7625012111659255e-15, stderr=9.36961433426038, intercept_stderr=8.255903002280556)
# LinregressResult(slope=79.2081101654435, intercept=-12.081646660054606, rvalue=0.712919955648751, pvalue=1.1863604632825639e-13, stderr=8.821686410245587, intercept_stderr=8.601605235688808)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
ax1.scatter(X_train[:,0], y_train, c='r', alpha=0.5)
ax1.plot(X_test[:,0], result0.slope * X_test[:,0] + result0.intercept, c='b', alpha=0.5)
ax1.set(title='Feature 1', xlabel='X1', ylabel='y')
ax2.scatter(X_train[:,1], y_train, c='r', alpha=0.5)
ax2.plot(X_test[:,1], result1.slope * X_test[:,1] + result1.intercept, c='b', alpha=0.5)
ax2.set(title='Feature 2', xlabel='X2', ylabel='y')
plt.show()

# %% [markdown]
# # Régression Linéaire Multivariée avec StatsModels
#
# Docs: https://www.statsmodels.org/dev/generated/statsmodels.regression.linear_model.OLS.html

# %%
import statsmodels.api as sm

# Add constant for intercept
X_train_ = sm.add_constant(X_train)
X_test_ = sm.add_constant(X_test)

# Train and predict
model = sm.OLS(y_train, X_train_).fit()
y_pred = model.predict(X_test_) 

# Show summary
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.070e+05
# Date:                Wed, 10 Apr 2024   Prob (F-statistic):          2.49e-133
# Time:                        08:49:49   Log-Likelihood:                -171.10
# No. Observations:                  80   AIC:                             348.2
# Df Residuals:                      77   BIC:                             355.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0132      0.237      0.056      0.956      -0.459       0.485
# x1            87.4519      0.270    324.398      0.000      86.915      87.989
# x2            73.9953      0.241    307.519      0.000      73.516      74.474
# ==============================================================================
# Omnibus:                        4.408   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                3.662
# Skew:                           0.412   Prob(JB):                        0.160
# Kurtosis:                       3.649   Cond. No.                         1.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_surface_ = sm.add_constant(X_surface)
y_surface = model.predict(X_surface_)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec SciKit-Learn
#
# Docs: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
from sklearn.linear_model import LinearRegression

# Fit the regressor
model = LinearRegression().fit(X_train, y_train)
print(model.coef_, model.intercept_)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# [87.45188282 73.99534523] 0.013190960728636014
# Mean squared error: 6.19
# Coefficient of determination: 1.00

# %%
y_surface = model.predict(X_surface)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec Jax
#
# Docs: https://jax.readthedocs.io/en/latest/

# %%
from jax import grad, jit
import jax.numpy as jnp

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

# Loss function based on mean squared error (mse)
def loss(w,b,X,y):
  pred = X.dot(w) + b
  return ((pred-y)**2).mean()

# Initialize weights with zeros
Weights = jnp.zeros((X_train.shape[1],1))
bias = 0.

# Learning rate and epochs
l_rate = 0.01
n_iter = 3000

# Gradient functions wrapped with jit function for faster processing
gradW = jit(grad(loss, argnums=0))
gradb = jit(grad(loss, argnums=1))

# Training loop
for _ in range(n_iter):
  dW = gradW(Weights, bias, X_train, y_train_)
  db = gradb(Weights, bias, X_train, y_train_)
  # print(loss(Weights, bias, X_train, y_train_))
  Weights -= dW * l_rate
  bias -= db * l_rate

print(Weights, bias)

# Predictions
y_pred = X_test.dot(Weights) + bias

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# [[87.45162]
#  [73.99556]] 0.0131549835
# Mean squared error: 6.18
# Coefficient of determination: 1.00

# %%
y_surface = X_surface.dot(Weights) + bias
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec PyTorch
#
# Docs: https://pytorch.org/docs/stable/index.html

# %%
import torch
from torch.autograd import Variable

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

class TorchLR(torch.nn.Module):
    def __init__(self, inputSize, outputSize):
        super(TorchLR, self).__init__()
        self.linear = torch.nn.Linear(inputSize, outputSize, dtype=torch.float64)

    def forward(self, x):
        out = self.linear(x)
        return out
    
# Learning rate and epochs
l_rate = 0.001 
n_iter = 3000

inputDim = X.shape[1]   # takes variable 'x' 
outputDim = 1  # takes variable 'y'
model = TorchLR(inputDim, outputDim)
if torch.cuda.is_available():
    model.cuda()

criterion = torch.nn.MSELoss() 
optimizer = torch.optim.SGD(model.parameters(), lr=l_rate)

# Training loop
for epoch in range(n_iter):
    # Converting inputs and labels to Variable
    if torch.cuda.is_available():
        inputs = Variable(torch.from_numpy(X_train).cuda())
        labels = Variable(torch.from_numpy(y_train_).cuda())
    else:
        inputs = Variable(torch.from_numpy(X_train))
        labels = Variable(torch.from_numpy(y_train_))

    print(inputs.dtype, labels.dtype) 

    # Clear gradient buffers because we don't want any gradient from previous epoch to carry forward, dont want to cummulate gradients
    optimizer.zero_grad()

    # get output from the model, given the inputs
    outputs = model(inputs)

    # get loss for the predicted output
    loss = criterion(outputs, labels)
    
    # get gradients w.r.t to parameters
    loss.backward()

    # update parameters
    optimizer.step()

    print('epoch {}, loss {}'.format(epoch, loss.item()))

# Predictions
with torch.no_grad(): # we don't need gradients in the testing phase
    if torch.cuda.is_available():
        y_pred = model(Variable(torch.from_numpy(X_test).cuda())).cpu().data.numpy()
    else:
        y_pred = model(Variable(torch.from_numpy(X_test))).data.numpy()

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# /Users/jlchereau/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# torch.float64 torch.float64
# epoch 0, loss 11960.585895083033
# torch.float64 torch.float64
# epoch 1, loss 11916.385655726062
# torch.float64 torch.float64
# epoch 2, loss 11872.352072105647
# torch.float64 torch.float64
# epoch 3, loss 11828.484505519196
# torch.float64 torch.float64
# epoch 4, loss 11784.78231974463
# torch.float64 torch.float64
# epoch 5, loss 11741.244881030641
# torch.float64 torch.float64
# epoch 6, loss 11697.871558086987
# torch.float64 torch.float64
# epoch 7, loss 11654.661722074847
# torch.float64 torch.float64
# epoch 8, loss 11611.614746597177
# torch.float64 torch.float64
# epoch 9, loss 11568.730007689144
# torch.float64 torch.float64
# epoch 10, loss 11526.006883808572
# torch.float64 torch.float64
# epoch 11, loss 11483.444755826433
# torch.float64 torch.float64
# epoch 12, loss 11441.04300701738
# torch.float64 torch.float64
# epoch 13, loss 11398.80102305031
# torch.float64 torch.float64
# epoch 14, loss 11356.718191978975
# torch.float64 torch.float64
# epoch 15, loss 11314.793904232607
# torch.float64 torch.float64
# epoch 16, loss 11273.027552606616
# torch.float64 torch.float64
# epoch 17, loss 11231.418532253298
# torch.float64 torch.float64
# epoch 18, loss 11189.96624067258
# torch.float64 torch.float64
# epoch 19, loss 11148.670077702813
# torch.float64 torch.float64
# epoch 20, loss 11107.529445511605
# torch.float64 torch.float64
# epoch 21, loss 11066.543748586671
# torch.float64 torch.float64
# epoch 22, loss 11025.712393726737
# torch.float64 torch.float64
# epoch 23, loss 10985.034790032467
# torch.float64 torch.float64
# epoch 24, loss 10944.510348897447
# torch.float64 torch.float64
# epoch 25, loss 10904.13848399917
# torch.float64 torch.float64
# epoch 26, loss 10863.91861129009
# torch.float64 torch.float64
# epoch 27, loss 10823.850148988702
# torch.float64 torch.float64
# epoch 28, loss 10783.932517570636
# torch.float64 torch.float64
# epoch 29, loss 10744.165139759822
# torch.float64 torch.float64
# epoch 30, loss 10704.547440519664
# torch.float64 torch.float64
# epoch 31, loss 10665.078847044255
# torch.float64 torch.float64
# epoch 32, loss 10625.75878874963
# torch.float64 torch.float64
# epoch 33, loss 10586.58669726506
# torch.float64 torch.float64
# epoch 34, loss 10547.56200642435
# torch.float64 torch.float64
# epoch 35, loss 10508.684152257225
# torch.float64 torch.float64
# epoch 36, loss 10469.952572980692
# torch.float64 torch.float64
# epoch 37, loss 10431.366708990481
# torch.float64 torch.float64
# epoch 38, loss 10392.926002852491
# torch.float64 torch.float64
# epoch 39, loss 10354.62989929429
# torch.float64 torch.float64
# epoch 40, loss 10316.477845196625
# torch.float64 torch.float64
# epoch 41, loss 10278.469289585004
# torch.float64 torch.float64
# epoch 42, loss 10240.60368362126
# torch.float64 torch.float64
# epoch 43, loss 10202.880480595195
# torch.float64 torch.float64
# epoch 44, loss 10165.299135916232
# torch.float64 torch.float64
# epoch 45, loss 10127.859107105105
# torch.float64 torch.float64
# epoch 46, loss 10090.55985378558
# torch.float64 torch.float64
# epoch 47, loss 10053.400837676225
# torch.float64 torch.float64
# epoch 48, loss 10016.381522582175
# torch.float64 torch.float64
# epoch 49, loss 9979.501374386973
# torch.float64 torch.float64
# epoch 50, loss 9942.759861044426
# torch.float64 torch.float64
# epoch 51, loss 9906.156452570469
# torch.float64 torch.float64
# epoch 52, loss 9869.69062103511
# torch.float64 torch.float64
# epoch 53, loss 9833.361840554358
# torch.float64 torch.float64
# epoch 54, loss 9797.169587282227
# torch.float64 torch.float64
# epoch 55, loss 9761.113339402722
# torch.float64 torch.float64
# epoch 56, loss 9725.19257712191
# torch.float64 torch.float64
# epoch 57, loss 9689.406782659982
# torch.float64 torch.float64
# epoch 58, loss 9653.75544024337
# torch.float64 torch.float64
# epoch 59, loss 9618.238036096876
# torch.float64 torch.float64
# epoch 60, loss 9582.854058435847
# torch.float64 torch.float64
# epoch 61, loss 9547.602997458387
# torch.float64 torch.float64
# epoch 62, loss 9512.484345337565
# torch.float64 torch.float64
# epoch 63, loss 9477.497596213705
# torch.float64 torch.float64
# epoch 64, loss 9442.642246186657
# torch.float64 torch.float64
# epoch 65, loss 9407.917793308136
# torch.float64 torch.float64
# epoch 66, loss 9373.32373757407
# torch.float64 torch.float64
# epoch 67, loss 9338.859580916984
# torch.float64 torch.float64
# epoch 68, loss 9304.524827198413
# torch.float64 torch.float64
# epoch 69, loss 9270.318982201356
# torch.float64 torch.float64
# epoch 70, loss 9236.24155362273
# torch.float64 torch.float64
# epoch 71, loss 9202.292051065908
# torch.float64 torch.float64
# epoch 72, loss 9168.469986033215
# torch.float64 torch.float64
# epoch 73, loss 9134.774871918518
# torch.float64 torch.float64
# epoch 74, loss 9101.206223999803
# torch.float64 torch.float64
# epoch 75, loss 9067.763559431809
# torch.float64 torch.float64
# epoch 76, loss 9034.446397238667
# torch.float64 torch.float64
# epoch 77, loss 9001.254258306595
# torch.float64 torch.float64
# epoch 78, loss 8968.186665376592
# torch.float64 torch.float64
# epoch 79, loss 8935.243143037185
# torch.float64 torch.float64
# epoch 80, loss 8902.423217717193
# torch.float64 torch.float64
# epoch 81, loss 8869.726417678517
# torch.float64 torch.float64
# epoch 82, loss 8837.15227300898
# torch.float64 torch.float64
# epoch 83, loss 8804.700315615159
# torch.float64 torch.float64
# epoch 84, loss 8772.37007921527
# torch.float64 torch.float64
# epoch 85, loss 8740.161099332097
# torch.float64 torch.float64
# epoch 86, loss 8708.072913285894
# torch.float64 torch.float64
# epoch 87, loss 8676.105060187378
# torch.float64 torch.float64
# epoch 88, loss 8644.257080930702
# torch.float64 torch.float64
# epoch 89, loss 8612.528518186491
# torch.float64 torch.float64
# epoch 90, loss 8580.918916394876
# torch.float64 torch.float64
# epoch 91, loss 8549.427821758572
# torch.float64 torch.float64
# epoch 92, loss 8518.054782235988
# torch.float64 torch.float64
# epoch 93, loss 8486.799347534345
# torch.float64 torch.float64
# epoch 94, loss 8455.661069102844
# torch.float64 torch.float64
# epoch 95, loss 8424.639500125835
# torch.float64 torch.float64
# epoch 96, loss 8393.734195516043
# torch.float64 torch.float64
# epoch 97, loss 8362.944711907796
# torch.float64 torch.float64
# epoch 98, loss 8332.27060765029
# torch.float64 torch.float64
# epoch 99, loss 8301.711442800883
# torch.float64 torch.float64
# epoch 100, loss 8271.266779118405
# torch.float64 torch.float64
# epoch 101, loss 8240.936180056515
# torch.float64 torch.float64
# epoch 102, loss 8210.719210757055
# torch.float64 torch.float64
# epoch 103, loss 8180.615438043455
# torch.float64 torch.float64
# epoch 104, loss 8150.624430414154
# torch.float64 torch.float64
# epoch 105, loss 8120.745758036047
# torch.float64 torch.float64
# epoch 106, loss 8090.978992737956
# torch.float64 torch.float64
# epoch 107, loss 8061.323708004138
# torch.float64 torch.float64
# epoch 108, loss 8031.779478967803
# torch.float64 torch.float64
# epoch 109, loss 8002.345882404663
# torch.float64 torch.float64
# epoch 110, loss 7973.022496726514
# torch.float64 torch.float64
# epoch 111, loss 7943.808901974841
# torch.float64 torch.float64
# epoch 112, loss 7914.704679814432
# torch.float64 torch.float64
# epoch 113, loss 7885.709413527045
# torch.float64 torch.float64
# epoch 114, loss 7856.8226880050715
# torch.float64 torch.float64
# epoch 115, loss 7828.044089745245
# torch.float64 torch.float64
# epoch 116, loss 7799.373206842376
# torch.float64 torch.float64
# epoch 117, loss 7770.809628983089
# torch.float64 torch.float64
# epoch 118, loss 7742.352947439608
# torch.float64 torch.float64
# epoch 119, loss 7714.002755063554
# torch.float64 torch.float64
# epoch 120, loss 7685.758646279772
# torch.float64 torch.float64
# epoch 121, loss 7657.620217080179
# torch.float64 torch.float64
# epoch 122, loss 7629.587065017642
# torch.float64 torch.float64
# epoch 123, loss 7601.658789199873
# torch.float64 torch.float64
# epoch 124, loss 7573.834990283351
# torch.float64 torch.float64
# epoch 125, loss 7546.115270467269
# torch.float64 torch.float64
# epoch 126, loss 7518.499233487503
# torch.float64 torch.float64
# epoch 127, loss 7490.986484610612
# torch.float64 torch.float64
# epoch 128, loss 7463.576630627848
# torch.float64 torch.float64
# epoch 129, loss 7436.269279849202
# torch.float64 torch.float64
# epoch 130, loss 7409.064042097464
# torch.float64 torch.float64
# epoch 131, loss 7381.960528702315
# torch.float64 torch.float64
# epoch 132, loss 7354.958352494441
# torch.float64 torch.float64
# epoch 133, loss 7328.057127799662
# torch.float64 torch.float64
# epoch 134, loss 7301.2564704330925
# torch.float64 torch.float64
# epoch 135, loss 7274.555997693325
# torch.float64 torch.float64
# epoch 136, loss 7247.955328356629
# torch.float64 torch.float64
# epoch 137, loss 7221.454082671179
# torch.float64 torch.float64
# epoch 138, loss 7195.051882351305
# torch.float64 torch.float64
# epoch 139, loss 7168.74835057177
# torch.float64 torch.float64
# epoch 140, loss 7142.543111962055
# torch.float64 torch.float64
# epoch 141, loss 7116.4357926006805
# torch.float64 torch.float64
# epoch 142, loss 7090.426020009548
# torch.float64 torch.float64
# epoch 143, loss 7064.513423148304
# torch.float64 torch.float64
# epoch 144, loss 7038.697632408715
# torch.float64 torch.float64
# epoch 145, loss 7012.978279609085
# torch.float64 torch.float64
# epoch 146, loss 6987.354997988671
# torch.float64 torch.float64
# epoch 147, loss 6961.827422202155
# torch.float64 torch.float64
# epoch 148, loss 6936.395188314089
# torch.float64 torch.float64
# epoch 149, loss 6911.057933793409
# torch.float64 torch.float64
# epoch 150, loss 6885.815297507946
# torch.float64 torch.float64
# epoch 151, loss 6860.666919718957
# torch.float64 torch.float64
# epoch 152, loss 6835.612442075694
# torch.float64 torch.float64
# epoch 153, loss 6810.651507609978
# torch.float64 torch.float64
# epoch 154, loss 6785.7837607308
# torch.float64 torch.float64
# epoch 155, loss 6761.008847218953
# torch.float64 torch.float64
# epoch 156, loss 6736.326414221659
# torch.float64 torch.float64
# epoch 157, loss 6711.736110247255
# torch.float64 torch.float64
# epoch 158, loss 6687.237585159867
# torch.float64 torch.float64
# epoch 159, loss 6662.830490174117
# torch.float64 torch.float64
# epoch 160, loss 6638.514477849855
# torch.float64 torch.float64
# epoch 161, loss 6614.289202086909
# torch.float64 torch.float64
# epoch 162, loss 6590.154318119856
# torch.float64 torch.float64
# epoch 163, loss 6566.109482512804
# torch.float64 torch.float64
# epoch 164, loss 6542.1543531542075
# torch.float64 torch.float64
# epoch 165, loss 6518.288589251702
# torch.float64 torch.float64
# epoch 166, loss 6494.511851326957
# torch.float64 torch.float64
# epoch 167, loss 6470.823801210538
# torch.float64 torch.float64
# epoch 168, loss 6447.224102036805
# torch.float64 torch.float64
# epoch 169, loss 6423.712418238831
# torch.float64 torch.float64
# epoch 170, loss 6400.28841554332
# torch.float64 torch.float64
# epoch 171, loss 6376.951760965574
# torch.float64 torch.float64
# epoch 172, loss 6353.702122804454
# torch.float64 torch.float64
# epoch 173, loss 6330.53917063738
# torch.float64 torch.float64
# epoch 174, loss 6307.462575315336
# torch.float64 torch.float64
# epoch 175, loss 6284.47200895791
# torch.float64 torch.float64
# epoch 176, loss 6261.567144948332
# torch.float64 torch.float64
# epoch 177, loss 6238.74765792856
# torch.float64 torch.float64
# epoch 178, loss 6216.013223794359
# torch.float64 torch.float64
# epoch 179, loss 6193.36351969041
# torch.float64 torch.float64
# epoch 180, loss 6170.798224005448
# torch.float64 torch.float64
# epoch 181, loss 6148.317016367401
# torch.float64 torch.float64
# epoch 182, loss 6125.919577638559
# torch.float64 torch.float64
# epoch 183, loss 6103.60558991076
# torch.float64 torch.float64
# epoch 184, loss 6081.374736500597
# torch.float64 torch.float64
# epoch 185, loss 6059.226701944637
# torch.float64 torch.float64
# epoch 186, loss 6037.161171994671
# torch.float64 torch.float64
# epoch 187, loss 6015.1778336129655
# torch.float64 torch.float64
# epoch 188, loss 5993.276374967551
# torch.float64 torch.float64
# epoch 189, loss 5971.456485427515
# torch.float64 torch.float64
# epoch 190, loss 5949.717855558322
# torch.float64 torch.float64
# epoch 191, loss 5928.06017711715
# torch.float64 torch.float64
# epoch 192, loss 5906.483143048235
# torch.float64 torch.float64
# epoch 193, loss 5884.9864474782635
# torch.float64 torch.float64
# epoch 194, loss 5863.569785711736
# torch.float64 torch.float64
# epoch 195, loss 5842.232854226397
# torch.float64 torch.float64
# epoch 196, loss 5820.975350668654
# torch.float64 torch.float64
# epoch 197, loss 5799.796973849017
# torch.float64 torch.float64
# epoch 198, loss 5778.697423737572
# torch.float64 torch.float64
# epoch 199, loss 5757.676401459451
# torch.float64 torch.float64
# epoch 200, loss 5736.733609290337
# torch.float64 torch.float64
# epoch 201, loss 5715.868750651976
# torch.float64 torch.float64
# epoch 202, loss 5695.081530107714
# torch.float64 torch.float64
# epoch 203, loss 5674.37165335804
# torch.float64 torch.float64
# epoch 204, loss 5653.73882723617
# torch.float64 torch.float64
# epoch 205, loss 5633.182759703617
# torch.float64 torch.float64
# epoch 206, loss 5612.703159845803
# torch.float64 torch.float64
# epoch 207, loss 5592.299737867678
# torch.float64 torch.float64
# epoch 208, loss 5571.97220508936
# torch.float64 torch.float64
# epoch 209, loss 5551.720273941784
# torch.float64 torch.float64
# epoch 210, loss 5531.543657962382
# torch.float64 torch.float64
# epoch 211, loss 5511.442071790766
# torch.float64 torch.float64
# epoch 212, loss 5491.415231164439
# torch.float64 torch.float64
# epoch 213, loss 5471.4628529145175
# torch.float64 torch.float64
# epoch 214, loss 5451.584654961465
# torch.float64 torch.float64
# epoch 215, loss 5431.780356310857
# torch.float64 torch.float64
# epoch 216, loss 5412.049677049153
# torch.float64 torch.float64
# epoch 217, loss 5392.39233833948
# torch.float64 torch.float64
# epoch 218, loss 5372.808062417449
# torch.float64 torch.float64
# epoch 219, loss 5353.296572586968
# torch.float64 torch.float64
# epoch 220, loss 5333.857593216092
# torch.float64 torch.float64
# epoch 221, loss 5314.490849732871
# torch.float64 torch.float64
# epoch 222, loss 5295.1960686212215
# torch.float64 torch.float64
# epoch 223, loss 5275.972977416824
# torch.float64 torch.float64
# epoch 224, loss 5256.821304703018
# torch.float64 torch.float64
# epoch 225, loss 5237.7407801067275
# torch.float64 torch.float64
# epoch 226, loss 5218.731134294398
# torch.float64 torch.float64
# epoch 227, loss 5199.792098967948
# torch.float64 torch.float64
# epoch 228, loss 5180.923406860735
# torch.float64 torch.float64
# epoch 229, loss 5162.124791733548
# torch.float64 torch.float64
# epoch 230, loss 5143.3959883705975
# torch.float64 torch.float64
# epoch 231, loss 5124.73673257554
# torch.float64 torch.float64
# epoch 232, loss 5106.146761167506
# torch.float64 torch.float64
# epoch 233, loss 5087.625811977147
# torch.float64 torch.float64
# epoch 234, loss 5069.173623842702
# torch.float64 torch.float64
# epoch 235, loss 5050.789936606071
# torch.float64 torch.float64
# epoch 236, loss 5032.474491108909
# torch.float64 torch.float64
# epoch 237, loss 5014.227029188741
# torch.float64 torch.float64
# epoch 238, loss 4996.04729367508
# torch.float64 torch.float64
# epoch 239, loss 4977.935028385572
# torch.float64 torch.float64
# epoch 240, loss 4959.889978122144
# torch.float64 torch.float64
# epoch 241, loss 4941.911888667183
# torch.float64 torch.float64
# epoch 242, loss 4924.00050677971
# torch.float64 torch.float64
# epoch 243, loss 4906.155580191592
# torch.float64 torch.float64
# epoch 244, loss 4888.376857603749
# torch.float64 torch.float64
# epoch 245, loss 4870.664088682385
# torch.float64 torch.float64
# epoch 246, loss 4853.017024055234
# torch.float64 torch.float64
# epoch 247, loss 4835.435415307819
# torch.float64 torch.float64
# epoch 248, loss 4817.9190149797305
# torch.float64 torch.float64
# epoch 249, loss 4800.467576560904
# torch.float64 torch.float64
# epoch 250, loss 4783.080854487931
# torch.float64 torch.float64
# epoch 251, loss 4765.758604140385
# torch.float64 torch.float64
# epoch 252, loss 4748.500581837134
# torch.float64 torch.float64
# epoch 253, loss 4731.306544832705
# torch.float64 torch.float64
# epoch 254, loss 4714.176251313636
# torch.float64 torch.float64
# epoch 255, loss 4697.109460394857
# torch.float64 torch.float64
# epoch 256, loss 4680.105932116074
# torch.float64 torch.float64
# epoch 257, loss 4663.165427438172
# torch.float64 torch.float64
# epoch 258, loss 4646.287708239643
# torch.float64 torch.float64
# epoch 259, loss 4629.47253731301
# torch.float64 torch.float64
# epoch 260, loss 4612.719678361273
# torch.float64 torch.float64
# epoch 261, loss 4596.028895994368
# torch.float64 torch.float64
# epoch 262, loss 4579.399955725651
# torch.float64 torch.float64
# epoch 263, loss 4562.832623968373
# torch.float64 torch.float64
# epoch 264, loss 4546.326668032188
# torch.float64 torch.float64
# epoch 265, loss 4529.881856119665
# torch.float64 torch.float64
# epoch 266, loss 4513.497957322827
# torch.float64 torch.float64
# epoch 267, loss 4497.174741619678
# torch.float64 torch.float64
# epoch 268, loss 4480.911979870771
# torch.float64 torch.float64
# epoch 269, loss 4464.709443815773
# torch.float64 torch.float64
# epoch 270, loss 4448.566906070051
# torch.float64 torch.float64
# epoch 271, loss 4432.484140121265
# torch.float64 torch.float64
# epoch 272, loss 4416.460920325982
# torch.float64 torch.float64
# epoch 273, loss 4400.497021906296
# torch.float64 torch.float64
# epoch 274, loss 4384.592220946467
# torch.float64 torch.float64
# epoch 275, loss 4368.746294389568
# torch.float64 torch.float64
# epoch 276, loss 4352.959020034152
# torch.float64 torch.float64
# epoch 277, loss 4337.230176530925
# torch.float64 torch.float64
# epoch 278, loss 4321.559543379435
# torch.float64 torch.float64
# epoch 279, loss 4305.946900924777
# torch.float64 torch.float64
# epoch 280, loss 4290.392030354304
# torch.float64 torch.float64
# epoch 281, loss 4274.894713694361
# torch.float64 torch.float64
# epoch 282, loss 4259.454733807017
# torch.float64 torch.float64
# epoch 283, loss 4244.071874386826
# torch.float64 torch.float64
# epoch 284, loss 4228.7459199575915
# torch.float64 torch.float64
# epoch 285, loss 4213.476655869146
# torch.float64 torch.float64
# epoch 286, loss 4198.263868294139
# torch.float64 torch.float64
# epoch 287, loss 4183.1073442248435
# torch.float64 torch.float64
# epoch 288, loss 4168.006871469979
# torch.float64 torch.float64
# epoch 289, loss 4152.962238651528
# torch.float64 torch.float64
# epoch 290, loss 4137.97323520159
# torch.float64 torch.float64
# epoch 291, loss 4123.039651359227
# torch.float64 torch.float64
# epoch 292, loss 4108.161278167337
# torch.float64 torch.float64
# epoch 293, loss 4093.3379074695267
# torch.float64 torch.float64
# epoch 294, loss 4078.5693319070074
# torch.float64 torch.float64
# epoch 295, loss 4063.8553449154947
# torch.float64 torch.float64
# epoch 296, loss 4049.195740722127
# torch.float64 torch.float64
# epoch 297, loss 4034.5903143423884
# torch.float64 torch.float64
# epoch 298, loss 4020.038861577055
# torch.float64 torch.float64
# epoch 299, loss 4005.54117900914
# torch.float64 torch.float64
# epoch 300, loss 3991.0970640008613
# torch.float64 torch.float64
# epoch 301, loss 3976.7063146906157
# torch.float64 torch.float64
# epoch 302, loss 3962.368729989964
# torch.float64 torch.float64
# epoch 303, loss 3948.084109580637
# torch.float64 torch.float64
# epoch 304, loss 3933.8522539115356
# torch.float64 torch.float64
# epoch 305, loss 3919.6729641957654
# torch.float64 torch.float64
# epoch 306, loss 3905.546042407662
# torch.float64 torch.float64
# epoch 307, loss 3891.4712912798386
# torch.float64 torch.float64
# epoch 308, loss 3877.4485143002516
# torch.float64 torch.float64
# epoch 309, loss 3863.4775157092563
# torch.float64 torch.float64
# epoch 310, loss 3849.558100496696
# torch.float64 torch.float64
# epoch 311, loss 3835.690074398996
# torch.float64 torch.float64
# epoch 312, loss 3821.87324389626
# torch.float64 torch.float64
# epoch 313, loss 3808.107416209389
# torch.float64 torch.float64
# epoch 314, loss 3794.3923992972072
# torch.float64 torch.float64
# epoch 315, loss 3780.7280018535967
# torch.float64 torch.float64
# epoch 316, loss 3767.114033304654
# torch.float64 torch.float64
# epoch 317, loss 3753.5503038058378
# torch.float64 torch.float64
# epoch 318, loss 3740.036624239149
# torch.float64 torch.float64
# epoch 319, loss 3726.5728062103117
# torch.float64 torch.float64
# epoch 320, loss 3713.1586620459616
# torch.float64 torch.float64
# epoch 321, loss 3699.7940047908546
# torch.float64 torch.float64
# epoch 322, loss 3686.478648205078
# torch.float64 torch.float64
# epoch 323, loss 3673.212406761283
# torch.float64 torch.float64
# epoch 324, loss 3659.995095641914
# torch.float64 torch.float64
# epoch 325, loss 3646.82653073646
# torch.float64 torch.float64
# epoch 326, loss 3633.706528638713
# torch.float64 torch.float64
# epoch 327, loss 3620.6349066440366
# torch.float64 torch.float64
# epoch 328, loss 3607.6114827466454
# torch.float64 torch.float64
# epoch 329, loss 3594.636075636897
# torch.float64 torch.float64
# epoch 330, loss 3581.708504698593
# torch.float64 torch.float64
# epoch 331, loss 3568.8285900062897
# torch.float64 torch.float64
# epoch 332, loss 3555.996152322618
# torch.float64 torch.float64
# epoch 333, loss 3543.2110130956244
# torch.float64 torch.float64
# epoch 334, loss 3530.472994456103
# torch.float64 torch.float64
# epoch 335, loss 3517.781919214962
# torch.float64 torch.float64
# epoch 336, loss 3505.1376108605737
# torch.float64 torch.float64
# epoch 337, loss 3492.5398935561598
# torch.float64 torch.float64
# epoch 338, loss 3479.9885921371724
# torch.float64 torch.float64
# epoch 339, loss 3467.4835321086875
# torch.float64 torch.float64
# epoch 340, loss 3455.02453964281
# torch.float64 torch.float64
# epoch 341, loss 3442.6114415760953
# torch.float64 torch.float64
# epoch 342, loss 3430.2440654069624
# torch.float64 torch.float64
# epoch 343, loss 3417.9222392931406
# torch.float64 torch.float64
# epoch 344, loss 3405.645792049113
# torch.float64 torch.float64
# epoch 345, loss 3393.4145531435643
# torch.float64 torch.float64
# epoch 346, loss 3381.2283526968595
# torch.float64 torch.float64
# epoch 347, loss 3369.087021478505
# torch.float64 torch.float64
# epoch 348, loss 3356.990390904645
# torch.float64 torch.float64
# epoch 349, loss 3344.938293035551
# torch.float64 torch.float64
# epoch 350, loss 3332.930560573128
# torch.float64 torch.float64
# epoch 351, loss 3320.9670268584314
# torch.float64 torch.float64
# epoch 352, loss 3309.0475258691863
# torch.float64 torch.float64
# epoch 353, loss 3297.1718922173263
# torch.float64 torch.float64
# epoch 354, loss 3285.3399611465393
# torch.float64 torch.float64
# epoch 355, loss 3273.5515685298133
# torch.float64 torch.float64
# epoch 356, loss 3261.806550867005
# torch.float64 torch.float64
# epoch 357, loss 3250.104745282413
# torch.float64 torch.float64
# epoch 358, loss 3238.4459895223563
# torch.float64 torch.float64
# epoch 359, loss 3226.8301219527675
# torch.float64 torch.float64
# epoch 360, loss 3215.256981556794
# torch.float64 torch.float64
# epoch 361, loss 3203.7264079324095
# torch.float64 torch.float64
# epoch 362, loss 3192.238241290031
# torch.float64 torch.float64
# epoch 363, loss 3180.79232245015
# torch.float64 torch.float64
# epoch 364, loss 3169.388492840972
# torch.float64 torch.float64
# epoch 365, loss 3158.026594496058
# torch.float64 torch.float64
# epoch 366, loss 3146.7064700519904
# torch.float64 torch.float64
# epoch 367, loss 3135.4279627460296
# torch.float64 torch.float64
# epoch 368, loss 3124.190916413797
# torch.float64 torch.float64
# epoch 369, loss 3112.9951754869535
# torch.float64 torch.float64
# epoch 370, loss 3101.840584990897
# torch.float64 torch.float64
# epoch 371, loss 3090.726990542461
# torch.float64 torch.float64
# epoch 372, loss 3079.6542383476285
# torch.float64 torch.float64
# epoch 373, loss 3068.6221751992516
# torch.float64 torch.float64
# epoch 374, loss 3057.6306484747797
# torch.float64 torch.float64
# epoch 375, loss 3046.679506133998
# torch.float64 torch.float64
# epoch 376, loss 3035.7685967167768
# torch.float64 torch.float64
# epoch 377, loss 3024.8977693408215
# torch.float64 torch.float64
# epoch 378, loss 3014.066873699444
# torch.float64 torch.float64
# epoch 379, loss 3003.27576005933
# torch.float64 torch.float64
# epoch 380, loss 2992.524279258326
# torch.float64 torch.float64
# epoch 381, loss 2981.812282703224
# torch.float64 torch.float64
# epoch 382, loss 2971.1396223675683
# torch.float64 torch.float64
# epoch 383, loss 2960.506150789456
# torch.float64 torch.float64
# epoch 384, loss 2949.911721069358
# torch.float64 torch.float64
# epoch 385, loss 2939.356186867944
# torch.float64 torch.float64
# epoch 386, loss 2928.8394024039126
# torch.float64 torch.float64
# epoch 387, loss 2918.3612224518374
# torch.float64 torch.float64
# epoch 388, loss 2907.921502340014
# torch.float64 torch.float64
# epoch 389, loss 2897.520097948321
# torch.float64 torch.float64
# epoch 390, loss 2887.156865706086
# torch.float64 torch.float64
# epoch 391, loss 2876.8316625899633
# torch.float64 torch.float64
# epoch 392, loss 2866.5443461218138
# torch.float64 torch.float64
# epoch 393, loss 2856.2947743666
# torch.float64 torch.float64
# epoch 394, loss 2846.0828059302885
# torch.float64 torch.float64
# epoch 395, loss 2835.9082999577527
# torch.float64 torch.float64
# epoch 396, loss 2825.771116130693
# torch.float64 torch.float64
# epoch 397, loss 2815.6711146655634
# torch.float64 torch.float64
# epoch 398, loss 2805.6081563115013
# torch.float64 torch.float64
# epoch 399, loss 2795.5821023482704
# torch.float64 torch.float64
# epoch 400, loss 2785.592814584209
# torch.float64 torch.float64
# epoch 401, loss 2775.6401553541878
# torch.float64 torch.float64
# epoch 402, loss 2765.7239875175737
# torch.float64 torch.float64
# epoch 403, loss 2755.844174456208
# torch.float64 torch.float64
# epoch 404, loss 2746.000580072377
# torch.float64 torch.float64
# epoch 405, loss 2736.193068786813
# torch.float64 torch.float64
# epoch 406, loss 2726.4215055366817
# torch.float64 torch.float64
# epoch 407, loss 2716.685755773594
# torch.float64 torch.float64
# epoch 408, loss 2706.9856854616123
# torch.float64 torch.float64
# epoch 409, loss 2697.321161075274
# torch.float64 torch.float64
# epoch 410, loss 2687.692049597619
# torch.float64 torch.float64
# epoch 411, loss 2678.0982185182265
# torch.float64 torch.float64
# epoch 412, loss 2668.539535831254
# torch.float64 torch.float64
# epoch 413, loss 2659.015870033494
# torch.float64 torch.float64
# epoch 414, loss 2649.5270901224294
# torch.float64 torch.float64
# epoch 415, loss 2640.0730655942984
# torch.float64 torch.float64
# epoch 416, loss 2630.6536664421706
# torch.float64 torch.float64
# epoch 417, loss 2621.2687631540275
# torch.float64 torch.float64
# epoch 418, loss 2611.9182267108527
# torch.float64 torch.float64
# epoch 419, loss 2602.6019285847246
# torch.float64 torch.float64
# epoch 420, loss 2593.319740736923
# torch.float64 torch.float64
# epoch 421, loss 2584.0715356160385
# torch.float64 torch.float64
# epoch 422, loss 2574.8571861560936
# torch.float64 torch.float64
# epoch 423, loss 2565.6765657746632
# torch.float64 torch.float64
# epoch 424, loss 2556.529548371015
# torch.float64 torch.float64
# epoch 425, loss 2547.416008324243
# torch.float64 torch.float64
# epoch 426, loss 2538.3358204914193
# torch.float64 torch.float64
# epoch 427, loss 2529.288860205748
# torch.float64 torch.float64
# epoch 428, loss 2520.275003274726
# torch.float64 torch.float64
# epoch 429, loss 2511.294125978314
# torch.float64 torch.float64
# epoch 430, loss 2502.3461050671126
# torch.float64 torch.float64
# epoch 431, loss 2493.4308177605462
# torch.float64 torch.float64
# epoch 432, loss 2484.548141745051
# torch.float64 torch.float64
# epoch 433, loss 2475.6979551722748
# torch.float64 torch.float64
# epoch 434, loss 2466.8801366572843
# torch.float64 torch.float64
# epoch 435, loss 2458.094565276772
# torch.float64 torch.float64
# epoch 436, loss 2449.341120567277
# torch.float64 torch.float64
# epoch 437, loss 2440.619682523412
# torch.float64 torch.float64
# epoch 438, loss 2431.930131596094
# torch.float64 torch.float64
# epoch 439, loss 2423.272348690785
# torch.float64 torch.float64
# epoch 440, loss 2414.6462151657374
# torch.float64 torch.float64
# epoch 441, loss 2406.051612830249
# torch.float64 torch.float64
# epoch 442, loss 2397.4884239429184
# torch.float64 torch.float64
# epoch 443, loss 2388.956531209921
# torch.float64 torch.float64
# epoch 444, loss 2380.455817783272
# torch.float64 torch.float64
# epoch 445, loss 2371.986167259112
# torch.float64 torch.float64
# epoch 446, loss 2363.5474636759977
# torch.float64 torch.float64
# epoch 447, loss 2355.1395915131875
# torch.float64 torch.float64
# epoch 448, loss 2346.762435688948
# torch.float64 torch.float64
# epoch 449, loss 2338.415881558858
# torch.float64 torch.float64
# epoch 450, loss 2330.0998149141255
# torch.float64 torch.float64
# epoch 451, loss 2321.8141219799036
# torch.float64 torch.float64
# epoch 452, loss 2313.558689413619
# torch.float64 torch.float64
# epoch 453, loss 2305.3334043033074
# torch.float64 torch.float64
# epoch 454, loss 2297.138154165951
# torch.float64 torch.float64
# epoch 455, loss 2288.9728269458255
# torch.float64 torch.float64
# epoch 456, loss 2280.8373110128514
# torch.float64 torch.float64
# epoch 457, loss 2272.7314951609565
# torch.float64 torch.float64
# epoch 458, loss 2264.6552686064383
# torch.float64 torch.float64
# epoch 459, loss 2256.6085209863377
# torch.float64 torch.float64
# epoch 460, loss 2248.591142356816
# torch.float64 torch.float64
# epoch 461, loss 2240.6030231915406
# torch.float64 torch.float64
# epoch 462, loss 2232.6440543800754
# torch.float64 torch.float64
# epoch 463, loss 2224.7141272262793
# torch.float64 torch.float64
# epoch 464, loss 2216.813133446708
# torch.float64 torch.float64
# epoch 465, loss 2208.9409651690225
# torch.float64 torch.float64
# epoch 466, loss 2201.0975149304086
# torch.float64 torch.float64
# epoch 467, loss 2193.282675675997
# torch.float64 torch.float64
# epoch 468, loss 2185.496340757291
# torch.float64 torch.float64
# epoch 469, loss 2177.7384039306007
# torch.float64 torch.float64
# epoch 470, loss 2170.0087593554867
# torch.float64 torch.float64
# epoch 471, loss 2162.3073015932014
# torch.float64 torch.float64
# epoch 472, loss 2154.633925605146
# torch.float64 torch.float64
# epoch 473, loss 2146.988526751326
# torch.float64 torch.float64
# epoch 474, loss 2139.3710007888176
# torch.float64 torch.float64
# epoch 475, loss 2131.7812438702395
# torch.float64 torch.float64
# epoch 476, loss 2124.2191525422268
# torch.float64 torch.float64
# epoch 477, loss 2116.684623743913
# torch.float64 torch.float64
# epoch 478, loss 2109.177554805424
# torch.float64 torch.float64
# epoch 479, loss 2101.6978434463645
# torch.float64 torch.float64
# epoch 480, loss 2094.245387774325
# torch.float64 torch.float64
# epoch 481, loss 2086.8200862833833
# torch.float64 torch.float64
# epoch 482, loss 2079.4218378526193
# torch.float64 torch.float64
# epoch 483, loss 2072.0505417446316
# torch.float64 torch.float64
# epoch 484, loss 2064.7060976040584
# torch.float64 torch.float64
# epoch 485, loss 2057.388405456114
# torch.float64 torch.float64
# epoch 486, loss 2050.097365705113
# torch.float64 torch.float64
# epoch 487, loss 2042.8328791330216
# torch.float64 torch.float64
# epoch 488, loss 2035.5948468979957
# torch.float64 torch.float64
# epoch 489, loss 2028.3831705329387
# torch.float64 torch.float64
# epoch 490, loss 2021.1977519440552
# torch.float64 torch.float64
# epoch 491, loss 2014.0384934094163
# torch.float64 torch.float64
# epoch 492, loss 2006.905297577528
# torch.float64 torch.float64
# epoch 493, loss 1999.798067465907
# torch.float64 torch.float64
# epoch 494, loss 1992.7167064596556
# torch.float64 torch.float64
# epoch 495, loss 1985.661118310054
# torch.float64 torch.float64
# epoch 496, loss 1978.6312071331474
# torch.float64 torch.float64
# epoch 497, loss 1971.6268774083426
# torch.float64 torch.float64
# epoch 498, loss 1964.648033977012
# torch.float64 torch.float64
# epoch 499, loss 1957.694582041096
# torch.float64 torch.float64
# epoch 500, loss 1950.7664271617257
# torch.float64 torch.float64
# epoch 501, loss 1943.8634752578291
# torch.float64 torch.float64
# epoch 502, loss 1936.9856326047648
# torch.float64 torch.float64
# epoch 503, loss 1930.132805832944
# torch.float64 torch.float64
# epoch 504, loss 1923.3049019264683
# torch.float64 torch.float64
# epoch 505, loss 1916.5018282217693
# torch.float64 torch.float64
# epoch 506, loss 1909.7234924062527
# torch.float64 torch.float64
# epoch 507, loss 1902.9698025169478
# torch.float64 torch.float64
# epoch 508, loss 1896.240666939165
# torch.float64 torch.float64
# epoch 509, loss 1889.5359944051554
# torch.float64 torch.float64
# epoch 510, loss 1882.8556939927762
# torch.float64 torch.float64
# epoch 511, loss 1876.1996751241618
# torch.float64 torch.float64
# epoch 512, loss 1869.5678475644017
# torch.float64 torch.float64
# epoch 513, loss 1862.9601214202212
# torch.float64 torch.float64
# epoch 514, loss 1856.3764071386663
# torch.float64 torch.float64
# epoch 515, loss 1849.8166155057975
# torch.float64 torch.float64
# epoch 516, loss 1843.2806576453859
# torch.float64 torch.float64
# epoch 517, loss 1836.768445017614
# torch.float64 torch.float64
# epoch 518, loss 1830.279889417786
# torch.float64 torch.float64
# epoch 519, loss 1823.8149029750348
# torch.float64 torch.float64
# epoch 520, loss 1817.373398151042
# torch.float64 torch.float64
# epoch 521, loss 1810.9552877387603
# torch.float64 torch.float64
# epoch 522, loss 1804.5604848611397
# torch.float64 torch.float64
# epoch 523, loss 1798.1889029698582
# torch.float64 torch.float64
# epoch 524, loss 1791.8404558440586
# torch.float64 torch.float64
# epoch 525, loss 1785.515057589094
# torch.float64 torch.float64
# epoch 526, loss 1779.2126226352696
# torch.float64 torch.float64
# epoch 527, loss 1772.933065736596
# torch.float64 torch.float64
# epoch 528, loss 1766.6763019695463
# torch.float64 torch.float64
# epoch 529, loss 1760.4422467318177
# torch.float64 torch.float64
# epoch 530, loss 1754.2308157410946
# torch.float64 torch.float64
# epoch 531, loss 1748.0419250338225
# torch.float64 torch.float64
# epoch 532, loss 1741.8754909639833
# torch.float64 torch.float64
# epoch 533, loss 1735.7314302018726
# torch.float64 torch.float64
# epoch 534, loss 1729.60965973289
# torch.float64 torch.float64
# epoch 535, loss 1723.5100968563227
# torch.float64 torch.float64
# epoch 536, loss 1717.432659184146
# torch.float64 torch.float64
# epoch 537, loss 1711.3772646398181
# torch.float64 torch.float64
# epoch 538, loss 1705.3438314570867
# torch.float64 torch.float64
# epoch 539, loss 1699.3322781787951
# torch.float64 torch.float64
# epoch 540, loss 1693.342523655699
# torch.float64 torch.float64
# epoch 541, loss 1687.3744870452815
# torch.float64 torch.float64
# epoch 542, loss 1681.428087810574
# torch.float64 torch.float64
# epoch 543, loss 1675.5032457189882
# torch.float64 torch.float64
# epoch 544, loss 1669.5998808411423
# torch.float64 torch.float64
# epoch 545, loss 1663.7179135497015
# torch.float64 torch.float64
# epoch 546, loss 1657.8572645182153
# torch.float64 torch.float64
# epoch 547, loss 1652.0178547199641
# torch.float64 torch.float64
# epoch 548, loss 1646.1996054268088
# torch.float64 torch.float64
# epoch 549, loss 1640.4024382080447
# torch.float64 torch.float64
# epoch 550, loss 1634.6262749292587
# torch.float64 torch.float64
# epoch 551, loss 1628.8710377511966
# torch.float64 torch.float64
# epoch 552, loss 1623.1366491286235
# torch.float64 torch.float64
# epoch 553, loss 1617.423031809202
# torch.float64 torch.float64
# epoch 554, loss 1611.730108832365
# torch.float64 torch.float64
# epoch 555, loss 1606.0578035281983
# torch.float64 torch.float64
# epoch 556, loss 1600.4060395163217
# torch.float64 torch.float64
# epoch 557, loss 1594.7747407047839
# torch.float64 torch.float64
# epoch 558, loss 1589.1638312889497
# torch.float64 torch.float64
# epoch 559, loss 1583.5732357504035
# torch.float64 torch.float64
# epoch 560, loss 1578.0028788558482
# torch.float64 torch.float64
# epoch 561, loss 1572.452685656012
# torch.float64 torch.float64
# epoch 562, loss 1566.922581484559
# torch.float64 torch.float64
# epoch 563, loss 1561.4124919570054
# torch.float64 torch.float64
# epoch 564, loss 1555.9223429696372
# torch.float64 torch.float64
# epoch 565, loss 1550.4520606984336
# torch.float64 torch.float64
# epoch 566, loss 1545.0015715979955
# torch.float64 torch.float64
# epoch 567, loss 1539.5708024004748
# torch.float64 torch.float64
# epoch 568, loss 1534.1596801145138
# torch.float64 torch.float64
# epoch 569, loss 1528.7681320241813
# torch.float64 torch.float64
# epoch 570, loss 1523.396085687919
# torch.float64 torch.float64
# epoch 571, loss 1518.0434689374897
# torch.float64 torch.float64
# epoch 572, loss 1512.7102098769274
# torch.float64 torch.float64
# epoch 573, loss 1507.3962368814957
# torch.float64 torch.float64
# epoch 574, loss 1502.1014785966481
# torch.float64 torch.float64
# epoch 575, loss 1496.8258639369906
# torch.float64 torch.float64
# epoch 576, loss 1491.5693220852518
# torch.float64 torch.float64
# epoch 577, loss 1486.3317824912544
# torch.float64 torch.float64
# epoch 578, loss 1481.113174870892
# torch.float64 torch.float64
# epoch 579, loss 1475.9134292051099
# torch.float64 torch.float64
# epoch 580, loss 1470.7324757388865
# torch.float64 torch.float64
# epoch 581, loss 1465.5702449802272
# torch.float64 torch.float64
# epoch 582, loss 1460.4266676991524
# torch.float64 torch.float64
# epoch 583, loss 1455.301674926693
# torch.float64 torch.float64
# epoch 584, loss 1450.195197953893
# torch.float64 torch.float64
# epoch 585, loss 1445.1071683308123
# torch.float64 torch.float64
# epoch 586, loss 1440.037517865534
# torch.float64 torch.float64
# epoch 587, loss 1434.9861786231777
# torch.float64 torch.float64
# epoch 588, loss 1429.9530829249125
# torch.float64 torch.float64
# epoch 589, loss 1424.938163346978
# torch.float64 torch.float64
# epoch 590, loss 1419.9413527197057
# torch.float64 torch.float64
# epoch 591, loss 1414.962584126549
# torch.float64 torch.float64
# epoch 592, loss 1410.0017909031105
# torch.float64 torch.float64
# epoch 593, loss 1405.0589066361772
# torch.float64 torch.float64
# epoch 594, loss 1400.1338651627614
# torch.float64 torch.float64
# epoch 595, loss 1395.226600569137
# torch.float64 torch.float64
# epoch 596, loss 1390.3370471898918
# torch.float64 torch.float64
# epoch 597, loss 1385.4651396069708
# torch.float64 torch.float64
# epoch 598, loss 1380.610812648733
# torch.float64 torch.float64
# epoch 599, loss 1375.774001389007
# torch.float64 torch.float64
# epoch 600, loss 1370.9546411461504
# torch.float64 torch.float64
# epoch 601, loss 1366.1526674821148
# torch.float64 torch.float64
# epoch 602, loss 1361.3680162015144
# torch.float64 torch.float64
# epoch 603, loss 1356.6006233506935
# torch.float64 torch.float64
# epoch 604, loss 1351.8504252168045
# torch.float64 torch.float64
# epoch 605, loss 1347.1173583268874
# torch.float64 torch.float64
# epoch 606, loss 1342.4013594469473
# torch.float64 torch.float64
# epoch 607, loss 1337.7023655810435
# torch.float64 torch.float64
# epoch 608, loss 1333.020313970379
# torch.float64 torch.float64
# epoch 609, loss 1328.355142092389
# torch.float64 torch.float64
# epoch 610, loss 1323.7067876598423
# torch.float64 torch.float64
# epoch 611, loss 1319.0751886199364
# torch.float64 torch.float64
# epoch 612, loss 1314.4602831534037
# torch.float64 torch.float64
# epoch 613, loss 1309.862009673617
# torch.float64 torch.float64
# epoch 614, loss 1305.2803068256987
# torch.float64 torch.float64
# epoch 615, loss 1300.7151134856363
# torch.float64 torch.float64
# epoch 616, loss 1296.166368759397
# torch.float64 torch.float64
# epoch 617, loss 1291.6340119820509
# torch.float64 torch.float64
# epoch 618, loss 1287.1179827168912
# torch.float64 torch.float64
# epoch 619, loss 1282.6182207545648
# torch.float64 torch.float64
# epoch 620, loss 1278.1346661122009
# torch.float64 torch.float64
# epoch 621, loss 1273.6672590325456
# torch.float64 torch.float64
# epoch 622, loss 1269.2159399830991
# torch.float64 torch.float64
# epoch 623, loss 1264.7806496552562
# torch.float64 torch.float64
# epoch 624, loss 1260.3613289634504
# torch.float64 torch.float64
# epoch 625, loss 1255.9579190443005
# torch.float64 torch.float64
# epoch 626, loss 1251.570361255763
# torch.float64 torch.float64
# epoch 627, loss 1247.1985971762838
# torch.float64 torch.float64
# epoch 628, loss 1242.8425686039575
# torch.float64 torch.float64
# epoch 629, loss 1238.5022175556846
# torch.float64 torch.float64
# epoch 630, loss 1234.1774862663392
# torch.float64 torch.float64
# epoch 631, loss 1229.8683171879334
# torch.float64 torch.float64
# epoch 632, loss 1225.5746529887867
# torch.float64 torch.float64
# epoch 633, loss 1221.2964365527027
# torch.float64 torch.float64
# epoch 634, loss 1217.0336109781424
# torch.float64 torch.float64
# epoch 635, loss 1212.7861195774055
# torch.float64 torch.float64
# epoch 636, loss 1208.5539058758125
# torch.float64 torch.float64
# epoch 637, loss 1204.3369136108922
# torch.float64 torch.float64
# epoch 638, loss 1200.1350867315684
# torch.float64 torch.float64
# epoch 639, loss 1195.9483693973555
# torch.float64 torch.float64
# epoch 640, loss 1191.776705977552
# torch.float64 torch.float64
# epoch 641, loss 1187.6200410504389
# torch.float64 torch.float64
# epoch 642, loss 1183.4783194024826
# torch.float64 torch.float64
# epoch 643, loss 1179.3514860275388
# torch.float64 torch.float64
# epoch 644, loss 1175.2394861260611
# torch.float64 torch.float64
# epoch 645, loss 1171.1422651043115
# torch.float64 torch.float64
# epoch 646, loss 1167.059768573574
# torch.float64 torch.float64
# epoch 647, loss 1162.991942349373
# torch.float64 torch.float64
# epoch 648, loss 1158.938732450692
# torch.float64 torch.float64
# epoch 649, loss 1154.9000850991974
# torch.float64 torch.float64
# epoch 650, loss 1150.875946718465
# torch.float64 torch.float64
# epoch 651, loss 1146.8662639332078
# torch.float64 torch.float64
# epoch 652, loss 1142.87098356851
# torch.float64 torch.float64
# epoch 653, loss 1138.8900526490593
# torch.float64 torch.float64
# epoch 654, loss 1134.9234183983888
# torch.float64 torch.float64
# epoch 655, loss 1130.9710282381143
# torch.float64 torch.float64
# epoch 656, loss 1127.0328297871802
# torch.float64 torch.float64
# epoch 657, loss 1123.1087708611053
# torch.float64 torch.float64
# epoch 658, loss 1119.1987994712345
# torch.float64 torch.float64
# epoch 659, loss 1115.302863823988
# torch.float64 torch.float64
# epoch 660, loss 1111.420912320121
# torch.float64 torch.float64
# epoch 661, loss 1107.5528935539792
# torch.float64 torch.float64
# epoch 662, loss 1103.6987563127605
# torch.float64 torch.float64
# epoch 663, loss 1099.8584495757805
# torch.float64 torch.float64
# epoch 664, loss 1096.031922513738
# torch.float64 torch.float64
# epoch 665, loss 1092.2191244879855
# torch.float64 torch.float64
# epoch 666, loss 1088.4200050498016
# torch.float64 torch.float64
# epoch 667, loss 1084.6345139396685
# torch.float64 torch.float64
# epoch 668, loss 1080.8626010865453
# torch.float64 torch.float64
# epoch 669, loss 1077.1042166071559
# torch.float64 torch.float64
# epoch 670, loss 1073.359310805266
# torch.float64 torch.float64
# epoch 671, loss 1069.6278341709751
# torch.float64 torch.float64
# epoch 672, loss 1065.9097373800028
# torch.float64 torch.float64
# epoch 673, loss 1062.204971292982
# torch.float64 torch.float64
# epoch 674, loss 1058.513486954754
# torch.float64 torch.float64
# epoch 675, loss 1054.835235593665
# torch.float64 torch.float64
# epoch 676, loss 1051.1701686208676
# torch.float64 torch.float64
# epoch 677, loss 1047.5182376296234
# torch.float64 torch.float64
# epoch 678, loss 1043.8793943946084
# torch.float64 torch.float64
# epoch 679, loss 1040.2535908712216
# torch.float64 torch.float64
# epoch 680, loss 1036.640779194897
# torch.float64 torch.float64
# epoch 681, loss 1033.0409116804144
# torch.float64 torch.float64
# epoch 682, loss 1029.45394082122
# torch.float64 torch.float64
# epoch 683, loss 1025.8798192887425
# torch.float64 torch.float64
# epoch 684, loss 1022.3184999317149
# torch.float64 torch.float64
# epoch 685, loss 1018.7699357755006
# torch.float64 torch.float64
# epoch 686, loss 1015.2340800214176
# torch.float64 torch.float64
# epoch 687, loss 1011.710886046071
# torch.float64 torch.float64
# epoch 688, loss 1008.2003074006822
# torch.float64 torch.float64
# epoch 689, loss 1004.7022978104254
# torch.float64 torch.float64
# epoch 690, loss 1001.216811173765
# torch.float64 torch.float64
# epoch 691, loss 997.7438015617936
# torch.float64 torch.float64
# epoch 692, loss 994.283223217577
# torch.float64 torch.float64
# epoch 693, loss 990.8350305554961
# torch.float64 torch.float64
# epoch 694, loss 987.3991781605968
# torch.float64 torch.float64
# epoch 695, loss 983.9756207879382
# torch.float64 torch.float64
# epoch 696, loss 980.5643133619463
# torch.float64 torch.float64
# epoch 697, loss 977.1652109757686
# torch.float64 torch.float64
# epoch 698, loss 973.7782688906309
# torch.float64 torch.float64
# epoch 699, loss 970.4034425351981
# torch.float64 torch.float64
# epoch 700, loss 967.040687504936
# torch.float64 torch.float64
# epoch 701, loss 963.689959561477
# torch.float64 torch.float64
# epoch 702, loss 960.3512146319857
# torch.float64 torch.float64
# epoch 703, loss 957.0244088085307
# torch.float64 torch.float64
# epoch 704, loss 953.7094983474553
# torch.float64 torch.float64
# epoch 705, loss 950.4064396687529
# torch.float64 torch.float64
# epoch 706, loss 947.1151893554437
# torch.float64 torch.float64
# epoch 707, loss 943.8357041529546
# torch.float64 torch.float64
# epoch 708, loss 940.5679409685002
# torch.float64 torch.float64
# epoch 709, loss 937.3118568704679
# torch.float64 torch.float64
# epoch 710, loss 934.0674090878038
# torch.float64 torch.float64
# epoch 711, loss 930.8345550094018
# torch.float64 torch.float64
# epoch 712, loss 927.6132521834958
# torch.float64 torch.float64
# epoch 713, loss 924.4034583170517
# torch.float64 torch.float64
# epoch 714, loss 921.2051312751652
# torch.float64 torch.float64
# epoch 715, loss 918.0182290804585
# torch.float64 torch.float64
# epoch 716, loss 914.8427099124823
# torch.float64 torch.float64
# epoch 717, loss 911.6785321071184
# torch.float64 torch.float64
# epoch 718, loss 908.5256541559842
# torch.float64 torch.float64
# epoch 719, loss 905.3840347058416
# torch.float64 torch.float64
# epoch 720, loss 902.2536325580056
# torch.float64 torch.float64
# epoch 721, loss 899.1344066677578
# torch.float64 torch.float64
# epoch 722, loss 896.0263161437593
# torch.float64 torch.float64
# epoch 723, loss 892.9293202474685
# torch.float64 torch.float64
# epoch 724, loss 889.8433783925593
# torch.float64 torch.float64
# epoch 725, loss 886.768450144343
# torch.float64 torch.float64
# epoch 726, loss 883.7044952191907
# torch.float64 torch.float64
# epoch 727, loss 880.6514734839602
# torch.float64 torch.float64
# epoch 728, loss 877.6093449554224
# torch.float64 torch.float64
# epoch 729, loss 874.5780697996931
# torch.float64 torch.float64
# epoch 730, loss 871.5576083316635
# torch.float64 torch.float64
# epoch 731, loss 868.5479210144352
# torch.float64 torch.float64
# epoch 732, loss 865.5489684587577
# torch.float64 torch.float64
# epoch 733, loss 862.5607114224656
# torch.float64 torch.float64
# epoch 734, loss 859.5831108099215
# torch.float64 torch.float64
# epoch 735, loss 856.6161276714571
# torch.float64 torch.float64
# epoch 736, loss 853.6597232028192
# torch.float64 torch.float64
# epoch 737, loss 850.7138587446182
# torch.float64 torch.float64
# epoch 738, loss 847.7784957817757
# torch.float64 torch.float64
# epoch 739, loss 844.853595942978
# torch.float64 torch.float64
# epoch 740, loss 841.9391210001289
# torch.float64 torch.float64
# epoch 741, loss 839.0350328678051
# torch.float64 torch.float64
# epoch 742, loss 836.1412936027149
# torch.float64 torch.float64
# epoch 743, loss 833.2578654031582
# torch.float64 torch.float64
# epoch 744, loss 830.3847106084888
# torch.float64 torch.float64
# epoch 745, loss 827.5217916985773
# torch.float64 torch.float64
# epoch 746, loss 824.6690712932799
# torch.float64 torch.float64
# epoch 747, loss 821.8265121519037
# torch.float64 torch.float64
# epoch 748, loss 818.9940771726798
# torch.float64 torch.float64
# epoch 749, loss 816.1717293922336
# torch.float64 torch.float64
# epoch 750, loss 813.3594319850608
# torch.float64 torch.float64
# epoch 751, loss 810.5571482630027
# torch.float64 torch.float64
# epoch 752, loss 807.7648416747261
# torch.float64 torch.float64
# epoch 753, loss 804.9824758052022
# torch.float64 torch.float64
# epoch 754, loss 802.2100143751898
# torch.float64 torch.float64
# epoch 755, loss 799.4474212407202
# torch.float64 torch.float64
# epoch 756, loss 796.6946603925838
# torch.float64 torch.float64
# epoch 757, loss 793.9516959558171
# torch.float64 torch.float64
# epoch 758, loss 791.2184921891945
# torch.float64 torch.float64
# epoch 759, loss 788.495013484721
# torch.float64 torch.float64
# epoch 760, loss 785.7812243671252
# torch.float64 torch.float64
# epoch 761, loss 783.0770894933561
# torch.float64 torch.float64
# epoch 762, loss 780.3825736520819
# torch.float64 torch.float64
# epoch 763, loss 777.6976417631902
# torch.float64 torch.float64
# epoch 764, loss 775.0222588772888
# torch.float64 torch.float64
# epoch 765, loss 772.3563901752116
# torch.float64 torch.float64
# epoch 766, loss 769.7000009675227
# ...
# epoch 2747, loss 5.662828293931139
# torch.float64 torch.float64
# epoch 2748, loss 5.658585908010419
# torch.float64 torch.float64
# epoch 2749, loss 5.6543561900723525
# torch.float64 torch.float64
# epoch 2750, loss 5.650139101544871
# torch.float64 torch.float64
# epoch 2751, loss 5.645934603976176
# torch.float64 torch.float64
# epoch 2752, loss 5.64174265903421
# torch.float64 torch.float64
# epoch 2753, loss 5.637563228506395
# torch.float64 torch.float64
# epoch 2754, loss 5.633396274299152
# torch.float64 torch.float64
# epoch 2755, loss 5.629241758437544
# torch.float64 torch.float64
# epoch 2756, loss 5.625099643065027
# torch.float64 torch.float64
# epoch 2757, loss 5.6209698904428365
# torch.float64 torch.float64
# epoch 2758, loss 5.61685246294982
# torch.float64 torch.float64
# epoch 2759, loss 5.612747323081907
# torch.float64 torch.float64
# epoch 2760, loss 5.608654433451834
# torch.float64 torch.float64
# epoch 2761, loss 5.6045737567888025
# torch.float64 torch.float64
# epoch 2762, loss 5.600505255937934
# torch.float64 torch.float64
# epoch 2763, loss 5.596448893860074
# torch.float64 torch.float64
# epoch 2764, loss 5.592404633631355
# torch.float64 torch.float64
# epoch 2765, loss 5.588372438442823
# torch.float64 torch.float64
# epoch 2766, loss 5.584352271600097
# torch.float64 torch.float64
# epoch 2767, loss 5.580344096522926
# torch.float64 torch.float64
# epoch 2768, loss 5.576347876745006
# torch.float64 torch.float64
# epoch 2769, loss 5.572363575913357
# torch.float64 torch.float64
# epoch 2770, loss 5.568391157788178
# torch.float64 torch.float64
# epoch 2771, loss 5.564430586242387
# torch.float64 torch.float64
# epoch 2772, loss 5.560481825261268
# torch.float64 torch.float64
# epoch 2773, loss 5.556544838942144
# torch.float64 torch.float64
# epoch 2774, loss 5.552619591493999
# torch.float64 torch.float64
# epoch 2775, loss 5.54870604723712
# torch.float64 torch.float64
# epoch 2776, loss 5.5448041706027285
# torch.float64 torch.float64
# epoch 2777, loss 5.54091392613265
# torch.float64 torch.float64
# epoch 2778, loss 5.5370352784789345
# torch.float64 torch.float64
# epoch 2779, loss 5.533168192403558
# torch.float64 torch.float64
# epoch 2780, loss 5.529312632778029
# torch.float64 torch.float64
# epoch 2781, loss 5.525468564583024
# torch.float64 torch.float64
# epoch 2782, loss 5.521635952908076
# torch.float64 torch.float64
# epoch 2783, loss 5.517814762951248
# torch.float64 torch.float64
# epoch 2784, loss 5.514004960018665
# torch.float64 torch.float64
# epoch 2785, loss 5.510206509524336
# torch.float64 torch.float64
# epoch 2786, loss 5.506419376989723
# torch.float64 torch.float64
# epoch 2787, loss 5.502643528043344
# torch.float64 torch.float64
# epoch 2788, loss 5.498878928420578
# torch.float64 torch.float64
# epoch 2789, loss 5.495125543963191
# torch.float64 torch.float64
# epoch 2790, loss 5.491383340619022
# torch.float64 torch.float64
# epoch 2791, loss 5.487652284441725
# torch.float64 torch.float64
# epoch 2792, loss 5.483932341590356
# torch.float64 torch.float64
# epoch 2793, loss 5.480223478329046
# torch.float64 torch.float64
# epoch 2794, loss 5.476525661026659
# torch.float64 torch.float64
# epoch 2795, loss 5.472838856156521
# torch.float64 torch.float64
# epoch 2796, loss 5.469163030296013
# torch.float64 torch.float64
# epoch 2797, loss 5.4654981501262805
# torch.float64 torch.float64
# epoch 2798, loss 5.461844182431868
# torch.float64 torch.float64
# epoch 2799, loss 5.45820109410045
# torch.float64 torch.float64
# epoch 2800, loss 5.4545688521224545
# torch.float64 torch.float64
# epoch 2801, loss 5.450947423590691
# torch.float64 torch.float64
# epoch 2802, loss 5.447336775700154
# torch.float64 torch.float64
# epoch 2803, loss 5.443736875747627
# torch.float64 torch.float64
# epoch 2804, loss 5.440147691131292
# torch.float64 torch.float64
# epoch 2805, loss 5.436569189350501
# torch.float64 torch.float64
# epoch 2806, loss 5.433001338005433
# torch.float64 torch.float64
# epoch 2807, loss 5.429444104796734
# torch.float64 torch.float64
# epoch 2808, loss 5.425897457525257
# torch.float64 torch.float64
# epoch 2809, loss 5.422361364091735
# torch.float64 torch.float64
# epoch 2810, loss 5.418835792496342
# torch.float64 torch.float64
# epoch 2811, loss 5.415320710838622
# torch.float64 torch.float64
# epoch 2812, loss 5.411816087316874
# torch.float64 torch.float64
# epoch 2813, loss 5.4083218902280645
# torch.float64 torch.float64
# epoch 2814, loss 5.404838087967469
# torch.float64 torch.float64
# epoch 2815, loss 5.401364649028287
# torch.float64 torch.float64
# epoch 2816, loss 5.3979015420013665
# torch.float64 torch.float64
# epoch 2817, loss 5.394448735574937
# torch.float64 torch.float64
# epoch 2818, loss 5.391006198534205
# torch.float64 torch.float64
# epoch 2819, loss 5.387573899761148
# torch.float64 torch.float64
# epoch 2820, loss 5.384151808234185
# torch.float64 torch.float64
# epoch 2821, loss 5.380739893027782
# torch.float64 torch.float64
# epoch 2822, loss 5.377338123312276
# torch.float64 torch.float64
# epoch 2823, loss 5.373946468353419
# torch.float64 torch.float64
# epoch 2824, loss 5.37056489751227
# torch.float64 torch.float64
# epoch 2825, loss 5.367193380244691
# torch.float64 torch.float64
# epoch 2826, loss 5.3638318861012255
# torch.float64 torch.float64
# epoch 2827, loss 5.360480384726661
# torch.float64 torch.float64
# epoch 2828, loss 5.357138845859766
# torch.float64 torch.float64
# epoch 2829, loss 5.353807239332992
# torch.float64 torch.float64
# epoch 2830, loss 5.350485535072261
# torch.float64 torch.float64
# epoch 2831, loss 5.3471737030965585
# torch.float64 torch.float64
# epoch 2832, loss 5.343871713517672
# torch.float64 torch.float64
# epoch 2833, loss 5.340579536539873
# torch.float64 torch.float64
# epoch 2834, loss 5.337297142459711
# torch.float64 torch.float64
# epoch 2835, loss 5.334024501665634
# torch.float64 torch.float64
# epoch 2836, loss 5.330761584637697
# torch.float64 torch.float64
# epoch 2837, loss 5.327508361947346
# torch.float64 torch.float64
# epoch 2838, loss 5.324264804257015
# torch.float64 torch.float64
# epoch 2839, loss 5.321030882319984
# torch.float64 torch.float64
# epoch 2840, loss 5.31780656697993
# torch.float64 torch.float64
# epoch 2841, loss 5.314591829170761
# torch.float64 torch.float64
# epoch 2842, loss 5.3113866399163046
# torch.float64 torch.float64
# epoch 2843, loss 5.308190970329944
# torch.float64 torch.float64
# epoch 2844, loss 5.305004791614457
# torch.float64 torch.float64
# epoch 2845, loss 5.301828075061627
# torch.float64 torch.float64
# epoch 2846, loss 5.29866079205205
# torch.float64 torch.float64
# epoch 2847, loss 5.2955029140547705
# torch.float64 torch.float64
# epoch 2848, loss 5.292354412627028
# torch.float64 torch.float64
# epoch 2849, loss 5.289215259414024
# torch.float64 torch.float64
# epoch 2850, loss 5.286085426148595
# torch.float64 torch.float64
# epoch 2851, loss 5.2829648846509345
# torch.float64 torch.float64
# epoch 2852, loss 5.279853606828343
# torch.float64 torch.float64
# epoch 2853, loss 5.276751564674894
# torch.float64 torch.float64
# epoch 2854, loss 5.273658730271274
# torch.float64 torch.float64
# epoch 2855, loss 5.270575075784381
# torch.float64 torch.float64
# epoch 2856, loss 5.267500573467116
# torch.float64 torch.float64
# epoch 2857, loss 5.26443519565813
# torch.float64 torch.float64
# epoch 2858, loss 5.261378914781455
# torch.float64 torch.float64
# epoch 2859, loss 5.258331703346387
# torch.float64 torch.float64
# epoch 2860, loss 5.25529353394707
# torch.float64 torch.float64
# epoch 2861, loss 5.252264379262302
# torch.float64 torch.float64
# epoch 2862, loss 5.249244212055266
# torch.float64 torch.float64
# epoch 2863, loss 5.246233005173233
# torch.float64 torch.float64
# epoch 2864, loss 5.243230731547314
# torch.float64 torch.float64
# epoch 2865, loss 5.240237364192226
# torch.float64 torch.float64
# epoch 2866, loss 5.237252876205908
# torch.float64 torch.float64
# epoch 2867, loss 5.234277240769459
# torch.float64 torch.float64
# epoch 2868, loss 5.231310431146678
# torch.float64 torch.float64
# epoch 2869, loss 5.228352420683899
# torch.float64 torch.float64
# epoch 2870, loss 5.225403182809711
# torch.float64 torch.float64
# epoch 2871, loss 5.222462691034722
# torch.float64 torch.float64
# epoch 2872, loss 5.219530918951281
# torch.float64 torch.float64
# epoch 2873, loss 5.216607840233164
# torch.float64 torch.float64
# epoch 2874, loss 5.2136934286354535
# torch.float64 torch.float64
# epoch 2875, loss 5.210787657994099
# torch.float64 torch.float64
# epoch 2876, loss 5.207890502225856
# torch.float64 torch.float64
# epoch 2877, loss 5.2050019353278705
# torch.float64 torch.float64
# epoch 2878, loss 5.202121931377473
# torch.float64 torch.float64
# epoch 2879, loss 5.199250464531995
# torch.float64 torch.float64
# epoch 2880, loss 5.19638750902846
# torch.float64 torch.float64
# epoch 2881, loss 5.193533039183281
# torch.float64 torch.float64
# epoch 2882, loss 5.1906870293921195
# torch.float64 torch.float64
# epoch 2883, loss 5.187849454129514
# torch.float64 torch.float64
# epoch 2884, loss 5.185020287948719
# torch.float64 torch.float64
# epoch 2885, loss 5.182199505481471
# torch.float64 torch.float64
# epoch 2886, loss 5.179387081437601
# torch.float64 torch.float64
# epoch 2887, loss 5.176582990605041
# torch.float64 torch.float64
# epoch 2888, loss 5.173787207849246
# torch.float64 torch.float64
# epoch 2889, loss 5.170999708113245
# torch.float64 torch.float64
# epoch 2890, loss 5.16822046641726
# torch.float64 torch.float64
# epoch 2891, loss 5.165449457858427
# torch.float64 torch.float64
# epoch 2892, loss 5.162686657610655
# torch.float64 torch.float64
# epoch 2893, loss 5.159932040924327
# torch.float64 torch.float64
# epoch 2894, loss 5.157185583126037
# torch.float64 torch.float64
# epoch 2895, loss 5.154447259618397
# torch.float64 torch.float64
# epoch 2896, loss 5.151717045879781
# torch.float64 torch.float64
# epoch 2897, loss 5.1489949174640754
# torch.float64 torch.float64
# epoch 2898, loss 5.146280850000445
# torch.float64 torch.float64
# epoch 2899, loss 5.143574819193072
# torch.float64 torch.float64
# epoch 2900, loss 5.140876800821012
# torch.float64 torch.float64
# epoch 2901, loss 5.138186770737836
# torch.float64 torch.float64
# epoch 2902, loss 5.135504704871449
# torch.float64 torch.float64
# epoch 2903, loss 5.13283057922389
# torch.float64 torch.float64
# epoch 2904, loss 5.1301643698710455
# torch.float64 torch.float64
# epoch 2905, loss 5.127506052962414
# torch.float64 torch.float64
# epoch 2906, loss 5.12485560472097
# torch.float64 torch.float64
# epoch 2907, loss 5.122213001442736
# torch.float64 torch.float64
# epoch 2908, loss 5.119578219496768
# torch.float64 torch.float64
# epoch 2909, loss 5.116951235324803
# torch.float64 torch.float64
# epoch 2910, loss 5.114332025441026
# torch.float64 torch.float64
# epoch 2911, loss 5.11172056643195
# torch.float64 torch.float64
# epoch 2912, loss 5.109116834956032
# torch.float64 torch.float64
# epoch 2913, loss 5.106520807743576
# torch.float64 torch.float64
# epoch 2914, loss 5.10393246159642
# torch.float64 torch.float64
# epoch 2915, loss 5.101351773387766
# torch.float64 torch.float64
# epoch 2916, loss 5.098778720061928
# torch.float64 torch.float64
# epoch 2917, loss 5.0962132786341225
# torch.float64 torch.float64
# epoch 2918, loss 5.093655426190246
# torch.float64 torch.float64
# epoch 2919, loss 5.09110513988659
# torch.float64 torch.float64
# epoch 2920, loss 5.088562396949736
# torch.float64 torch.float64
# epoch 2921, loss 5.086027174676249
# torch.float64 torch.float64
# epoch 2922, loss 5.08349945043251
# torch.float64 torch.float64
# epoch 2923, loss 5.08097920165436
# torch.float64 torch.float64
# epoch 2924, loss 5.078466405847094
# torch.float64 torch.float64
# epoch 2925, loss 5.075961040585114
# torch.float64 torch.float64
# epoch 2926, loss 5.073463083511676
# torch.float64 torch.float64
# epoch 2927, loss 5.0709725123388
# torch.float64 torch.float64
# epoch 2928, loss 5.0684893048469535
# torch.float64 torch.float64
# epoch 2929, loss 5.066013438884821
# torch.float64 torch.float64
# epoch 2930, loss 5.063544892369233
# torch.float64 torch.float64
# epoch 2931, loss 5.061083643284752
# torch.float64 torch.float64
# epoch 2932, loss 5.058629669683617
# torch.float64 torch.float64
# epoch 2933, loss 5.0561829496854624
# torch.float64 torch.float64
# epoch 2934, loss 5.053743461477099
# torch.float64 torch.float64
# epoch 2935, loss 5.051311183312355
# torch.float64 torch.float64
# epoch 2936, loss 5.048886093511765
# torch.float64 torch.float64
# epoch 2937, loss 5.0464681704624805
# torch.float64 torch.float64
# epoch 2938, loss 5.044057392618006
# torch.float64 torch.float64
# epoch 2939, loss 5.041653738497963
# torch.float64 torch.float64
# epoch 2940, loss 5.039257186687906
# torch.float64 torch.float64
# epoch 2941, loss 5.036867715839125
# torch.float64 torch.float64
# epoch 2942, loss 5.034485304668465
# torch.float64 torch.float64
# epoch 2943, loss 5.032109931958016
# torch.float64 torch.float64
# epoch 2944, loss 5.029741576555045
# torch.float64 torch.float64
# epoch 2945, loss 5.027380217371688
# torch.float64 torch.float64
# epoch 2946, loss 5.0250258333847935
# torch.float64 torch.float64
# epoch 2947, loss 5.022678403635675
# torch.float64 torch.float64
# epoch 2948, loss 5.020337907229989
# torch.float64 torch.float64
# epoch 2949, loss 5.018004323337472
# torch.float64 torch.float64
# epoch 2950, loss 5.015677631191745
# torch.float64 torch.float64
# epoch 2951, loss 5.0133578100900955
# torch.float64 torch.float64
# epoch 2952, loss 5.011044839393348
# torch.float64 torch.float64
# epoch 2953, loss 5.008738698525578
# torch.float64 torch.float64
# epoch 2954, loss 5.006439366973984
# torch.float64 torch.float64
# epoch 2955, loss 5.004146824288634
# torch.float64 torch.float64
# epoch 2956, loss 5.001861050082292
# torch.float64 torch.float64
# epoch 2957, loss 4.999582024030242
# torch.float64 torch.float64
# epoch 2958, loss 4.997309725870054
# torch.float64 torch.float64
# epoch 2959, loss 4.995044135401416
# torch.float64 torch.float64
# epoch 2960, loss 4.992785232485922
# torch.float64 torch.float64
# epoch 2961, loss 4.990532997046875
# torch.float64 torch.float64
# epoch 2962, loss 4.988287409069118
# torch.float64 torch.float64
# epoch 2963, loss 4.986048448598825
# torch.float64 torch.float64
# epoch 2964, loss 4.983816095743313
# torch.float64 torch.float64
# epoch 2965, loss 4.9815903306708
# torch.float64 torch.float64
# epoch 2966, loss 4.979371133610341
# torch.float64 torch.float64
# epoch 2967, loss 4.977158484851453
# torch.float64 torch.float64
# epoch 2968, loss 4.974952364744135
# torch.float64 torch.float64
# epoch 2969, loss 4.972752753698517
# torch.float64 torch.float64
# epoch 2970, loss 4.970559632184694
# torch.float64 torch.float64
# epoch 2971, loss 4.968372980732637
# torch.float64 torch.float64
# epoch 2972, loss 4.9661927799318875
# torch.float64 torch.float64
# epoch 2973, loss 4.964019010431457
# torch.float64 torch.float64
# epoch 2974, loss 4.961851652939559
# torch.float64 torch.float64
# epoch 2975, loss 4.959690688223504
# torch.float64 torch.float64
# epoch 2976, loss 4.9575360971095055
# torch.float64 torch.float64
# epoch 2977, loss 4.955387860482381
# torch.float64 torch.float64
# epoch 2978, loss 4.953245959285547
# torch.float64 torch.float64
# epoch 2979, loss 4.95111037452069
# torch.float64 torch.float64
# epoch 2980, loss 4.948981087247633
# torch.float64 torch.float64
# epoch 2981, loss 4.946858078584199
# torch.float64 torch.float64
# epoch 2982, loss 4.944741329705961
# torch.float64 torch.float64
# epoch 2983, loss 4.942630821846095
# torch.float64 torch.float64
# epoch 2984, loss 4.9405265362951996
# torch.float64 torch.float64
# epoch 2985, loss 4.93842845440111
# torch.float64 torch.float64
# epoch 2986, loss 4.936336557568702
# torch.float64 torch.float64
# epoch 2987, loss 4.934250827259736
# torch.float64 torch.float64
# epoch 2988, loss 4.932171244992668
# torch.float64 torch.float64
# epoch 2989, loss 4.930097792342521
# torch.float64 torch.float64
# epoch 2990, loss 4.928030450940591
# torch.float64 torch.float64
# epoch 2991, loss 4.925969202474375
# torch.float64 torch.float64
# epoch 2992, loss 4.9239140286873955
# torch.float64 torch.float64
# epoch 2993, loss 4.921864911378943
# torch.float64 torch.float64
# epoch 2994, loss 4.919821832403975
# torch.float64 torch.float64
# epoch 2995, loss 4.917784773672881
# torch.float64 torch.float64
# epoch 2996, loss 4.915753717151433
# torch.float64 torch.float64
# epoch 2997, loss 4.913728644860437
# torch.float64 torch.float64
# epoch 2998, loss 4.911709538875703
# torch.float64 torch.float64
# epoch 2999, loss 4.909696381327773
# Mean squared error: 6.57
# Coefficient of determination: 1.00

# %%
with torch.no_grad(): # we don't need gradients in the testing phase
    if torch.cuda.is_available():
        y_surface = model(Variable(torch.from_numpy(X_surface).cuda())).cpu().data.numpy()
    else:
        y_surface = model(Variable(torch.from_numpy(X_surface))).data.numpy()
    # print(y_pred)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec Tensorflow
#
# Docs:
# - https://www.tensorflow.org/api_docs
# - https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb

# %%
from distutils.version import LooseVersion
from keras import __version__ as version
import pandas as pd
import tensorflow as tf

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

l_rate=0.01
n_iter=500
batch_size=2

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=1))
optimizer = None
if LooseVersion(version) >= LooseVersion('3'):
    optimizer = tf.keras.optimizers.Adam(learning_rate=l_rate)
else:
    optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=l_rate)
model.compile(
    optimizer=optimizer,
    loss="mean_squared_error",
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )
history = model.fit(x=X_train, y=y_train, batch_size=batch_size, epochs=n_iter)
trained_weight = model.get_weights()[0]
trained_bias = model.get_weights()[1]
epochs = history.epoch
hist = pd.DataFrame(history.history)
rmse = hist["root_mean_squared_error"]

y_pred = model.predict(X_test)

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# Epoch 1/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - loss: 11069.1855 - root_mean_squared_error: 104.6061
# Epoch 2/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 11949.2354 - root_mean_squared_error: 108.2310
# Epoch 3/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 13439.7871 - root_mean_squared_error: 115.7662
# Epoch 4/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 11134.8984 - root_mean_squared_error: 105.1332
# Epoch 5/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 9285.1777 - root_mean_squared_error: 95.7581
# Epoch 6/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 12408.8115 - root_mean_squared_error: 111.1323
# Epoch 7/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 12220.2666 - root_mean_squared_error: 110.3619
# Epoch 8/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 10690.9941 - root_mean_squared_error: 102.7250
# Epoch 9/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - loss: 9753.9590 - root_mean_squared_error: 98.3458
# Epoch 10/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 14750.2070 - root_mean_squared_error: 121.0029
# Epoch 11/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 14421.4941 - root_mean_squared_error: 119.0826
# Epoch 12/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 12177.6729 - root_mean_squared_error: 109.7224
# Epoch 13/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 351us/step - loss: 11719.7520 - root_mean_squared_error: 107.8779
# Epoch 14/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 11732.3193 - root_mean_squared_error: 108.1556
# Epoch 15/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 10538.0918 - root_mean_squared_error: 101.9671
# Epoch 16/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 11254.1709 - root_mean_squared_error: 105.3935
# Epoch 17/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 9005.7881 - root_mean_squared_error: 94.5139
# Epoch 18/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 13047.9219 - root_mean_squared_error: 113.9301
# Epoch 19/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 9050.1152 - root_mean_squared_error: 94.5972
# Epoch 20/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 9600.6895 - root_mean_squared_error: 97.4422
# Epoch 21/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 13223.5215 - root_mean_squared_error: 113.8558
# Epoch 22/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 9840.3096 - root_mean_squared_error: 98.8621
# Epoch 23/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 11523.2920 - root_mean_squared_error: 106.9883
# Epoch 24/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 11014.3799 - root_mean_squared_error: 104.4399
# Epoch 25/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 11183.4678 - root_mean_squared_error: 105.4073
# Epoch 26/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 10327.7354 - root_mean_squared_error: 101.2628
# Epoch 27/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 10285.8057 - root_mean_squared_error: 101.0394
# Epoch 28/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 8164.6021 - root_mean_squared_error: 90.1908
# Epoch 29/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 9279.9297 - root_mean_squared_error: 96.1382
# Epoch 30/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 9429.5400 - root_mean_squared_error: 96.4622
# Epoch 31/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 8082.6436 - root_mean_squared_error: 89.2211
# Epoch 32/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 9350.6406 - root_mean_squared_error: 96.5888
# Epoch 33/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - loss: 9640.7568 - root_mean_squared_error: 97.9869
# Epoch 34/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 8821.4229 - root_mean_squared_error: 93.7431
# Epoch 35/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - loss: 9104.2109 - root_mean_squared_error: 95.3328
# Epoch 36/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 9108.8398 - root_mean_squared_error: 94.4781
# Epoch 37/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 9717.5361 - root_mean_squared_error: 98.2729
# Epoch 38/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 9435.3945 - root_mean_squared_error: 96.2105
# Epoch 39/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 8700.9307 - root_mean_squared_error: 93.0811
# Epoch 40/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 10319.2559 - root_mean_squared_error: 101.4855
# Epoch 41/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 11217.6514 - root_mean_squared_error: 104.9550
# Epoch 42/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - loss: 7413.3477 - root_mean_squared_error: 85.1353
# Epoch 43/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 10744.0352 - root_mean_squared_error: 102.6683
# Epoch 44/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 8108.3276 - root_mean_squared_error: 88.9504
# Epoch 45/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 8175.3770 - root_mean_squared_error: 89.4358
# Epoch 46/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 7315.0767 - root_mean_squared_error: 84.6773
# Epoch 47/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 10143.4912 - root_mean_squared_error: 99.7244
# Epoch 48/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 7730.0889 - root_mean_squared_error: 87.0695
# Epoch 49/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 6883.0659 - root_mean_squared_error: 82.6883
# Epoch 50/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 8625.4180 - root_mean_squared_error: 92.3418
# Epoch 51/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 8105.6875 - root_mean_squared_error: 89.7434
# Epoch 52/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 4874.2397 - root_mean_squared_error: 67.8705
# Epoch 53/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 7413.7427 - root_mean_squared_error: 85.7097
# Epoch 54/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 7817.0513 - root_mean_squared_error: 87.9848
# Epoch 55/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 7447.1025 - root_mean_squared_error: 86.1872
# Epoch 56/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 9916.2920 - root_mean_squared_error: 99.2885
# Epoch 57/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 5617.3525 - root_mean_squared_error: 72.8607
# Epoch 58/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 8660.1113 - root_mean_squared_error: 92.8876
# Epoch 59/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - loss: 9072.0938 - root_mean_squared_error: 95.0486
# Epoch 60/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 6410.8184 - root_mean_squared_error: 79.7845
# Epoch 61/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - loss: 6792.9570 - root_mean_squared_error: 81.6080
# Epoch 62/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 6315.3462 - root_mean_squared_error: 78.8397
# Epoch 63/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 8607.1328 - root_mean_squared_error: 92.2828
# Epoch 64/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 353us/step - loss: 8341.9785 - root_mean_squared_error: 90.8871
# Epoch 65/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 7669.6973 - root_mean_squared_error: 87.4791
# Epoch 66/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 347us/step - loss: 6493.8940 - root_mean_squared_error: 79.8295
# Epoch 67/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 7678.6177 - root_mean_squared_error: 87.4663
# Epoch 68/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 7617.1045 - root_mean_squared_error: 87.1728
# Epoch 69/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 7488.4497 - root_mean_squared_error: 86.4282
# Epoch 70/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 7850.4995 - root_mean_squared_error: 88.5170
# Epoch 71/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 6048.9102 - root_mean_squared_error: 77.3602
# Epoch 72/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 8957.5273 - root_mean_squared_error: 93.7623
# Epoch 73/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 7894.5684 - root_mean_squared_error: 88.4023
# Epoch 74/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 7151.6807 - root_mean_squared_error: 84.2578
# Epoch 75/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 7036.6040 - root_mean_squared_error: 83.7762
# Epoch 76/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 6141.6426 - root_mean_squared_error: 77.4578
# Epoch 77/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 6021.7251 - root_mean_squared_error: 76.8604
# Epoch 78/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 5653.7173 - root_mean_squared_error: 74.6483
# Epoch 79/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 5785.0386 - root_mean_squared_error: 75.5613
# Epoch 80/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 6100.7080 - root_mean_squared_error: 77.7491
# Epoch 81/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - loss: 6883.9888 - root_mean_squared_error: 82.7299
# Epoch 82/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 5711.3931 - root_mean_squared_error: 75.1056
# Epoch 83/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 5786.6650 - root_mean_squared_error: 75.8291
# Epoch 84/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 7116.9868 - root_mean_squared_error: 84.1416
# Epoch 85/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 6152.7808 - root_mean_squared_error: 78.2758
# Epoch 86/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 7036.9141 - root_mean_squared_error: 83.2505
# Epoch 87/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 6897.2915 - root_mean_squared_error: 82.8036
# Epoch 88/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - loss: 5653.1118 - root_mean_squared_error: 74.9708
# Epoch 89/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 5777.1191 - root_mean_squared_error: 75.2533
# Epoch 90/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 7327.5044 - root_mean_squared_error: 84.8612
# Epoch 91/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - loss: 6090.5542 - root_mean_squared_error: 77.9760
# Epoch 92/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 5474.0400 - root_mean_squared_error: 73.7171
# Epoch 93/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 5674.4873 - root_mean_squared_error: 74.6345
# Epoch 94/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 6259.1348 - root_mean_squared_error: 78.9709
# Epoch 95/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 5471.7104 - root_mean_squared_error: 73.6469
# Epoch 96/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 5373.5820 - root_mean_squared_error: 72.9213
# Epoch 97/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 5768.0464 - root_mean_squared_error: 75.9155
# Epoch 98/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 5002.7271 - root_mean_squared_error: 70.1064
# Epoch 99/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 5317.5615 - root_mean_squared_error: 72.8184
# Epoch 100/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5714.5898 - root_mean_squared_error: 75.4985
# Epoch 101/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 5148.7285 - root_mean_squared_error: 71.6154
# Epoch 102/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 5232.9287 - root_mean_squared_error: 72.1853
# Epoch 103/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 6744.3433 - root_mean_squared_error: 81.7494
# Epoch 104/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 467us/step - loss: 5313.4375 - root_mean_squared_error: 72.6707
# Epoch 105/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 5185.4976 - root_mean_squared_error: 71.5638
# Epoch 106/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 5643.5327 - root_mean_squared_error: 74.9796
# Epoch 107/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 4672.8506 - root_mean_squared_error: 68.2113
# Epoch 108/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - loss: 6168.9683 - root_mean_squared_error: 78.0088
# Epoch 109/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 5303.5527 - root_mean_squared_error: 72.5239
# Epoch 110/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 349us/step - loss: 4324.6172 - root_mean_squared_error: 64.4782
# Epoch 111/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 5206.1572 - root_mean_squared_error: 71.8046
# Epoch 112/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 4470.9829 - root_mean_squared_error: 65.7154
# Epoch 113/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 4569.6528 - root_mean_squared_error: 66.3895
# Epoch 114/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 5976.1953 - root_mean_squared_error: 77.0248
# Epoch 115/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 5235.1055 - root_mean_squared_error: 71.9539
# Epoch 116/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 5419.8911 - root_mean_squared_error: 73.5008
# Epoch 117/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4203.7065 - root_mean_squared_error: 64.6967
# Epoch 118/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 4269.1289 - root_mean_squared_error: 65.0388
# Epoch 119/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 5261.9756 - root_mean_squared_error: 72.3603
# Epoch 120/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 4986.8525 - root_mean_squared_error: 70.4674
# Epoch 121/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 4074.9421 - root_mean_squared_error: 62.9642
# Epoch 122/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 4874.9580 - root_mean_squared_error: 69.5743
# Epoch 123/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 4534.1372 - root_mean_squared_error: 67.1611
# Epoch 124/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - loss: 3758.0139 - root_mean_squared_error: 60.8105
# Epoch 125/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 4208.2246 - root_mean_squared_error: 64.2952
# Epoch 126/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 5547.9849 - root_mean_squared_error: 73.8543
# Epoch 127/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - loss: 4296.9688 - root_mean_squared_error: 65.2777
# Epoch 128/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 3862.0593 - root_mean_squared_error: 61.7853
# Epoch 129/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 4409.8247 - root_mean_squared_error: 66.1969
# Epoch 130/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 5103.9463 - root_mean_squared_error: 70.9780
# Epoch 131/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 4502.0581 - root_mean_squared_error: 66.9794
# Epoch 132/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 4738.4248 - root_mean_squared_error: 68.5341
# Epoch 133/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 4173.4146 - root_mean_squared_error: 64.5166
# Epoch 134/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 3712.7078 - root_mean_squared_error: 60.2745
# Epoch 135/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 4174.7529 - root_mean_squared_error: 64.5134
# Epoch 136/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 3710.5244 - root_mean_squared_error: 60.4696
# Epoch 137/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 4243.6621 - root_mean_squared_error: 65.0390
# Epoch 138/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 4695.2090 - root_mean_squared_error: 68.1765
# Epoch 139/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 3493.9282 - root_mean_squared_error: 58.8008
# Epoch 140/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 3421.3394 - root_mean_squared_error: 57.6583
# Epoch 141/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 3367.7488 - root_mean_squared_error: 57.8637
# Epoch 142/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 3508.9153 - root_mean_squared_error: 58.8682
# Epoch 143/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 3437.1692 - root_mean_squared_error: 58.3475
# Epoch 144/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 3748.4326 - root_mean_squared_error: 60.5529
# Epoch 145/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 3901.8801 - root_mean_squared_error: 61.4366
# Epoch 146/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 4038.6162 - root_mean_squared_error: 63.1381
# Epoch 147/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - loss: 3051.7466 - root_mean_squared_error: 55.0941
# Epoch 148/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 4143.0547 - root_mean_squared_error: 64.1164
# Epoch 149/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - loss: 3765.7085 - root_mean_squared_error: 61.2685
# Epoch 150/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 3050.3257 - root_mean_squared_error: 54.3209
# Epoch 151/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 2923.1255 - root_mean_squared_error: 53.4376
# Epoch 152/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 2830.1526 - root_mean_squared_error: 52.3644
# Epoch 153/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 3727.5820 - root_mean_squared_error: 60.9937
# Epoch 154/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 3122.9048 - root_mean_squared_error: 55.7819
# Epoch 155/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 2480.8394 - root_mean_squared_error: 49.1832
# Epoch 156/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 3327.0171 - root_mean_squared_error: 57.3850
# Epoch 157/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 3001.2075 - root_mean_squared_error: 54.6489
# Epoch 158/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 355us/step - loss: 3234.7539 - root_mean_squared_error: 56.7766
# Epoch 159/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - loss: 2722.8159 - root_mean_squared_error: 51.8886
# Epoch 160/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 3180.0796 - root_mean_squared_error: 56.3136
# Epoch 161/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 3553.9304 - root_mean_squared_error: 59.5193
# Epoch 162/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 2417.0479 - root_mean_squared_error: 48.8668
# Epoch 163/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 2960.6851 - root_mean_squared_error: 54.3653
# Epoch 164/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 2764.9089 - root_mean_squared_error: 52.0157
# Epoch 165/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 3192.8191 - root_mean_squared_error: 56.0020
# Epoch 166/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 3104.4492 - root_mean_squared_error: 55.6498
# Epoch 167/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 3144.3374 - root_mean_squared_error: 55.9150
# Epoch 168/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - loss: 2411.9709 - root_mean_squared_error: 48.4381
# Epoch 169/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - loss: 2424.1934 - root_mean_squared_error: 49.0628
# Epoch 170/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 2625.9153 - root_mean_squared_error: 51.1711
# Epoch 171/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 2679.2495 - root_mean_squared_error: 51.6427
# Epoch 172/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 2634.6799 - root_mean_squared_error: 51.1524
# Epoch 173/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - loss: 3050.8706 - root_mean_squared_error: 55.0554
# Epoch 174/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 2464.5649 - root_mean_squared_error: 49.5198
# Epoch 175/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - loss: 2643.4243 - root_mean_squared_error: 51.2624
# Epoch 176/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 2854.5518 - root_mean_squared_error: 53.0912
# Epoch 177/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 2744.0034 - root_mean_squared_error: 52.1480
# Epoch 178/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 2919.3469 - root_mean_squared_error: 53.9179
# Epoch 179/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 3093.1208 - root_mean_squared_error: 55.0798
# Epoch 180/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 2302.3423 - root_mean_squared_error: 47.5644
# Epoch 181/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 2552.7576 - root_mean_squared_error: 50.4715
# Epoch 182/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 2559.4841 - root_mean_squared_error: 50.1312
# Epoch 183/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 2219.6714 - root_mean_squared_error: 46.8081
# Epoch 184/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 1715.1146 - root_mean_squared_error: 40.8432
# Epoch 185/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 2382.2827 - root_mean_squared_error: 48.4359
# Epoch 186/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 2108.0513 - root_mean_squared_error: 45.7011
# Epoch 187/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 2148.1848 - root_mean_squared_error: 46.2911
# Epoch 188/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 1988.2307 - root_mean_squared_error: 44.5040
# Epoch 189/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 2186.3865 - root_mean_squared_error: 46.6914
# Epoch 190/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 2393.1738 - root_mean_squared_error: 48.7706
# Epoch 191/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 2030.5171 - root_mean_squared_error: 45.0259
# Epoch 192/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - loss: 1609.7147 - root_mean_squared_error: 39.6537
# Epoch 193/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 2392.7344 - root_mean_squared_error: 48.7297
# Epoch 194/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 2089.1616 - root_mean_squared_error: 45.5864
# Epoch 195/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 2293.6218 - root_mean_squared_error: 47.7418
# Epoch 196/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 2527.3850 - root_mean_squared_error: 50.0925
# Epoch 197/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 530us/step - loss: 2103.2942 - root_mean_squared_error: 45.7849
# Epoch 198/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 1617.0813 - root_mean_squared_error: 39.8018
# Epoch 199/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 1766.2649 - root_mean_squared_error: 41.8562
# Epoch 200/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 1776.3518 - root_mean_squared_error: 41.8633
# Epoch 201/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 2214.4666 - root_mean_squared_error: 46.7841
# Epoch 202/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 1733.2480 - root_mean_squared_error: 41.5089
# Epoch 203/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 1637.3420 - root_mean_squared_error: 40.0421
# Epoch 204/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 1513.3134 - root_mean_squared_error: 38.4956
# Epoch 205/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 1879.3165 - root_mean_squared_error: 43.0839
# Epoch 206/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 1612.9552 - root_mean_squared_error: 40.0526
# Epoch 207/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 1608.8459 - root_mean_squared_error: 39.9990
# Epoch 208/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 1801.5798 - root_mean_squared_error: 42.1856
# Epoch 209/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 1660.3099 - root_mean_squared_error: 40.3860
# Epoch 210/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 1696.7886 - root_mean_squared_error: 41.0661
# Epoch 211/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 1637.9658 - root_mean_squared_error: 40.2188
# Epoch 212/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 1667.6254 - root_mean_squared_error: 40.5760
# Epoch 213/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 1567.5906 - root_mean_squared_error: 39.5099
# Epoch 214/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 1425.1104 - root_mean_squared_error: 37.3812
# Epoch 215/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 1393.9740 - root_mean_squared_error: 37.2890
# Epoch 216/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 1362.4376 - root_mean_squared_error: 36.5718
# Epoch 217/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 1562.3568 - root_mean_squared_error: 39.4003
# Epoch 218/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 1393.8284 - root_mean_squared_error: 37.2682
# Epoch 219/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 1365.8434 - root_mean_squared_error: 36.7780
# Epoch 220/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 1479.9059 - root_mean_squared_error: 38.2314
# Epoch 221/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 1391.3445 - root_mean_squared_error: 37.1680
# Epoch 222/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 1261.6366 - root_mean_squared_error: 35.4439
# Epoch 223/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 1435.6440 - root_mean_squared_error: 37.8238
# Epoch 224/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1134.1505 - root_mean_squared_error: 33.3475
# Epoch 225/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 1352.6134 - root_mean_squared_error: 36.6855
# Epoch 226/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 1252.7020 - root_mean_squared_error: 35.2617
# Epoch 227/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 1433.5681 - root_mean_squared_error: 37.7473
# Epoch 228/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 1318.4221 - root_mean_squared_error: 36.1582
# Epoch 229/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 1215.5837 - root_mean_squared_error: 34.7800
# Epoch 230/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 1209.1434 - root_mean_squared_error: 34.6902
# Epoch 231/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 1207.4299 - root_mean_squared_error: 34.6614
# Epoch 232/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 1262.7622 - root_mean_squared_error: 35.1282
# Epoch 233/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 1109.7325 - root_mean_squared_error: 32.9162
# Epoch 234/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 1076.0258 - root_mean_squared_error: 32.7531
# Epoch 235/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 937.2731 - root_mean_squared_error: 30.5554
# Epoch 236/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 1016.6860 - root_mean_squared_error: 31.6373
# Epoch 237/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 1002.4692 - root_mean_squared_error: 31.6342
# Epoch 238/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 1181.8093 - root_mean_squared_error: 34.2135
# Epoch 239/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 1018.3894 - root_mean_squared_error: 31.8387
# Epoch 240/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 1220.3359 - root_mean_squared_error: 34.7066
# Epoch 241/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 1104.1130 - root_mean_squared_error: 33.1750
# Epoch 242/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 973.4524 - root_mean_squared_error: 31.1817
# Epoch 243/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 866.8064 - root_mean_squared_error: 29.3617
# Epoch 244/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 776.0571 - root_mean_squared_error: 27.5465
# Epoch 245/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 964.8728 - root_mean_squared_error: 31.0254
# Epoch 246/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 854.6327 - root_mean_squared_error: 29.1063
# Epoch 247/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 753.3870 - root_mean_squared_error: 27.1388
# Epoch 248/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 935.2746 - root_mean_squared_error: 30.5251
# Epoch 249/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 856.4991 - root_mean_squared_error: 29.1299
# Epoch 250/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 837.5462 - root_mean_squared_error: 28.8997
# Epoch 251/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 627.4411 - root_mean_squared_error: 24.7334
# Epoch 252/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 716.3957 - root_mean_squared_error: 26.5119
# Epoch 253/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 875.1206 - root_mean_squared_error: 29.4181
# Epoch 254/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - loss: 826.4613 - root_mean_squared_error: 28.5912
# Epoch 255/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 748.5331 - root_mean_squared_error: 27.3041
# Epoch 256/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 344us/step - loss: 735.7515 - root_mean_squared_error: 27.0644
# Epoch 257/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 609.2688 - root_mean_squared_error: 24.4444
# Epoch 258/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 697.1960 - root_mean_squared_error: 26.2949
# Epoch 259/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 630.9996 - root_mean_squared_error: 25.0686
# Epoch 260/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 667.2617 - root_mean_squared_error: 25.7659
# Epoch 261/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 553.7083 - root_mean_squared_error: 23.4312
# Epoch 262/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 725.3928 - root_mean_squared_error: 26.8397
# Epoch 263/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 722.1412 - root_mean_squared_error: 26.7688
# Epoch 264/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 706.6459 - root_mean_squared_error: 26.5181
# Epoch 265/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 596.1936 - root_mean_squared_error: 24.3025
# Epoch 266/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 614.8730 - root_mean_squared_error: 24.5881
# Epoch 267/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 643.8096 - root_mean_squared_error: 25.3104
# Epoch 268/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 457.9097 - root_mean_squared_error: 21.3563
# Epoch 269/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 482.1465 - root_mean_squared_error: 21.8227
# Epoch 270/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 458.9524 - root_mean_squared_error: 21.2082
# Epoch 271/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 509.6371 - root_mean_squared_error: 22.5205
# Epoch 272/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 568.7689 - root_mean_squared_error: 23.8016
# Epoch 273/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - loss: 490.7578 - root_mean_squared_error: 22.0295
# Epoch 274/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 550.2189 - root_mean_squared_error: 23.3951
# Epoch 275/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 476.8618 - root_mean_squared_error: 21.7315
# Epoch 276/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 561.2507 - root_mean_squared_error: 23.4934
# Epoch 277/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 417.0873 - root_mean_squared_error: 20.2743
# Epoch 278/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 470.9078 - root_mean_squared_error: 21.3160
# Epoch 279/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 544.2079 - root_mean_squared_error: 23.1149
# Epoch 280/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 535.5551 - root_mean_squared_error: 23.0418
# Epoch 281/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 416.2867 - root_mean_squared_error: 20.2772
# Epoch 282/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - loss: 366.2843 - root_mean_squared_error: 18.9904
# Epoch 283/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 419.0285 - root_mean_squared_error: 20.3769
# Epoch 284/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 442.8181 - root_mean_squared_error: 20.9808
# Epoch 285/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 343.5581 - root_mean_squared_error: 18.3117
# Epoch 286/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - loss: 342.4680 - root_mean_squared_error: 18.4685
# Epoch 287/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 385.2306 - root_mean_squared_error: 19.5472
# Epoch 288/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 349.8506 - root_mean_squared_error: 18.6662
# Epoch 289/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - loss: 367.5641 - root_mean_squared_error: 19.1367
# Epoch 290/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 267.2503 - root_mean_squared_error: 16.2279
# Epoch 291/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 278.7547 - root_mean_squared_error: 16.5728
# Epoch 292/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 285.4235 - root_mean_squared_error: 16.7585
# Epoch 293/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - loss: 292.1694 - root_mean_squared_error: 16.8836
# Epoch 294/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 401.8152 - root_mean_squared_error: 19.7928
# Epoch 295/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 319.0504 - root_mean_squared_error: 17.7504
# Epoch 296/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 256.2673 - root_mean_squared_error: 15.9062
# Epoch 297/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 322.4761 - root_mean_squared_error: 17.9029
# Epoch 298/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 235.3288 - root_mean_squared_error: 15.2604
# Epoch 299/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 240.4585 - root_mean_squared_error: 15.2290
# Epoch 300/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - loss: 239.5571 - root_mean_squared_error: 15.3604
# Epoch 301/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 190.1745 - root_mean_squared_error: 13.6279
# Epoch 302/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 245.6758 - root_mean_squared_error: 15.6455
# Epoch 303/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 235.0326 - root_mean_squared_error: 15.3019
# Epoch 304/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 227.0628 - root_mean_squared_error: 15.0313
# Epoch 305/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 258.0316 - root_mean_squared_error: 16.0258
# Epoch 306/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 233.2599 - root_mean_squared_error: 15.2202
# Epoch 307/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 228.0905 - root_mean_squared_error: 14.8913
# Epoch 308/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 213.0864 - root_mean_squared_error: 14.5626
# Epoch 309/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 343us/step - loss: 188.2243 - root_mean_squared_error: 13.6953
# Epoch 310/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 234.5509 - root_mean_squared_error: 15.1581
# Epoch 311/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 154.4640 - root_mean_squared_error: 12.3494
# Epoch 312/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 168.2504 - root_mean_squared_error: 12.9639
# Epoch 313/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 169.5036 - root_mean_squared_error: 12.9249
# Epoch 314/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 156.2312 - root_mean_squared_error: 12.4181
# Epoch 315/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 153.5688 - root_mean_squared_error: 12.3505
# Epoch 316/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 139.4524 - root_mean_squared_error: 11.6496
# Epoch 317/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 151.9400 - root_mean_squared_error: 12.2000
# Epoch 318/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 141.3754 - root_mean_squared_error: 11.6979
# Epoch 319/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - loss: 152.9350 - root_mean_squared_error: 12.3326
# Epoch 320/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 141.9198 - root_mean_squared_error: 11.8620
# Epoch 321/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 121.9977 - root_mean_squared_error: 11.0011
# Epoch 322/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 126.9611 - root_mean_squared_error: 11.2594
# Epoch 323/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 121.3085 - root_mean_squared_error: 10.9489
# Epoch 324/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 96.9676 - root_mean_squared_error: 9.7815
# Epoch 325/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 118.3843 - root_mean_squared_error: 10.8190
# Epoch 326/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 94.7598 - root_mean_squared_error: 9.6736
# Epoch 327/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 81.0146 - root_mean_squared_error: 8.9383
# Epoch 328/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 102.3811 - root_mean_squared_error: 10.1088
# Epoch 329/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 75.1213 - root_mean_squared_error: 8.5435
# Epoch 330/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 88.6419 - root_mean_squared_error: 9.2721
# Epoch 331/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 97.3331 - root_mean_squared_error: 9.8329
# Epoch 332/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 95.9924 - root_mean_squared_error: 9.7218
# Epoch 333/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 74.7676 - root_mean_squared_error: 8.6333
# Epoch 334/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - loss: 96.8198 - root_mean_squared_error: 9.6681
# Epoch 335/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 102.3810 - root_mean_squared_error: 10.0455
# Epoch 336/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 60.4153 - root_mean_squared_error: 7.6993
# Epoch 337/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 68.1643 - root_mean_squared_error: 8.1633
# Epoch 338/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 60.2332 - root_mean_squared_error: 7.7446
# Epoch 339/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 54.3562 - root_mean_squared_error: 7.3510
# Epoch 340/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 63.7537 - root_mean_squared_error: 7.9410
# Epoch 341/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 58.5757 - root_mean_squared_error: 7.5969
# Epoch 342/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 67.1141 - root_mean_squared_error: 8.1595
# Epoch 343/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 65.5903 - root_mean_squared_error: 8.0663
# Epoch 344/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 60.8010 - root_mean_squared_error: 7.7830
# Epoch 345/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 44.2389 - root_mean_squared_error: 6.6352
# Epoch 346/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - loss: 43.6170 - root_mean_squared_error: 6.5862
# Epoch 347/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 52.6429 - root_mean_squared_error: 7.2294
# Epoch 348/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 38.9502 - root_mean_squared_error: 6.2046
# Epoch 349/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 36.5394 - root_mean_squared_error: 6.0167
# Epoch 350/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 39.4107 - root_mean_squared_error: 6.2645
# Epoch 351/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 29.9354 - root_mean_squared_error: 5.4104
# Epoch 352/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - loss: 43.1059 - root_mean_squared_error: 6.5479
# Epoch 353/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 27.9839 - root_mean_squared_error: 5.2729
# Epoch 354/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 37.2054 - root_mean_squared_error: 6.0785
# Epoch 355/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 35.5653 - root_mean_squared_error: 5.9422
# Epoch 356/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 24.1087 - root_mean_squared_error: 4.8764
# Epoch 357/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 23.6523 - root_mean_squared_error: 4.8548
# Epoch 358/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 27.8274 - root_mean_squared_error: 5.2184
# Epoch 359/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 22.2677 - root_mean_squared_error: 4.6737
# Epoch 360/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 31.9537 - root_mean_squared_error: 5.5385
# Epoch 361/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 22.9824 - root_mean_squared_error: 4.7428
# Epoch 362/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 27.1706 - root_mean_squared_error: 5.1929
# Epoch 363/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 28.0023 - root_mean_squared_error: 5.2629
# Epoch 364/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 20.3180 - root_mean_squared_error: 4.4920
# Epoch 365/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 15.0407 - root_mean_squared_error: 3.7831
# Epoch 366/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 17.6862 - root_mean_squared_error: 4.1843
# Epoch 367/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 17.5260 - root_mean_squared_error: 4.1661
# Epoch 368/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 15.7115 - root_mean_squared_error: 3.9302
# Epoch 369/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 17.9827 - root_mean_squared_error: 4.2257
# Epoch 370/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 14.3587 - root_mean_squared_error: 3.7671
# Epoch 371/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 14.4222 - root_mean_squared_error: 3.7612
# Epoch 372/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - loss: 14.3613 - root_mean_squared_error: 3.7676
# Epoch 373/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 13.6974 - root_mean_squared_error: 3.6933
# Epoch 374/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 15.3240 - root_mean_squared_error: 3.8837
# Epoch 375/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 12.7246 - root_mean_squared_error: 3.5143
# Epoch 376/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 10.5287 - root_mean_squared_error: 3.2364
# Epoch 377/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 12.8590 - root_mean_squared_error: 3.5696
# Epoch 378/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 13.7275 - root_mean_squared_error: 3.6625
# Epoch 379/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 7.8569 - root_mean_squared_error: 2.7206
# Epoch 380/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 10.2300 - root_mean_squared_error: 3.1837
# Epoch 381/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - loss: 7.8082 - root_mean_squared_error: 2.7875
# Epoch 382/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 11.2200 - root_mean_squared_error: 3.3361
# Epoch 383/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 9.3388 - root_mean_squared_error: 3.0434
# Epoch 384/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 6.7866 - root_mean_squared_error: 2.5891
# Epoch 385/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 6.6505 - root_mean_squared_error: 2.5333
# Epoch 386/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 7.2172 - root_mean_squared_error: 2.6791
# Epoch 387/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 8.3380 - root_mean_squared_error: 2.8754
# Epoch 388/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 8.8807 - root_mean_squared_error: 2.9650
# Epoch 389/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 5.8031 - root_mean_squared_error: 2.3943
# Epoch 390/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 6.5961 - root_mean_squared_error: 2.5414
# Epoch 391/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 6.0911 - root_mean_squared_error: 2.4506
# Epoch 392/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 5.5675 - root_mean_squared_error: 2.3513
# Epoch 393/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 6.1391 - root_mean_squared_error: 2.4510
# Epoch 394/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 5.4274 - root_mean_squared_error: 2.3215
# Epoch 395/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 5.9479 - root_mean_squared_error: 2.4205
# Epoch 396/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 4.4519 - root_mean_squared_error: 2.0991
# Epoch 397/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 5.9225 - root_mean_squared_error: 2.4167
# Epoch 398/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - loss: 5.1052 - root_mean_squared_error: 2.2385
# Epoch 399/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 6.2337 - root_mean_squared_error: 2.4908
# Epoch 400/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 4.9661 - root_mean_squared_error: 2.2221
# Epoch 401/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 4.7064 - root_mean_squared_error: 2.1545
# Epoch 402/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 5.5856 - root_mean_squared_error: 2.3531
# Epoch 403/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 4.3483 - root_mean_squared_error: 2.0506
# Epoch 404/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 4.5871 - root_mean_squared_error: 2.1315
# Epoch 405/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 3.6797 - root_mean_squared_error: 1.9046
# Epoch 406/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 5.0874 - root_mean_squared_error: 2.2497
# Epoch 407/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - loss: 5.3712 - root_mean_squared_error: 2.3033
# Epoch 408/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - loss: 4.1923 - root_mean_squared_error: 2.0304
# Epoch 409/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 4.9007 - root_mean_squared_error: 2.2068
# Epoch 410/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 4.4465 - root_mean_squared_error: 2.0988
# Epoch 411/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 4.4324 - root_mean_squared_error: 2.0975
# Epoch 412/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 4.6305 - root_mean_squared_error: 2.1461
# Epoch 413/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 4.0568 - root_mean_squared_error: 2.0080
# Epoch 414/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 4.9838 - root_mean_squared_error: 2.2233
# Epoch 415/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 4.0131 - root_mean_squared_error: 1.9923
# Epoch 416/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 4.2839 - root_mean_squared_error: 2.0640
# Epoch 417/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 4.0219 - root_mean_squared_error: 1.9904
# Epoch 418/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 5.0593 - root_mean_squared_error: 2.2396
# Epoch 419/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 3.3990 - root_mean_squared_error: 1.8282
# Epoch 420/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 5.2291 - root_mean_squared_error: 2.2799
# Epoch 421/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 4.1351 - root_mean_squared_error: 2.0157
# Epoch 422/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - loss: 3.2696 - root_mean_squared_error: 1.7806
# Epoch 423/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 4.8962 - root_mean_squared_error: 2.2081
# Epoch 424/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - loss: 4.4615 - root_mean_squared_error: 2.0957
# Epoch 425/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 4.1359 - root_mean_squared_error: 2.0314
# Epoch 426/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 3.7706 - root_mean_squared_error: 1.9231
# Epoch 427/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 4.0083 - root_mean_squared_error: 1.9810
# Epoch 428/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 4.9166 - root_mean_squared_error: 2.1980
# Epoch 429/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - loss: 4.4824 - root_mean_squared_error: 2.1104
# Epoch 430/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 4.2863 - root_mean_squared_error: 2.0511
# Epoch 431/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - loss: 4.0737 - root_mean_squared_error: 2.0106
# Epoch 432/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 4.8549 - root_mean_squared_error: 2.1964
# Epoch 433/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - loss: 3.4650 - root_mean_squared_error: 1.8476
# Epoch 434/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 5.0806 - root_mean_squared_error: 2.2308
# Epoch 435/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 3.6503 - root_mean_squared_error: 1.9065
# Epoch 436/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 3.1103 - root_mean_squared_error: 1.7439
# Epoch 437/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 3.7451 - root_mean_squared_error: 1.9278
# Epoch 438/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 4.4212 - root_mean_squared_error: 2.0969
# Epoch 439/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 4.9161 - root_mean_squared_error: 2.1880
# Epoch 440/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 5.1009 - root_mean_squared_error: 2.2537
# Epoch 441/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3513 - root_mean_squared_error: 2.0783
# Epoch 442/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - loss: 4.4419 - root_mean_squared_error: 2.1014
# Epoch 443/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - loss: 4.4079 - root_mean_squared_error: 2.0890
# Epoch 444/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 3.6651 - root_mean_squared_error: 1.8638
# Epoch 445/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - loss: 3.3473 - root_mean_squared_error: 1.8180
# Epoch 446/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 4.3173 - root_mean_squared_error: 2.0679
# Epoch 447/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 3.2294 - root_mean_squared_error: 1.7784
# Epoch 448/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - loss: 5.2734 - root_mean_squared_error: 2.2751
# Epoch 449/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 3.4109 - root_mean_squared_error: 1.8257
# Epoch 450/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 3.7572 - root_mean_squared_error: 1.9223
# Epoch 451/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - loss: 4.1627 - root_mean_squared_error: 2.0312
# Epoch 452/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 3.4350 - root_mean_squared_error: 1.8497
# Epoch 453/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - loss: 5.9067 - root_mean_squared_error: 2.3857
# Epoch 454/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - loss: 3.3916 - root_mean_squared_error: 1.8239
# Epoch 455/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 5.4837 - root_mean_squared_error: 2.3054
# Epoch 456/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - loss: 3.8581 - root_mean_squared_error: 1.9586
# Epoch 457/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - loss: 4.5438 - root_mean_squared_error: 2.1292
# Epoch 458/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 4.2812 - root_mean_squared_error: 2.0537
# Epoch 459/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - loss: 4.0519 - root_mean_squared_error: 2.0108
# Epoch 460/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - loss: 4.9046 - root_mean_squared_error: 2.1669
# Epoch 461/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 5.2554 - root_mean_squared_error: 2.2604
# Epoch 462/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 4.2117 - root_mean_squared_error: 2.0310
# Epoch 463/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 4.4994 - root_mean_squared_error: 2.1104
# Epoch 464/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 4.0419 - root_mean_squared_error: 2.0075
# Epoch 465/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 6.5389 - root_mean_squared_error: 2.4785
# Epoch 466/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - loss: 4.5302 - root_mean_squared_error: 2.1237
# Epoch 467/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - loss: 3.7077 - root_mean_squared_error: 1.9118
# Epoch 468/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 4.1307 - root_mean_squared_error: 2.0281
# Epoch 469/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - loss: 4.3778 - root_mean_squared_error: 2.0778
# Epoch 470/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 4.2273 - root_mean_squared_error: 2.0265
# Epoch 471/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 5.2025 - root_mean_squared_error: 2.2382
# Epoch 472/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - loss: 3.4035 - root_mean_squared_error: 1.8066
# Epoch 473/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - loss: 4.6022 - root_mean_squared_error: 2.1276
# Epoch 474/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - loss: 5.8405 - root_mean_squared_error: 2.3895
# Epoch 475/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - loss: 3.8882 - root_mean_squared_error: 1.9524
# Epoch 476/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - loss: 4.2026 - root_mean_squared_error: 2.0413
# Epoch 477/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 4.1864 - root_mean_squared_error: 2.0432
# Epoch 478/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - loss: 6.3159 - root_mean_squared_error: 2.4760
# Epoch 479/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 4.2623 - root_mean_squared_error: 2.0563
# Epoch 480/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 3.2261 - root_mean_squared_error: 1.7689
# Epoch 481/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 5.8626 - root_mean_squared_error: 2.3941
# Epoch 482/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - loss: 3.6065 - root_mean_squared_error: 1.8945
# Epoch 483/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 6.1492 - root_mean_squared_error: 2.3961
# Epoch 484/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - loss: 3.7166 - root_mean_squared_error: 1.9163
# Epoch 485/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 3.3512 - root_mean_squared_error: 1.8133
# Epoch 486/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 4.3761 - root_mean_squared_error: 2.0869
# Epoch 487/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 2.7169 - root_mean_squared_error: 1.6310
# Epoch 488/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - loss: 3.6902 - root_mean_squared_error: 1.9105
# Epoch 489/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - loss: 5.0539 - root_mean_squared_error: 2.2406
# Epoch 490/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 3.9277 - root_mean_squared_error: 1.9784
# Epoch 491/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - loss: 3.5492 - root_mean_squared_error: 1.8705
# Epoch 492/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - loss: 4.0615 - root_mean_squared_error: 2.0068
# Epoch 493/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 4.4174 - root_mean_squared_error: 2.0980
# Epoch 494/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - loss: 5.0247 - root_mean_squared_error: 2.2033
# Epoch 495/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - loss: 4.3743 - root_mean_squared_error: 2.0799
# Epoch 496/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step - loss: 3.8868 - root_mean_squared_error: 1.9654
# Epoch 497/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - loss: 4.0704 - root_mean_squared_error: 1.9967
# Epoch 498/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - loss: 4.2444 - root_mean_squared_error: 2.0528
# Epoch 499/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 4.0605 - root_mean_squared_error: 2.0085
# Epoch 500/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 5.3247 - root_mean_squared_error: 2.2875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Mean squared error: 6.19
# Coefficient of determination: 1.00

# %%
y_surface = model.predict(X_surface)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
