# %% [markdown]
# # Régression Linéaire
#
# [![Index](https://img.shields.io/badge/Index-blue)](../index.ipynb)
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/digillia/Digillia-Colab/blob/main/algorithms/linear-regression.ipynb)
#
# La régression est largement utilisée en statistiques et en science des données pour la modélisation, la prédiction et la compréhension des relations entre des variables, dans des domaines tels que l'économie, la biologie, la finance et bien d'autres.
#
# La régression linéaire permet de modéliser la relation entre une variable dépendante (ou cible) et plusieurs variables indépendantes (ou caractéristiques) en supposant une relation linéaire entre elles. L'objectif est de trouver un modèle linéaire qui minimise l'écart entre les valeurs prédites et les valeurs observées de la variable dépendante.
#
# En régression linéaire multivariée, l'équation prend la forme : $Y = b_0 + b_1X_1 + b_2X_2 + ... + b_nX_n$, où $Y$ représente la variable dépendante, $X_1, X_2, ..., X_n$ sont les variables indépendantes, et $b_0, b_1, b_2, ..., b_n$ sont les coefficients à estimer. Ces coefficients déterminent la contribution de chaque variable indépendante à la prédiction de la variable dépendante.
#
# [![Wikipedia](https://img.shields.io/badge/Wikipedia-lightgrey)](https://en.wikipedia.org/wiki/Linear_regression)

# %%
# Supprimer les commentaires pour installer (requirements.txt)
# !pip3 install -q -U numpy
# !pip3 install -q -U pandas
# !pip3 install -q -U matplotlib
# !pip3 install -q -U scipy
# !pip3 install -q -U statsmodels
# !pip3 install -q -U scikit-learn
# !pip3 install -q -U jax
# !pip3 install -q -U torch
# !pip3 install -q -U tensorflow

# %% [markdown]
# ## Données
#
# Création d'un jeu de données synthétiques:

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

random_state = 42

# Create features and labels
X, y = make_regression(n_samples=100, n_features=2, n_targets=1, noise=2.0, random_state=random_state)

# Create training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)

# Check shapes
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (80, 2) (20, 2) (80,) (20,)

# %% [markdown]
# Visualisation:

# %%
from matplotlib import pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='train')
ax.scatter(X_test[:,0], X_test[:,1], y_test, marker='o', c='b', label='test')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
plt.show()

# %% [markdown]
# Autres données pour visualisation 3D du plan de regression linéaire:

# %%
import numpy as np

# Data for 3D visualization
x1_range = np.linspace(min(X[:, 0]), max(X[:, 0]), 40)
x2_range = np.linspace(min(X[:, 1]), max(X[:, 1]), 40)
x1_values, x2_values = np.meshgrid(x1_range, x2_range)
X_surface = np.column_stack((x1_values.ravel(), x2_values.ravel()))
X_surface
# Out:
# array([[-2.6197451 , -1.98756891],
#        [-2.50420841, -1.98756891],
#        [-2.38867172, -1.98756891],
#        ...,
#        [ 1.65511252,  2.72016917],
#        [ 1.77064921,  2.72016917],
#        [ 1.8861859 ,  2.72016917]])

# %% [markdown]
# ## Régression Linéaire Univariée avec SciPy
#
# > SciPy ne supporte pas la régression multivariée
#
# Docs: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# %%
from scipy.stats import linregress

# linregress du package SciPy ne supporte pas la régression multivariée
# result = linregress(X_train, y_train)

# Deux regressions univariées comme ci-dessous, ne sont pas équivalentes à une regression multivariée (plan multidimensionnel).
# La suite permet seulement d'illustrer un exemple de régression univariée (droite dans un plan).

result0 = linregress(X_train[:,0], y_train)
print(result0)

result1 = linregress(X_train[:,1], y_train)
print(result1)
# Out:
# LinregressResult(slope=np.float64(92.98819197619855), intercept=np.float64(1.285422546227835), rvalue=np.float64(0.7470341322548782), pvalue=np.float64(1.7625012111659697e-15), stderr=np.float64(9.369614334260381), intercept_stderr=np.float64(8.255903002280558))
# LinregressResult(slope=np.float64(79.2081101654435), intercept=np.float64(-12.08164666005461), rvalue=np.float64(0.7129199556487509), pvalue=np.float64(1.1863604632825853e-13), stderr=np.float64(8.82168641024559), intercept_stderr=np.float64(8.60160523568881))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
ax1.scatter(X_train[:,0], y_train, c='r', alpha=0.5)
ax1.plot(X_test[:,0], result0.slope * X_test[:,0] + result0.intercept, c='b', alpha=0.5)
ax1.set(title='Feature 1', xlabel='X1', ylabel='y')
ax2.scatter(X_train[:,1], y_train, c='r', alpha=0.5)
ax2.plot(X_test[:,1], result1.slope * X_test[:,1] + result1.intercept, c='b', alpha=0.5)
ax2.set(title='Feature 2', xlabel='X2', ylabel='y')
plt.show()

# %% [markdown]
# # Régression Linéaire Multivariée avec StatsModels
#
# Docs: https://www.statsmodels.org/dev/generated/statsmodels.regression.linear_model.OLS.html

# %%
import statsmodels.api as sm

# Add constant for intercept
X_train_ = sm.add_constant(X_train)
X_test_ = sm.add_constant(X_test)

# Train and predict
model = sm.OLS(y_train, X_train_).fit()
y_pred = model.predict(X_test_) 

# Show summary
summary = model.summary()
print(summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.070e+05
# Date:                Thu, 12 Dec 2024   Prob (F-statistic):          2.49e-133
# Time:                        18:06:49   Log-Likelihood:                -171.10
# No. Observations:                  80   AIC:                             348.2
# Df Residuals:                      77   BIC:                             355.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0132      0.237      0.056      0.956      -0.459       0.485
# x1            87.4519      0.270    324.398      0.000      86.915      87.989
# x2            73.9953      0.241    307.519      0.000      73.516      74.474
# ==============================================================================
# Omnibus:                        4.408   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                3.662
# Skew:                           0.412   Prob(JB):                        0.160
# Kurtosis:                       3.649   Cond. No.                         1.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_surface_ = sm.add_constant(X_surface)
y_surface = model.predict(X_surface_)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec SciKit-Learn
#
# Docs: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
from sklearn.linear_model import LinearRegression

# Fit the regressor
model = LinearRegression().fit(X_train, y_train)
print(model.coef_, model.intercept_)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# [87.45188282 73.99534523] 0.013190960728634238
# Mean squared error: 6.19
# Coefficient of determination: 1.00

# %%
y_surface = model.predict(X_surface)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec Jax
#
# Docs: https://jax.readthedocs.io/en/latest/

# %%
from jax import grad, jit, device_get
import jax.numpy as jnp

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

# Loss function based on mean squared error (mse)
def loss(w,b,X,y):
  pred = X.dot(w) + b
  return ((pred-y)**2).mean()

# Initialize weights with zeros
Weights = jnp.zeros((X_train.shape[1],1))
bias = 0.

# Learning rate and epochs
l_rate = 0.01
n_iter = 3000

# Gradient functions wrapped with jit function for faster processing
gradW = jit(grad(loss, argnums=0))
gradb = jit(grad(loss, argnums=1))

# Training loop
for _ in range(n_iter):
  dW = gradW(Weights, bias, X_train, y_train_)
  db = gradb(Weights, bias, X_train, y_train_)
  # print(loss(Weights, bias, X_train, y_train_))
  Weights -= dW * l_rate
  bias -= db * l_rate

print(Weights, bias)

# Predictions
y_pred = X_test.dot(Weights) + bias

# Display mse and r2 score
# device_get should prevent ValueError: Input arrays use different devices: cpu, TFRT_CPU_0
print("Mean squared error: %.2f" % mean_squared_error(y_test_, device_get(y_pred)))
print("Coefficient of determination: %.2f" % r2_score(y_test_, device_get(y_pred)))
# Out:
# [[87.45162]
#  [73.99556]] 0.0131549835
# Mean squared error: 6.18
# Coefficient of determination: 1.00

# %%
y_surface = X_surface.dot(Weights) + bias
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec PyTorch
#
# Docs: https://pytorch.org/docs/stable/index.html

# %%
import torch
from torch.autograd import Variable

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

class TorchLR(torch.nn.Module):
    def __init__(self, inputSize, outputSize):
        super(TorchLR, self).__init__()
        self.linear = torch.nn.Linear(inputSize, outputSize, dtype=torch.float64)

    def forward(self, x):
        out = self.linear(x)
        return out
    
# Learning rate and epochs
l_rate = 0.001 
n_iter = 3000

inputDim = X.shape[1]   # takes variable 'x' 
outputDim = 1  # takes variable 'y'
model = TorchLR(inputDim, outputDim)
if torch.cuda.is_available():
    model.cuda()

criterion = torch.nn.MSELoss() 
optimizer = torch.optim.SGD(model.parameters(), lr=l_rate)

# Training loop
for epoch in range(n_iter):
    # Converting inputs and labels to Variable
    if torch.cuda.is_available():
        inputs = Variable(torch.from_numpy(X_train).cuda())
        labels = Variable(torch.from_numpy(y_train_).cuda())
    else:
        inputs = Variable(torch.from_numpy(X_train))
        labels = Variable(torch.from_numpy(y_train_))

    print(inputs.dtype, labels.dtype) 

    # Clear gradient buffers because we don't want any gradient from previous epoch to carry forward, dont want to cummulate gradients
    optimizer.zero_grad()

    # get output from the model, given the inputs
    outputs = model(inputs)

    # get loss for the predicted output
    loss = criterion(outputs, labels)
    
    # get gradients w.r.t to parameters
    loss.backward()

    # update parameters
    optimizer.step()

    print('epoch {}, loss {}'.format(epoch, loss.item()))

# Predictions
with torch.no_grad(): # we don't need gradients in the testing phase
    if torch.cuda.is_available():
        y_pred = model(Variable(torch.from_numpy(X_test).cuda())).cpu().data.numpy()
    else:
        y_pred = model(Variable(torch.from_numpy(X_test))).data.numpy()

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# torch.float64 torch.float64
# epoch 0, loss 11786.02834395917
# torch.float64 torch.float64
# epoch 1, loss 11742.492575298664
# torch.float64 torch.float64
# epoch 2, loss 11699.120912292774
# torch.float64 torch.float64
# epoch 3, loss 11655.912726090752
# torch.float64 torch.float64
# epoch 4, loss 11612.867390284076
# torch.float64 torch.float64
# epoch 5, loss 11569.984280896886
# torch.float64 torch.float64
# epoch 6, loss 11527.26277637641
# torch.float64 torch.float64
# epoch 7, loss 11484.702257583467
# torch.float64 torch.float64
# epoch 8, loss 11442.302107782989
# torch.float64 torch.float64
# epoch 9, loss 11400.061712634575
# torch.float64 torch.float64
# epoch 10, loss 11357.980460183106
# torch.float64 torch.float64
# epoch 11, loss 11316.057740849374
# torch.float64 torch.float64
# epoch 12, loss 11274.292947420752
# torch.float64 torch.float64
# epoch 13, loss 11232.68547504192
# torch.float64 torch.float64
# epoch 14, loss 11191.2347212056
# torch.float64 torch.float64
# epoch 15, loss 11149.94008574334
# torch.float64 torch.float64
# epoch 16, loss 11108.80097081635
# torch.float64 torch.float64
# epoch 17, loss 11067.816780906342
# torch.float64 torch.float64
# epoch 18, loss 11026.98692280644
# torch.float64 torch.float64
# epoch 19, loss 10986.310805612095
# torch.float64 torch.float64
# epoch 20, loss 10945.787840712066
# torch.float64 torch.float64
# epoch 21, loss 10905.41744177941
# torch.float64 torch.float64
# epoch 22, loss 10865.199024762513
# torch.float64 torch.float64
# epoch 23, loss 10825.132007876191
# torch.float64 torch.float64
# epoch 24, loss 10785.21581159277
# torch.float64 torch.float64
# epoch 25, loss 10745.449858633241
# torch.float64 torch.float64
# epoch 26, loss 10705.833573958429
# torch.float64 torch.float64
# epoch 27, loss 10666.36638476023
# torch.float64 torch.float64
# epoch 28, loss 10627.047720452823
# torch.float64 torch.float64
# epoch 29, loss 10587.877012663987
# torch.float64 torch.float64
# epoch 30, loss 10548.8536952264
# torch.float64 torch.float64
# epoch 31, loss 10509.977204168994
# torch.float64 torch.float64
# epoch 32, loss 10471.246977708337
# torch.float64 torch.float64
# epoch 33, loss 10432.662456240063
# torch.float64 torch.float64
# epoch 34, loss 10394.223082330314
# torch.float64 torch.float64
# epoch 35, loss 10355.928300707237
# torch.float64 torch.float64
# epoch 36, loss 10317.7775582525
# torch.float64 torch.float64
# epoch 37, loss 10279.77030399285
# torch.float64 torch.float64
# epoch 38, loss 10241.905989091698
# torch.float64 torch.float64
# epoch 39, loss 10204.184066840739
# torch.float64 torch.float64
# epoch 40, loss 10166.603992651615
# torch.float64 torch.float64
# epoch 41, loss 10129.165224047605
# torch.float64 torch.float64
# epoch 42, loss 10091.86722065532
# torch.float64 torch.float64
# epoch 43, loss 10054.709444196487
# torch.float64 torch.float64
# epoch 44, loss 10017.691358479724
# torch.float64 torch.float64
# epoch 45, loss 9980.81242939235
# torch.float64 torch.float64
# epoch 46, loss 9944.072124892247
# torch.float64 torch.float64
# epoch 47, loss 9907.46991499974
# torch.float64 torch.float64
# epoch 48, loss 9871.005271789512
# torch.float64 torch.float64
# epoch 49, loss 9834.677669382549
# torch.float64 torch.float64
# epoch 50, loss 9798.48658393812
# torch.float64 torch.float64
# epoch 51, loss 9762.431493645792
# torch.float64 torch.float64
# epoch 52, loss 9726.511878717463
# torch.float64 torch.float64
# epoch 53, loss 9690.727221379446
# torch.float64 torch.float64
# epoch 54, loss 9655.07700586457
# torch.float64 torch.float64
# epoch 55, loss 9619.560718404318
# torch.float64 torch.float64
# epoch 56, loss 9584.177847220988
# torch.float64 torch.float64
# epoch 57, loss 9548.927882519902
# torch.float64 torch.float64
# epoch 58, loss 9513.810316481624
# torch.float64 torch.float64
# epoch 59, loss 9478.824643254226
# torch.float64 torch.float64
# epoch 60, loss 9443.970358945588
# torch.float64 torch.float64
# epoch 61, loss 9409.246961615696
# torch.float64 torch.float64
# epoch 62, loss 9374.653951269021
# torch.float64 torch.float64
# epoch 63, loss 9340.190829846875
# torch.float64 torch.float64
# epoch 64, loss 9305.857101219843
# torch.float64 torch.float64
# epoch 65, loss 9271.652271180214
# torch.float64 torch.float64
# epoch 66, loss 9237.575847434453
# torch.float64 torch.float64
# epoch 67, loss 9203.627339595709
# torch.float64 torch.float64
# epoch 68, loss 9169.806259176341
# torch.float64 torch.float64
# epoch 69, loss 9136.112119580484
# torch.float64 torch.float64
# epoch 70, loss 9102.544436096625
# torch.float64 torch.float64
# epoch 71, loss 9069.102725890243
# torch.float64 torch.float64
# epoch 72, loss 9035.786507996443
# torch.float64 torch.float64
# epoch 73, loss 9002.595303312635
# torch.float64 torch.float64
# epoch 74, loss 8969.52863459125
# torch.float64 torch.float64
# epoch 75, loss 8936.586026432464
# torch.float64 torch.float64
# epoch 76, loss 8903.76700527697
# torch.float64 torch.float64
# epoch 77, loss 8871.071099398765
# torch.float64 torch.float64
# epoch 78, loss 8838.497838897973
# torch.float64 torch.float64
# epoch 79, loss 8806.046755693702
# torch.float64 torch.float64
# epoch 80, loss 8773.717383516909
# torch.float64 torch.float64
# epoch 81, loss 8741.509257903313
# torch.float64 torch.float64
# epoch 82, loss 8709.421916186335
# torch.float64 torch.float64
# epoch 83, loss 8677.454897490044
# torch.float64 torch.float64
# epoch 84, loss 8645.607742722163
# torch.float64 torch.float64
# epoch 85, loss 8613.879994567074
# torch.float64 torch.float64
# epoch 86, loss 8582.271197478878
# torch.float64 torch.float64
# epoch 87, loss 8550.780897674445
# torch.float64 torch.float64
# epoch 88, loss 8519.408643126542
# torch.float64 torch.float64
# epoch 89, loss 8488.153983556931
# torch.float64 torch.float64
# epoch 90, loss 8457.01647042955
# torch.float64 torch.float64
# epoch 91, loss 8425.995656943673
# torch.float64 torch.float64
# epoch 92, loss 8395.09109802713
# torch.float64 torch.float64
# epoch 93, loss 8364.30235032954
# torch.float64 torch.float64
# epoch 94, loss 8333.628972215574
# torch.float64 torch.float64
# epoch 95, loss 8303.07052375824
# torch.float64 torch.float64
# epoch 96, loss 8272.6265667322
# torch.float64 torch.float64
# epoch 97, loss 8242.29666460711
# torch.float64 torch.float64
# epoch 98, loss 8212.080382540991
# torch.float64 torch.float64
# epoch 99, loss 8181.977287373619
# torch.float64 torch.float64
# epoch 100, loss 8151.986947619946
# torch.float64 torch.float64
# epoch 101, loss 8122.108933463547
# torch.float64 torch.float64
# epoch 102, loss 8092.342816750097
# torch.float64 torch.float64
# epoch 103, loss 8062.688170980854
# torch.float64 torch.float64
# epoch 104, loss 8033.1445713061985
# torch.float64 torch.float64
# epoch 105, loss 8003.711594519171
# torch.float64 torch.float64
# epoch 106, loss 7974.388819049054
# torch.float64 torch.float64
# epoch 107, loss 7945.175824954966
# torch.float64 torch.float64
# epoch 108, loss 7916.072193919492
# torch.float64 torch.float64
# epoch 109, loss 7887.077509242328
# torch.float64 torch.float64
# epoch 110, loss 7858.191355833957
# torch.float64 torch.float64
# epoch 111, loss 7829.413320209356
# torch.float64 torch.float64
# epoch 112, loss 7800.742990481714
# torch.float64 torch.float64
# epoch 113, loss 7772.179956356182
# torch.float64 torch.float64
# epoch 114, loss 7743.723809123652
# torch.float64 torch.float64
# epoch 115, loss 7715.374141654555
# torch.float64 torch.float64
# epoch 116, loss 7687.13054839268
# torch.float64 torch.float64
# epoch 117, loss 7658.9926253490285
# torch.float64 torch.float64
# epoch 118, loss 7630.959970095681
# torch.float64 torch.float64
# epoch 119, loss 7603.032181759695
# torch.float64 torch.float64
# epoch 120, loss 7575.208861017032
# torch.float64 torch.float64
# epoch 121, loss 7547.489610086492
# torch.float64 torch.float64
# epoch 122, loss 7519.874032723688
# torch.float64 torch.float64
# epoch 123, loss 7492.361734215039
# torch.float64 torch.float64
# epoch 124, loss 7464.952321371777
# torch.float64 torch.float64
# epoch 125, loss 7437.645402524
# torch.float64 torch.float64
# epoch 126, loss 7410.4405875147295
# torch.float64 torch.float64
# epoch 127, loss 7383.337487693987
# torch.float64 torch.float64
# epoch 128, loss 7356.3357159129255
# torch.float64 torch.float64
# epoch 129, loss 7329.434886517937
# torch.float64 torch.float64
# epoch 130, loss 7302.63461534483
# torch.float64 torch.float64
# epoch 131, loss 7275.934519713002
# torch.float64 torch.float64
# epoch 132, loss 7249.334218419634
# torch.float64 torch.float64
# epoch 133, loss 7222.833331733923
# torch.float64 torch.float64
# epoch 134, loss 7196.431481391334
# torch.float64 torch.float64
# epoch 135, loss 7170.12829058786
# torch.float64 torch.float64
# epoch 136, loss 7143.923383974325
# torch.float64 torch.float64
# epoch 137, loss 7117.816387650693
# torch.float64 torch.float64
# epoch 138, loss 7091.806929160407
# torch.float64 torch.float64
# epoch 139, loss 7065.894637484758
# torch.float64 torch.float64
# epoch 140, loss 7040.079143037256
# torch.float64 torch.float64
# epoch 141, loss 7014.360077658037
# torch.float64 torch.float64
# epoch 142, loss 6988.737074608301
# torch.float64 torch.float64
# epoch 143, loss 6963.209768564743
# torch.float64 torch.float64
# epoch 144, loss 6937.777795614046
# torch.float64 torch.float64
# epoch 145, loss 6912.440793247348
# torch.float64 torch.float64
# epoch 146, loss 6887.198400354781
# torch.float64 torch.float64
# epoch 147, loss 6862.050257219989
# torch.float64 torch.float64
# epoch 148, loss 6836.996005514695
# torch.float64 torch.float64
# epoch 149, loss 6812.03528829328
# torch.float64 torch.float64
# epoch 150, loss 6787.167749987374
# torch.float64 torch.float64
# epoch 151, loss 6762.393036400489
# torch.float64 torch.float64
# epoch 152, loss 6737.710794702658
# torch.float64 torch.float64
# epoch 153, loss 6713.120673425097
# torch.float64 torch.float64
# epoch 154, loss 6688.622322454894
# torch.float64 torch.float64
# epoch 155, loss 6664.215393029711
# torch.float64 torch.float64
# epoch 156, loss 6639.899537732509
# torch.float64 torch.float64
# epoch 157, loss 6615.6744104863055
# torch.float64 torch.float64
# epoch 158, loss 6591.539666548933
# torch.float64 torch.float64
# epoch 159, loss 6567.4949625078325
# torch.float64 torch.float64
# epoch 160, loss 6543.53995627486
# torch.float64 torch.float64
# epoch 161, loss 6519.674307081125
# torch.float64 torch.float64
# epoch 162, loss 6495.89767547183
# torch.float64 torch.float64
# epoch 163, loss 6472.209723301143
# torch.float64 torch.float64
# epoch 164, loss 6448.6101137271
# torch.float64 torch.float64
# epoch 165, loss 6425.0985112065
# torch.float64 torch.float64
# epoch 166, loss 6401.674581489844
# torch.float64 torch.float64
# epoch 167, loss 6378.337991616293
# torch.float64 torch.float64
# epoch 168, loss 6355.08840990862
# torch.float64 torch.float64
# epoch 169, loss 6331.9255059682255
# torch.float64 torch.float64
# epoch 170, loss 6308.848950670123
# torch.float64 torch.float64
# epoch 171, loss 6285.858416157987
# torch.float64 torch.float64
# epoch 172, loss 6262.953575839199
# torch.float64 torch.float64
# epoch 173, loss 6240.134104379915
# torch.float64 torch.float64
# epoch 174, loss 6217.399677700148
# torch.float64 torch.float64
# epoch 175, loss 6194.749972968884
# torch.float64 torch.float64
# epoch 176, loss 6172.184668599216
# torch.float64 torch.float64
# epoch 177, loss 6149.703444243472
# torch.float64 torch.float64
# epoch 178, loss 6127.3059807883965
# torch.float64 torch.float64
# epoch 179, loss 6104.991960350328
# torch.float64 torch.float64
# epoch 180, loss 6082.761066270403
# torch.float64 torch.float64
# epoch 181, loss 6060.612983109781
# torch.float64 torch.float64
# epoch 182, loss 6038.54739664489
# torch.float64 torch.float64
# epoch 183, loss 6016.563993862673
# torch.float64 torch.float64
# epoch 184, loss 5994.662462955881
# torch.float64 torch.float64
# epoch 185, loss 5972.8424933183605
# torch.float64 torch.float64
# epoch 186, loss 5951.103775540383
# torch.float64 torch.float64
# epoch 187, loss 5929.446001403956
# torch.float64 torch.float64
# epoch 188, loss 5907.868863878206
# torch.float64 torch.float64
# epoch 189, loss 5886.37205711472
# torch.float64 torch.float64
# epoch 190, loss 5864.955276442956
# torch.float64 torch.float64
# epoch 191, loss 5843.618218365643
# torch.float64 torch.float64
# epoch 192, loss 5822.360580554203
# torch.float64 torch.float64
# epoch 193, loss 5801.182061844201
# torch.float64 torch.float64
# epoch 194, loss 5780.082362230802
# torch.float64 torch.float64
# epoch 195, loss 5759.061182864252
# torch.float64 torch.float64
# epoch 196, loss 5738.11822604538
# torch.float64 torch.float64
# epoch 197, loss 5717.253195221099
# torch.float64 torch.float64
# epoch 198, loss 5696.465794979958
# torch.float64 torch.float64
# epoch 199, loss 5675.755731047674
# torch.float64 torch.float64
# epoch 200, loss 5655.122710282712
# torch.float64 torch.float64
# epoch 201, loss 5634.566440671866
# torch.float64 torch.float64
# epoch 202, loss 5614.0866313258575
# torch.float64 torch.float64
# epoch 203, loss 5593.682992474963
# torch.float64 torch.float64
# epoch 204, loss 5573.355235464647
# torch.float64 torch.float64
# epoch 205, loss 5553.103072751215
# torch.float64 torch.float64
# epoch 206, loss 5532.926217897488
# torch.float64 torch.float64
# epoch 207, loss 5512.824385568488
# torch.float64 torch.float64
# epoch 208, loss 5492.7972915271475
# torch.float64 torch.float64
# epoch 209, loss 5472.844652630024
# torch.float64 torch.float64
# epoch 210, loss 5452.966186823049
# torch.float64 torch.float64
# epoch 211, loss 5433.161613137276
# torch.float64 torch.float64
# epoch 212, loss 5413.430651684657
# torch.float64 torch.float64
# epoch 213, loss 5393.7730236538355
# torch.float64 torch.float64
# epoch 214, loss 5374.188451305939
# torch.float64 torch.float64
# epoch 215, loss 5354.676657970416
# torch.float64 torch.float64
# epoch 216, loss 5335.237368040868
# torch.float64 torch.float64
# epoch 217, loss 5315.870306970903
# torch.float64 torch.float64
# epoch 218, loss 5296.57520127001
# torch.float64 torch.float64
# epoch 219, loss 5277.351778499451
# torch.float64 torch.float64
# epoch 220, loss 5258.199767268152
# torch.float64 torch.float64
# epoch 221, loss 5239.118897228636
# torch.float64 torch.float64
# epoch 222, loss 5220.108899072951
# torch.float64 torch.float64
# epoch 223, loss 5201.169504528629
# torch.float64 torch.float64
# epoch 224, loss 5182.300446354644
# torch.float64 torch.float64
# epoch 225, loss 5163.501458337407
# torch.float64 torch.float64
# epoch 226, loss 5144.772275286755
# torch.float64 torch.float64
# epoch 227, loss 5126.112633031977
# torch.float64 torch.float64
# epoch 228, loss 5107.522268417835
# torch.float64 torch.float64
# epoch 229, loss 5089.000919300618
# torch.float64 torch.float64
# epoch 230, loss 5070.548324544199
# torch.float64 torch.float64
# epoch 231, loss 5052.164224016118
# torch.float64 torch.float64
# epoch 232, loss 5033.84835858367
# torch.float64 torch.float64
# epoch 233, loss 5015.600470110015
# torch.float64 torch.float64
# epoch 234, loss 4997.420301450303
# torch.float64 torch.float64
# epoch 235, loss 4979.307596447814
# torch.float64 torch.float64
# epoch 236, loss 4961.262099930109
# torch.float64 torch.float64
# epoch 237, loss 4943.283557705198
# torch.float64 torch.float64
# epoch 238, loss 4925.3717165577345
# torch.float64 torch.float64
# epoch 239, loss 4907.526324245199
# torch.float64 torch.float64
# epoch 240, loss 4889.747129494127
# torch.float64 torch.float64
# epoch 241, loss 4872.033881996333
# torch.float64 torch.float64
# epoch 242, loss 4854.386332405152
# torch.float64 torch.float64
# epoch 243, loss 4836.804232331704
# torch.float64 torch.float64
# epoch 244, loss 4819.287334341161
# torch.float64 torch.float64
# epoch 245, loss 4801.835391949042
# torch.float64 torch.float64
# epoch 246, loss 4784.448159617508
# torch.float64 torch.float64
# epoch 247, loss 4767.12539275169
# torch.float64 torch.float64
# epoch 248, loss 4749.866847696008
# torch.float64 torch.float64
# epoch 249, loss 4732.672281730527
# torch.float64 torch.float64
# epoch 250, loss 4715.541453067312
# torch.float64 torch.float64
# epoch 251, loss 4698.474120846808
# torch.float64 torch.float64
# epoch 252, loss 4681.470045134221
# torch.float64 torch.float64
# epoch 253, loss 4664.528986915933
# torch.float64 torch.float64
# epoch 254, loss 4647.650708095907
# torch.float64 torch.float64
# epoch 255, loss 4630.834971492126
# torch.float64 torch.float64
# epoch 256, loss 4614.081540833037
# torch.float64 torch.float64
# epoch 257, loss 4597.390180754011
# torch.float64 torch.float64
# epoch 258, loss 4580.7606567938155
# torch.float64 torch.float64
# epoch 259, loss 4564.1927353911
# torch.float64 torch.float64
# epoch 260, loss 4547.6861838809
# torch.float64 torch.float64
# epoch 261, loss 4531.240770491151
# torch.float64 torch.float64
# epoch 262, loss 4514.856264339217
# torch.float64 torch.float64
# epoch 263, loss 4498.532435428433
# torch.float64 torch.float64
# epoch 264, loss 4482.269054644659
# torch.float64 torch.float64
# epoch 265, loss 4466.065893752851
# torch.float64 torch.float64
# epoch 266, loss 4449.922725393641
# torch.float64 torch.float64
# epoch 267, loss 4433.83932307994
# torch.float64 torch.float64
# epoch 268, loss 4417.815461193539
# torch.float64 torch.float64
# epoch 269, loss 4401.850914981736
# torch.float64 torch.float64
# epoch 270, loss 4385.945460553975
# torch.float64 torch.float64
# epoch 271, loss 4370.0988748784885
# torch.float64 torch.float64
# epoch 272, loss 4354.310935778965
# torch.float64 torch.float64
# epoch 273, loss 4338.581421931225
# torch.float64 torch.float64
# epoch 274, loss 4322.910112859904
# torch.float64 torch.float64
# epoch 275, loss 4307.296788935164
# torch.float64 torch.float64
# epoch 276, loss 4291.741231369396
# torch.float64 torch.float64
# epoch 277, loss 4276.243222213958
# torch.float64 torch.float64
# epoch 278, loss 4260.802544355908
# torch.float64 torch.float64
# epoch 279, loss 4245.418981514764
# torch.float64 torch.float64
# epoch 280, loss 4230.0923182392635
# torch.float64 torch.float64
# epoch 281, loss 4214.822339904146
# torch.float64 torch.float64
# epoch 282, loss 4199.608832706943
# torch.float64 torch.float64
# epoch 283, loss 4184.451583664781
# torch.float64 torch.float64
# epoch 284, loss 4169.3503806111985
# torch.float64 torch.float64
# epoch 285, loss 4154.305012192979
# torch.float64 torch.float64
# epoch 286, loss 4139.315267866985
# torch.float64 torch.float64
# epoch 287, loss 4124.380937897016
# torch.float64 torch.float64
# epoch 288, loss 4109.5018133506765
# torch.float64 torch.float64
# epoch 289, loss 4094.6776860962477
# torch.float64 torch.float64
# epoch 290, loss 4079.908348799587
# torch.float64 torch.float64
# epoch 291, loss 4065.193594921023
# torch.float64 torch.float64
# epoch 292, loss 4050.533218712276
# torch.float64 torch.float64
# epoch 293, loss 4035.9270152133818
# torch.float64 torch.float64
# epoch 294, loss 4021.374780249632
# torch.float64 torch.float64
# epoch 295, loss 4006.876310428526
# torch.float64 torch.float64
# epoch 296, loss 3992.431403136733
# torch.float64 torch.float64
# epoch 297, loss 3978.0398565370683
# torch.float64 torch.float64
# epoch 298, loss 3963.701469565479
# torch.float64 torch.float64
# epoch 299, loss 3949.416041928044
# torch.float64 torch.float64
# epoch 300, loss 3935.1833740979796
# torch.float64 torch.float64
# epoch 301, loss 3921.0032673126743
# torch.float64 torch.float64
# epoch 302, loss 3906.8755235707094
# torch.float64 torch.float64
# epoch 303, loss 3892.7999456289094
# torch.float64 torch.float64
# epoch 304, loss 3878.7763369994004
# torch.float64 torch.float64
# epoch 305, loss 3864.8045019466795
# torch.float64 torch.float64
# epoch 306, loss 3850.8842454846913
# torch.float64 torch.float64
# epoch 307, loss 3837.0153733739253
# torch.float64 torch.float64
# epoch 308, loss 3823.197692118511
# torch.float64 torch.float64
# epoch 309, loss 3809.4310089633414
# torch.float64 torch.float64
# epoch 310, loss 3795.715131891192
# torch.float64 torch.float64
# epoch 311, loss 3782.0498696198606
# torch.float64 torch.float64
# epoch 312, loss 3768.435031599317
# torch.float64 torch.float64
# epoch 313, loss 3754.870428008857
# torch.float64 torch.float64
# epoch 314, loss 3741.3558697542817
# torch.float64 torch.float64
# epoch 315, loss 3727.89116846507
# torch.float64 torch.float64
# epoch 316, loss 3714.4761364915785
# torch.float64 torch.float64
# epoch 317, loss 3701.110586902242
# torch.float64 torch.float64
# epoch 318, loss 3687.7943334807887
# torch.float64 torch.float64
# epoch 319, loss 3674.527190723465
# torch.float64 torch.float64
# epoch 320, loss 3661.3089738362746
# torch.float64 torch.float64
# epoch 321, loss 3648.1394987322224
# torch.float64 torch.float64
# epoch 322, loss 3635.018582028576
# torch.float64 torch.float64
# epoch 323, loss 3621.9460410441343
# torch.float64 torch.float64
# epoch 324, loss 3608.921693796503
# torch.float64 torch.float64
# epoch 325, loss 3595.94535899939
# torch.float64 torch.float64
# epoch 326, loss 3583.0168560599036
# torch.float64 torch.float64
# epoch 327, loss 3570.136005075866
# torch.float64 torch.float64
# epoch 328, loss 3557.302626833132
# torch.float64 torch.float64
# epoch 329, loss 3544.516542802926
# torch.float64 torch.float64
# epoch 330, loss 3531.777575139179
# torch.float64 torch.float64
# epoch 331, loss 3519.0855466758903
# torch.float64 torch.float64
# epoch 332, loss 3506.4402809244834
# torch.float64 torch.float64
# epoch 333, loss 3493.841602071184
# torch.float64 torch.float64
# epoch 334, loss 3481.289334974403
# torch.float64 torch.float64
# epoch 335, loss 3468.7833051621346
# torch.float64 torch.float64
# epoch 336, loss 3456.3233388293565
# torch.float64 torch.float64
# epoch 337, loss 3443.9092628354447
# torch.float64 torch.float64
# epoch 338, loss 3431.5409047016074
# torch.float64 torch.float64
# epoch 339, loss 3419.218092608308
# torch.float64 torch.float64
# epoch 340, loss 3406.9406553927174
# torch.float64 torch.float64
# epoch 341, loss 3394.7084225461695
# torch.float64 torch.float64
# epoch 342, loss 3382.521224211626
# torch.float64 torch.float64
# epoch 343, loss 3370.3788911811453
# torch.float64 torch.float64
# epoch 344, loss 3358.281254893382
# torch.float64 torch.float64
# epoch 345, loss 3346.2281474310644
# torch.float64 torch.float64
# epoch 346, loss 3334.2194015185123
# torch.float64 torch.float64
# epoch 347, loss 3322.254850519147
# torch.float64 torch.float64
# epoch 348, loss 3310.334328433015
# torch.float64 torch.float64
# epoch 349, loss 3298.4576698943215
# torch.float64 torch.float64
# epoch 350, loss 3286.624710168978
# torch.float64 torch.float64
# epoch 351, loss 3274.83528515215
# torch.float64 torch.float64
# epoch 352, loss 3263.089231365825
# torch.float64 torch.float64
# epoch 353, loss 3251.3863859563817
# torch.float64 torch.float64
# epoch 354, loss 3239.7265866921716
# torch.float64 torch.float64
# epoch 355, loss 3228.109671961114
# torch.float64 torch.float64
# epoch 356, loss 3216.5354807682934
# torch.float64 torch.float64
# epoch 357, loss 3205.00385273357
# torch.float64 torch.float64
# epoch 358, loss 3193.5146280891995
# torch.float64 torch.float64
# epoch 359, loss 3182.0676476774656
# torch.float64 torch.float64
# epoch 360, loss 3170.662752948311
# torch.float64 torch.float64
# epoch 361, loss 3159.2997859569928
# torch.float64 torch.float64
# epoch 362, loss 3147.9785893617336
# torch.float64 torch.float64
# epoch 363, loss 3136.699006421387
# torch.float64 torch.float64
# epoch 364, loss 3125.4608809931174
# torch.float64 torch.float64
# epoch 365, loss 3114.26405753008
# torch.float64 torch.float64
# epoch 366, loss 3103.108381079115
# torch.float64 torch.float64
# epoch 367, loss 3091.9936972784512
# torch.float64 torch.float64
# epoch 368, loss 3080.9198523554123
# torch.float64 torch.float64
# epoch 369, loss 3069.8866931241437
# torch.float64 torch.float64
# epoch 370, loss 3058.894066983338
# torch.float64 torch.float64
# epoch 371, loss 3047.9418219139707
# torch.float64 torch.float64
# epoch 372, loss 3037.029806477053
# torch.float64 torch.float64
# epoch 373, loss 3026.157869811382
# torch.float64 torch.float64
# epoch 374, loss 3015.3258616313055
# torch.float64 torch.float64
# epoch 375, loss 3004.5336322245
# torch.float64 torch.float64
# epoch 376, loss 2993.7810324497473
# torch.float64 torch.float64
# epoch 377, loss 2983.067913734726
# torch.float64 torch.float64
# epoch 378, loss 2972.394128073813
# torch.float64 torch.float64
# epoch 379, loss 2961.759528025889
# torch.float64 torch.float64
# epoch 380, loss 2951.163966712154
# torch.float64 torch.float64
# epoch 381, loss 2940.6072978139587
# torch.float64 torch.float64
# epoch 382, loss 2930.0893755706265
# torch.float64 torch.float64
# epoch 383, loss 2919.610054777308
# torch.float64 torch.float64
# epoch 384, loss 2909.1691907828217
# torch.float64 torch.float64
# epoch 385, loss 2898.766639487516
# torch.float64 torch.float64
# epoch 386, loss 2888.402257341139
# torch.float64 torch.float64
# epoch 387, loss 2878.075901340709
# torch.float64 torch.float64
# epoch 388, loss 2867.787429028403
# torch.float64 torch.float64
# epoch 389, loss 2857.5366984894463
# torch.float64 torch.float64
# epoch 390, loss 2847.3235683500106
# torch.float64 torch.float64
# epoch 391, loss 2837.1478977751276
# torch.float64 torch.float64
# epoch 392, loss 2827.009546466602
# torch.float64 torch.float64
# epoch 393, loss 2816.908374660937
# torch.float64 torch.float64
# epoch 394, loss 2806.8442431272697
# torch.float64 torch.float64
# epoch 395, loss 2796.817013165306
# torch.float64 torch.float64
# epoch 396, loss 2786.826546603278
# torch.float64 torch.float64
# epoch 397, loss 2776.872705795895
# torch.float64 torch.float64
# epoch 398, loss 2766.955353622308
# torch.float64 torch.float64
# epoch 399, loss 2757.0743534840904
# torch.float64 torch.float64
# epoch 400, loss 2747.2295693032092
# torch.float64 torch.float64
# epoch 401, loss 2737.4208655200214
# torch.float64 torch.float64
# epoch 402, loss 2727.6481070912655
# torch.float64 torch.float64
# epoch 403, loss 2717.911159488069
# torch.float64 torch.float64
# epoch 404, loss 2708.209888693961
# torch.float64 torch.float64
# epoch 405, loss 2698.5441612028894
# torch.float64 torch.float64
# epoch 406, loss 2688.9138440172537
# torch.float64 torch.float64
# epoch 407, loss 2679.318804645935
# torch.float64 torch.float64
# epoch 408, loss 2669.758911102342
# torch.float64 torch.float64
# epoch 409, loss 2660.234031902464
# torch.float64 torch.float64
# epoch 410, loss 2650.744036062925
# torch.float64 torch.float64
# epoch 411, loss 2641.2887930990537
# torch.float64 torch.float64
# epoch 412, loss 2631.868173022953
# torch.float64 torch.float64
# epoch 413, loss 2622.4820463415876
# torch.float64 torch.float64
# epoch 414, loss 2613.1302840548647
# torch.float64 torch.float64
# epoch 415, loss 2603.8127576537363
# torch.float64 torch.float64
# epoch 416, loss 2594.529339118302
# torch.float64 torch.float64
# epoch 417, loss 2585.2799009159166
# torch.float64 torch.float64
# epoch 418, loss 2576.0643159993115
# torch.float64 torch.float64
# epoch 419, loss 2566.8824578047197
# torch.float64 torch.float64
# epoch 420, loss 2557.734200250009
# torch.float64 torch.float64
# epoch 421, loss 2548.619417732821
# torch.float64 torch.float64
# epoch 422, loss 2539.5379851287225
# torch.float64 torch.float64
# epoch 423, loss 2530.4897777893552
# torch.float64 torch.float64
# epoch 424, loss 2521.4746715406013
# torch.float64 torch.float64
# epoch 425, loss 2512.4925426807517
# torch.float64 torch.float64
# epoch 426, loss 2503.543267978682
# torch.float64 torch.float64
# epoch 427, loss 2494.62672467204
# torch.float64 torch.float64
# epoch 428, loss 2485.742790465427
# torch.float64 torch.float64
# epoch 429, loss 2476.891343528605
# torch.float64 torch.float64
# epoch 430, loss 2468.0722624946984
# torch.float64 torch.float64
# epoch 431, loss 2459.2854264584034
# torch.float64 torch.float64
# epoch 432, loss 2450.5307149742084
# torch.float64 torch.float64
# epoch 433, loss 2441.8080080546215
# torch.float64 torch.float64
# epoch 434, loss 2433.117186168399
# torch.float64 torch.float64
# epoch 435, loss 2424.4581302387887
# torch.float64 torch.float64
# epoch 436, loss 2415.830721641775
# torch.float64 torch.float64
# epoch 437, loss 2407.2348422043315
# torch.float64 torch.float64
# epoch 438, loss 2398.6703742026816
# torch.float64 torch.float64
# epoch 439, loss 2390.1372003605657
# torch.float64 torch.float64
# epoch 440, loss 2381.6352038475134
# torch.float64 torch.float64
# epoch 441, loss 2373.1642682771244
# torch.float64 torch.float64
# epoch 442, loss 2364.724277705359
# torch.float64 torch.float64
# epoch 443, loss 2356.3151166288253
# torch.float64 torch.float64
# epoch 444, loss 2347.936669983087
# torch.float64 torch.float64
# epoch 445, loss 2339.5888231409613
# torch.float64 torch.float64
# epoch 446, loss 2331.2714619108433
# torch.float64 torch.float64
# epoch 447, loss 2322.984472535018
# torch.float64 torch.float64
# epoch 448, loss 2314.7277416879897
# torch.float64 torch.float64
# epoch 449, loss 2306.5011564748174
# torch.float64 torch.float64
# epoch 450, loss 2298.30460442945
# torch.float64 torch.float64
# epoch 451, loss 2290.137973513078
# torch.float64 torch.float64
# epoch 452, loss 2282.001152112482
# torch.float64 torch.float64
# epoch 453, loss 2273.8940290383944
# torch.float64 torch.float64
# epoch 454, loss 2265.816493523864
# torch.float64 torch.float64
# epoch 455, loss 2257.768435222627
# torch.float64 torch.float64
# epoch 456, loss 2249.749744207488
# torch.float64 torch.float64
# epoch 457, loss 2241.760310968703
# torch.float64 torch.float64
# epoch 458, loss 2233.800026412367
# torch.float64 torch.float64
# epoch 459, loss 2225.8687818588182
# torch.float64 torch.float64
# epoch 460, loss 2217.966469041038
# torch.float64 torch.float64
# epoch 461, loss 2210.092980103059
# torch.float64 torch.float64
# epoch 462, loss 2202.2482075983817
# torch.float64 torch.float64
# epoch 463, loss 2194.4320444883997
# torch.float64 torch.float64
# epoch 464, loss 2186.6443841408245
# torch.float64 torch.float64
# epoch 465, loss 2178.8851203281215
# torch.float64 torch.float64
# epoch 466, loss 2171.154147225948
# torch.float64 torch.float64
# epoch 467, loss 2163.4513594116042
# torch.float64 torch.float64
# epoch 468, loss 2155.776651862482
# torch.float64 torch.float64
# epoch 469, loss 2148.129919954527
# torch.float64 torch.float64
# epoch 470, loss 2140.5110594606967
# torch.float64 torch.float64
# epoch 471, loss 2132.9199665494416
# torch.float64 torch.float64
# epoch 472, loss 2125.3565377831706
# torch.float64 torch.float64
# epoch 473, loss 2117.8206701167423
# torch.float64 torch.float64
# epoch 474, loss 2110.312260895947
# torch.float64 torch.float64
# epoch 475, loss 2102.8312078560075
# torch.float64 torch.float64
# epoch 476, loss 2095.377409120073
# torch.float64 torch.float64
# epoch 477, loss 2087.95076319773
# torch.float64 torch.float64
# epoch 478, loss 2080.5511689835103
# torch.float64 torch.float64
# epoch 479, loss 2073.1785257554125
# torch.float64 torch.float64
# epoch 480, loss 2065.832733173423
# torch.float64 torch.float64
# epoch 481, loss 2058.5136912780445
# torch.float64 torch.float64
# epoch 482, loss 2051.221300488836
# torch.float64 torch.float64
# epoch 483, loss 2043.9554616029454
# torch.float64 torch.float64
# epoch 484, loss 2036.716075793664
# torch.float64 torch.float64
# epoch 485, loss 2029.5030446089725
# torch.float64 torch.float64
# epoch 486, loss 2022.3162699701024
# torch.float64 torch.float64
# epoch 487, loss 2015.1556541700968
# torch.float64 torch.float64
# epoch 488, loss 2008.021099872382
# torch.float64 torch.float64
# epoch 489, loss 2000.9125101093384
# torch.float64 torch.float64
# epoch 490, loss 1993.8297882808845
# torch.float64 torch.float64
# epoch 491, loss 1986.772838153059
# torch.float64 torch.float64
# epoch 492, loss 1979.7415638566144
# torch.float64 torch.float64
# epoch 493, loss 1972.7358698856121
# torch.float64 torch.float64
# epoch 494, loss 1965.755661096025
# torch.float64 torch.float64
# epoch 495, loss 1958.8008427043449
# torch.float64 torch.float64
# epoch 496, loss 1951.871320286195
# torch.float64 torch.float64
# epoch 497, loss 1944.9669997749486
# torch.float64 torch.float64
# epoch 498, loss 1938.0877874603539
# torch.float64 torch.float64
# epoch 499, loss 1931.2335899871607
# torch.float64 torch.float64
# epoch 500, loss 1924.4043143537558
# torch.float64 torch.float64
# epoch 501, loss 1917.599867910804
# torch.float64 torch.float64
# epoch 502, loss 1910.8201583598911
# torch.float64 torch.float64
# epoch 503, loss 1904.065093752175
# torch.float64 torch.float64
# epoch 504, loss 1897.334582487043
# torch.float64 torch.float64
# epoch 505, loss 1890.628533310768
# torch.float64 torch.float64
# epoch 506, loss 1883.94685531518
# torch.float64 torch.float64
# epoch 507, loss 1877.2894579363335
# torch.float64 torch.float64
# epoch 508, loss 1870.6562509531855
# torch.float64 torch.float64
# epoch 509, loss 1864.0471444862749
# torch.float64 torch.float64
# epoch 510, loss 1857.4620489964138
# torch.float64 torch.float64
# epoch 511, loss 1850.9008752833738
# torch.float64 torch.float64
# epoch 512, loss 1844.3635344845868
# torch.float64 torch.float64
# epoch 513, loss 1837.8499380738435
# torch.float64 torch.float64
# epoch 514, loss 1831.3599978600043
# torch.float64 torch.float64
# epoch 515, loss 1824.8936259857087
# torch.float64 torch.float64
# epoch 516, loss 1818.4507349260923
# torch.float64 torch.float64
# epoch 517, loss 1812.0312374875107
# torch.float64 torch.float64
# epoch 518, loss 1805.6350468062642
# torch.float64 torch.float64
# epoch 519, loss 1799.2620763473315
# torch.float64 torch.float64
# epoch 520, loss 1792.912239903105
# torch.float64 torch.float64
# epoch 521, loss 1786.5854515921342
# torch.float64 torch.float64
# epoch 522, loss 1780.281625857871
# torch.float64 torch.float64
# epoch 523, loss 1774.0006774674227
# torch.float64 torch.float64
# epoch 524, loss 1767.742521510309
# torch.float64 torch.float64
# epoch 525, loss 1761.5070733972184
# torch.float64 torch.float64
# epoch 526, loss 1755.2942488587807
# torch.float64 torch.float64
# epoch 527, loss 1749.103963944334
# torch.float64 torch.float64
# epoch 528, loss 1742.9361350207025
# torch.float64 torch.float64
# epoch 529, loss 1736.7906787709744
# torch.float64 torch.float64
# epoch 530, loss 1730.667512193289
# torch.float64 torch.float64
# epoch 531, loss 1724.5665525996264
# torch.float64 torch.float64
# epoch 532, loss 1718.4877176146026
# torch.float64 torch.float64
# epoch 533, loss 1712.430925174266
# torch.float64 torch.float64
# epoch 534, loss 1706.3960935249056
# torch.float64 torch.float64
# epoch 535, loss 1700.3831412218556
# torch.float64 torch.float64
# epoch 536, loss 1694.391987128312
# torch.float64 torch.float64
# epoch 537, loss 1688.4225504141482
# torch.float64 torch.float64
# epoch 538, loss 1682.4747505547384
# torch.float64 torch.float64
# epoch 539, loss 1676.5485073297848
# torch.float64 torch.float64
# epoch 540, loss 1670.6437408221486
# torch.float64 torch.float64
# epoch 541, loss 1664.7603714166864
# torch.float64 torch.float64
# epoch 542, loss 1658.8983197990915
# torch.float64 torch.float64
# epoch 543, loss 1653.057506954738
# torch.float64 torch.float64
# epoch 544, loss 1647.2378541675316
# torch.float64 torch.float64
# epoch 545, loss 1641.439283018763
# torch.float64 torch.float64
# epoch 546, loss 1635.6617153859656
# torch.float64 torch.float64
# epoch 547, loss 1629.9050734417815
# torch.float64 torch.float64
# epoch 548, loss 1624.169279652826
# torch.float64 torch.float64
# epoch 549, loss 1618.454256778561
# torch.float64 torch.float64
# epoch 550, loss 1612.75992787017
# torch.float64 torch.float64
# epoch 551, loss 1607.0862162694405
# torch.float64 torch.float64
# epoch 552, loss 1601.4330456076475
# torch.float64 torch.float64
# epoch 553, loss 1595.8003398044443
# torch.float64 torch.float64
# epoch 554, loss 1590.1880230667532
# torch.float64 torch.float64
# epoch 555, loss 1584.596019887667
# torch.float64 torch.float64
# epoch 556, loss 1579.0242550453488
# torch.float64 torch.float64
# epoch 557, loss 1573.4726536019402
# torch.float64 torch.float64
# epoch 558, loss 1567.9411409024701
# torch.float64 torch.float64
# epoch 559, loss 1562.4296425737714
# torch.float64 torch.float64
# epoch 560, loss 1556.9380845233977
# torch.float64 torch.float64
# epoch 561, loss 1551.4663929385504
# torch.float64 torch.float64
# epoch 562, loss 1546.0144942850034
# torch.float64 torch.float64
# epoch 563, loss 1540.582315306035
# torch.float64 torch.float64
# epoch 564, loss 1535.1697830213657
# torch.float64 torch.float64
# epoch 565, loss 1529.7768247260963
# torch.float64 torch.float64
# epoch 566, loss 1524.403367989652
# torch.float64 torch.float64
# epoch 567, loss 1519.0493406547316
# torch.float64 torch.float64
# epoch 568, loss 1513.7146708362604
# torch.float64 torch.float64
# epoch 569, loss 1508.3992869203444
# torch.float64 torch.float64
# epoch 570, loss 1503.1031175632324
# torch.float64 torch.float64
# epoch 571, loss 1497.82609169028
# torch.float64 torch.float64
# epoch 572, loss 1492.5681384949182
# torch.float64 torch.float64
# epoch 573, loss 1487.3291874376257
# torch.float64 torch.float64
# epoch 574, loss 1482.1091682449053
# torch.float64 torch.float64
# epoch 575, loss 1476.908010908265
# torch.float64 torch.float64
# epoch 576, loss 1471.725645683202
# torch.float64 torch.float64
# epoch 577, loss 1466.5620030881907
# torch.float64 torch.float64
# epoch 578, loss 1461.4170139036753
# torch.float64 torch.float64
# epoch 579, loss 1456.2906091710665
# torch.float64 torch.float64
# epoch 580, loss 1451.1827201917404
# torch.float64 torch.float64
# epoch 581, loss 1446.0932785260443
# torch.float64 torch.float64
# epoch 582, loss 1441.0222159923014
# torch.float64 torch.float64
# epoch 583, loss 1435.969464665827
# torch.float64 torch.float64
# epoch 584, loss 1430.9349568779405
# torch.float64 torch.float64
# epoch 585, loss 1425.9186252149857
# torch.float64 torch.float64
# epoch 586, loss 1420.9204025173551
# torch.float64 torch.float64
# epoch 587, loss 1415.940221878514
# torch.float64 torch.float64
# epoch 588, loss 1410.978016644035
# torch.float64 torch.float64
# epoch 589, loss 1406.0337204106293
# torch.float64 torch.float64
# epoch 590, loss 1401.1072670251867
# torch.float64 torch.float64
# epoch 591, loss 1396.198590583818
# torch.float64 torch.float64
# epoch 592, loss 1391.3076254308985
# torch.float64 torch.float64
# epoch 593, loss 1386.434306158119
# torch.float64 torch.float64
# epoch 594, loss 1381.5785676035389
# torch.float64 torch.float64
# epoch 595, loss 1376.740344850643
# torch.float64 torch.float64
# epoch 596, loss 1371.9195732274006
# torch.float64 torch.float64
# epoch 597, loss 1367.1161883053305
# torch.float64 torch.float64
# epoch 598, loss 1362.3301258985698
# torch.float64 torch.float64
# epoch 599, loss 1357.5613220629436
# torch.float64 torch.float64
# epoch 600, loss 1352.8097130950407
# torch.float64 torch.float64
# epoch 601, loss 1348.0752355312907
# torch.float64 torch.float64
# epoch 602, loss 1343.357826147048
# torch.float64 torch.float64
# epoch 603, loss 1338.6574219556767
# torch.float64 torch.float64
# epoch 604, loss 1333.9739602076402
# torch.float64 torch.float64
# epoch 605, loss 1329.3073783895918
# torch.float64 torch.float64
# epoch 606, loss 1324.6576142234746
# torch.float64 torch.float64
# epoch 607, loss 1320.0246056656172
# torch.float64 torch.float64
# epoch 608, loss 1315.4082909058409
# torch.float64 torch.float64
# epoch 609, loss 1310.8086083665626
# torch.float64 torch.float64
# epoch 610, loss 1306.2254967019085
# torch.float64 torch.float64
# epoch 611, loss 1301.6588947968246
# torch.float64 torch.float64
# epoch 612, loss 1297.108741766196
# torch.float64 torch.float64
# epoch 613, loss 1292.5749769539664
# torch.float64 torch.float64
# epoch 614, loss 1288.057539932261
# torch.float64 torch.float64
# epoch 615, loss 1283.556370500517
# torch.float64 torch.float64
# epoch 616, loss 1279.0714086846106
# torch.float64 torch.float64
# epoch 617, loss 1274.6025947359935
# torch.float64 torch.float64
# epoch 618, loss 1270.149869130829
# torch.float64 torch.float64
# epoch 619, loss 1265.713172569133
# torch.float64 torch.float64
# epoch 620, loss 1261.2924459739186
# torch.float64 torch.float64
# epoch 621, loss 1256.8876304903429
# torch.float64 torch.float64
# epoch 622, loss 1252.498667484858
# torch.float64 torch.float64
# epoch 623, loss 1248.1254985443652
# torch.float64 torch.float64
# epoch 624, loss 1243.7680654753713
# torch.float64 torch.float64
# epoch 625, loss 1239.4263103031503
# torch.float64 torch.float64
# epoch 626, loss 1235.100175270906
# torch.float64 torch.float64
# epoch 627, loss 1230.7896028389405
# torch.float64 torch.float64
# epoch 628, loss 1226.4945356838232
# torch.float64 torch.float64
# epoch 629, loss 1222.2149166975644
# torch.float64 torch.float64
# epoch 630, loss 1217.9506889867923
# torch.float64 torch.float64
# epoch 631, loss 1213.701795871934
# torch.float64 torch.float64
# epoch 632, loss 1209.4681808863957
# torch.float64 torch.float64
# epoch 633, loss 1205.249787775751
# torch.float64 torch.float64
# epoch 634, loss 1201.04656049693
# torch.float64 torch.float64
# epoch 635, loss 1196.8584432174116
# torch.float64 torch.float64
# epoch 636, loss 1192.6853803144193
# torch.float64 torch.float64
# epoch 637, loss 1188.5273163741183
# torch.float64 torch.float64
# epoch 638, loss 1184.3841961908201
# torch.float64 torch.float64
# epoch 639, loss 1180.2559647661867
# torch.float64 torch.float64
# epoch 640, loss 1176.1425673084352
# torch.float64 torch.float64
# epoch 641, loss 1172.0439492315545
# torch.float64 torch.float64
# epoch 642, loss 1167.9600561545153
# torch.float64 torch.float64
# epoch 643, loss 1163.890833900488
# torch.float64 torch.float64
# epoch 644, loss 1159.8362284960645
# torch.float64 torch.float64
# epoch 645, loss 1155.7961861704798
# torch.float64 torch.float64
# epoch 646, loss 1151.7706533548385
# torch.float64 torch.float64
# epoch 647, loss 1147.7595766813445
# torch.float64 torch.float64
# epoch 648, loss 1143.7629029825334
# torch.float64 torch.float64
# epoch 649, loss 1139.780579290507
# torch.float64 torch.float64
# epoch 650, loss 1135.812552836171
# torch.float64 torch.float64
# epoch 651, loss 1131.8587710484776
# torch.float64 torch.float64
# epoch 652, loss 1127.9191815536683
# torch.float64 torch.float64
# epoch 653, loss 1123.9937321745213
# torch.float64 torch.float64
# epoch 654, loss 1120.082370929602
# torch.float64 torch.float64
# epoch 655, loss 1116.1850460325136
# torch.float64 torch.float64
# epoch 656, loss 1112.3017058911557
# torch.float64 torch.float64
# epoch 657, loss 1108.43229910698
# torch.float64 torch.float64
# epoch 658, loss 1104.5767744742548
# torch.float64 torch.float64
# epoch 659, loss 1100.7350809793263
# torch.float64 torch.float64
# epoch 660, loss 1096.9071677998872
# torch.float64 torch.float64
# epoch 661, loss 1093.0929843042463
# torch.float64 torch.float64
# epoch 662, loss 1089.292480050602
# torch.float64 torch.float64
# epoch 663, loss 1085.5056047863168
# torch.float64 torch.float64
# epoch 664, loss 1081.7323084471957
# torch.float64 torch.float64
# epoch 665, loss 1077.972541156768
# torch.float64 torch.float64
# epoch 666, loss 1074.2262532255722
# torch.float64 torch.float64
# epoch 667, loss 1070.4933951504402
# torch.float64 torch.float64
# epoch 668, loss 1066.7739176137893
# torch.float64 torch.float64
# epoch 669, loss 1063.0677714829121
# torch.float64 torch.float64
# epoch 670, loss 1059.3749078092746
# torch.float64 torch.float64
# epoch 671, loss 1055.6952778278096
# torch.float64 torch.float64
# epoch 672, loss 1052.0288329562222
# torch.float64 torch.float64
# epoch 673, loss 1048.3755247942881
# torch.float64 torch.float64
# epoch 674, loss 1044.735305123162
# torch.float64 torch.float64
# epoch 675, loss 1041.1081259046864
# torch.float64 torch.float64
# epoch 676, loss 1037.493939280702
# torch.float64 torch.float64
# epoch 677, loss 1033.8926975723605
# torch.float64 torch.float64
# epoch 678, loss 1030.3043532794431
# torch.float64 torch.float64
# epoch 679, loss 1026.728859079679
# torch.float64 torch.float64
# epoch 680, loss 1023.1661678280664
# torch.float64 torch.float64
# epoch 681, loss 1019.6162325561963
# torch.float64 torch.float64
# epoch 682, loss 1016.0790064715824
# torch.float64 torch.float64
# epoch 683, loss 1012.5544429569876
# torch.float64 torch.float64
# epoch 684, loss 1009.0424955697581
# torch.float64 torch.float64
# epoch 685, loss 1005.5431180411573
# torch.float64 torch.float64
# epoch 686, loss 1002.0562642757028
# torch.float64 torch.float64
# epoch 687, loss 998.5818883505078
# torch.float64 torch.float64
# epoch 688, loss 995.1199445146218
# torch.float64 torch.float64
# epoch 689, loss 991.6703871883768
# torch.float64 torch.float64
# epoch 690, loss 988.2331709627346
# torch.float64 torch.float64
# epoch 691, loss 984.808250598636
# torch.float64 torch.float64
# epoch 692, loss 981.3955810263542
# torch.float64 torch.float64
# epoch 693, loss 977.9951173448505
# torch.float64 torch.float64
# epoch 694, loss 974.6068148211307
# torch.float64 torch.float64
# epoch 695, loss 971.2306288896041
# torch.float64 torch.float64
# epoch 696, loss 967.866515151449
# torch.float64 torch.float64
# epoch 697, loss 964.5144293739755
# torch.float64 torch.float64
# epoch 698, loss 961.1743274899933
# torch.float64 torch.float64
# epoch 699, loss 957.846165597182
# torch.float64 torch.float64
# epoch 700, loss 954.5298999574628
# torch.float64 torch.float64
# epoch 701, loss 951.2254869963733
# torch.float64 torch.float64
# epoch 702, loss 947.9328833024459
# torch.float64 torch.float64
# epoch 703, loss 944.6520456265856
# torch.float64 torch.float64
# epoch 704, loss 941.3829308814522
# torch.float64 torch.float64
# epoch 705, loss 938.1254961408456
# torch.float64 torch.float64
# epoch 706, loss 934.8796986390919
# torch.float64 torch.float64
# epoch 707, loss 931.6454957704333
# torch.float64 torch.float64
# epoch 708, loss 928.4228450884169
# torch.float64 torch.float64
# epoch 709, loss 925.2117043052924
# torch.float64 torch.float64
# epoch 710, loss 922.0120312914044
# torch.float64 torch.float64
# epoch 711, loss 918.8237840745935
# torch.float64 torch.float64
# epoch 712, loss 915.6469208395963
# torch.float64 torch.float64
# epoch 713, loss 912.4813999274484
# torch.float64 torch.float64
# epoch 714, loss 909.3271798348894
# torch.float64 torch.float64
# epoch 715, loss 906.1842192137705
# torch.float64 torch.float64
# epoch 716, loss 903.0524768704654
# torch.float64 torch.float64
# epoch 717, loss 899.9319117652828
# torch.float64 torch.float64
# epoch 718, loss 896.8224830118786
# torch.float64 torch.float64
# epoch 719, loss 893.7241498766755
# torch.float64 torch.float64
# epoch 720, loss 890.6368717782798
# torch.float64 torch.float64
# epoch 721, loss 887.5606082869047
# torch.float64 torch.float64
# epoch 722, loss 884.495319123791
# torch.float64 torch.float64
# epoch 723, loss 881.4409641606366
# torch.float64 torch.float64
# epoch 724, loss 878.397503419021
# torch.float64 torch.float64
# epoch 725, loss 875.3648970698372
# torch.float64 torch.float64
# epoch 726, loss 872.3431054327236
# torch.float64 torch.float64
# epoch 727, loss 869.3320889754992
# torch.float64 torch.float64
# epoch 728, loss 866.3318083135986
# torch.float64 torch.float64
# epoch 729, loss 863.3422242095127
# torch.float64 torch.float64
# epoch 730, loss 860.3632975722292
# torch.float64 torch.float64
# epoch 731, loss 857.3949894566751
# torch.float64 torch.float64
# epoch 732, loss 854.4372610631624
# torch.float64 torch.float64
# epoch 733, loss 851.4900737368374
# torch.float64 torch.float64
# epoch 734, loss 848.5533889671266
# torch.float64 torch.float64
# epoch 735, loss 845.6271683871919
# torch.float64 torch.float64
# epoch 736, loss 842.7113737733823
# torch.float64 torch.float64
# epoch 737, loss 839.8059670446925
# torch.float64 torch.float64
# epoch 738, loss 836.9109102622169
# torch.float64 torch.float64
# epoch 739, loss 834.026165628613
# torch.float64 torch.float64
# epoch 740, loss 831.1516954875627
# torch.float64 torch.float64
# epoch 741, loss 828.2874623232367
# torch.float64 torch.float64
# epoch 742, loss 825.4334287597597
# torch.float64 torch.float64
# epoch 743, loss 822.5895575606817
# torch.float64 torch.float64
# epoch 744, loss 819.7558116284447
# torch.float64 torch.float64
# epoch 745, loss 816.9321540038585
# torch.float64 torch.float64
# epoch 746, loss 814.1185478655731
# torch.float64 torch.float64
# epoch 747, loss 811.314956529557
# torch.float64 torch.float64
# epoch 748, loss 808.5213434485737
# torch.float64 torch.float64
# epoch 749, loss 805.7376722116644
# torch.float64 torch.float64
# epoch 750, loss 802.9639065436289
# torch.float64 torch.float64
# epoch 751, loss 800.2000103045119
# torch.float64 torch.float64
# epoch 752, loss 797.4459474890879
# torch.float64 torch.float64
# epoch 753, loss 794.7016822263508
# torch.float64 torch.float64
# epoch 754, loss 791.9671787790046
# torch.float64 torch.float64
# epoch 755, loss 789.2424015429542
# torch.float64 torch.float64
# epoch 756, loss 786.5273150468029
# torch.float64 torch.float64
# epoch 757, loss 783.8218839513453
# torch.float64 torch.float64
# epoch 758, loss 781.1260730490686
# torch.float64 torch.float64
# epoch 759, loss 778.4398472636503
# torch.float64 torch.float64
# epoch 760, loss 775.7631716494634
# torch.float64 torch.float64
# epoch 761, loss 773.0960113910775
# torch.float64 torch.float64
# epoch 762, loss 770.4383318027664
# torch.float64 torch.float64
# epoch 763, loss 767.790098328016
# torch.float64 torch.float64
# epoch 764, loss 765.1512765390339
# torch.float64 torch.float64
# epoch 765, loss 762.5218321362611
# torch.float64 torch.float64
# epoch 766, loss 759.9017309478855
# torch.float64 torch.float64
# epoch 767, loss 757.290938929357
# torch.float64 torch.float64
# epoch 768, loss 754.689422162906
# torch.float64 torch.float64
# epoch 769, loss 752.0971468570615
# torch.float64 torch.float64
# epoch 770, loss 749.5140793461727
# torch.float64 torch.float64
# epoch 771, loss 746.9401860899309
# ...
# torch.float64 torch.float64
# epoch 2747, loss 5.652271263245456
# torch.float64 torch.float64
# epoch 2748, loss 5.648062340372838
# torch.float64 torch.float64
# epoch 2749, loss 5.643865976666897
# torch.float64 torch.float64
# epoch 2750, loss 5.639682133918827
# torch.float64 torch.float64
# epoch 2751, loss 5.635510774038828
# torch.float64 torch.float64
# epoch 2752, loss 5.63135185905565
# torch.float64 torch.float64
# epoch 2753, loss 5.627205351116228
# torch.float64 torch.float64
# epoch 2754, loss 5.623071212485337
# torch.float64 torch.float64
# epoch 2755, loss 5.618949405545111
# torch.float64 torch.float64
# epoch 2756, loss 5.614839892794848
# torch.float64 torch.float64
# epoch 2757, loss 5.610742636850459
# torch.float64 torch.float64
# epoch 2758, loss 5.606657600444172
# torch.float64 torch.float64
# epoch 2759, loss 5.602584746424218
# torch.float64 torch.float64
# epoch 2760, loss 5.598524037754318
# torch.float64 torch.float64
# epoch 2761, loss 5.594475437513446
# torch.float64 torch.float64
# epoch 2762, loss 5.590438908895415
# torch.float64 torch.float64
# epoch 2763, loss 5.586414415208429
# torch.float64 torch.float64
# epoch 2764, loss 5.582401919874879
# torch.float64 torch.float64
# epoch 2765, loss 5.578401386430886
# torch.float64 torch.float64
# epoch 2766, loss 5.574412778525908
# torch.float64 torch.float64
# epoch 2767, loss 5.570436059922438
# torch.float64 torch.float64
# epoch 2768, loss 5.566471194495626
# torch.float64 torch.float64
# epoch 2769, loss 5.562518146232904
# torch.float64 torch.float64
# epoch 2770, loss 5.558576879233618
# torch.float64 torch.float64
# epoch 2771, loss 5.554647357708771
# torch.float64 torch.float64
# epoch 2772, loss 5.5507295459804915
# torch.float64 torch.float64
# epoch 2773, loss 5.546823408481822
# torch.float64 torch.float64
# epoch 2774, loss 5.542928909756347
# torch.float64 torch.float64
# epoch 2775, loss 5.539046014457758
# torch.float64 torch.float64
# epoch 2776, loss 5.535174687349566
# torch.float64 torch.float64
# epoch 2777, loss 5.531314893304771
# torch.float64 torch.float64
# epoch 2778, loss 5.527466597305471
# torch.float64 torch.float64
# epoch 2779, loss 5.523629764442527
# torch.float64 torch.float64
# epoch 2780, loss 5.519804359915189
# torch.float64 torch.float64
# epoch 2781, loss 5.515990349030825
# torch.float64 torch.float64
# epoch 2782, loss 5.512187697204505
# torch.float64 torch.float64
# epoch 2783, loss 5.5083963699586755
# torch.float64 torch.float64
# epoch 2784, loss 5.5046163329228515
# torch.float64 torch.float64
# epoch 2785, loss 5.500847551833211
# torch.float64 torch.float64
# epoch 2786, loss 5.497089992532312
# torch.float64 torch.float64
# epoch 2787, loss 5.493343620968746
# torch.float64 torch.float64
# epoch 2788, loss 5.489608403196776
# torch.float64 torch.float64
# epoch 2789, loss 5.48588430537597
# torch.float64 torch.float64
# epoch 2790, loss 5.482171293771004
# torch.float64 torch.float64
# epoch 2791, loss 5.4784693347511535
# torch.float64 torch.float64
# epoch 2792, loss 5.474778394790039
# torch.float64 torch.float64
# epoch 2793, loss 5.471098440465367
# torch.float64 torch.float64
# epoch 2794, loss 5.4674294384584154
# torch.float64 torch.float64
# epoch 2795, loss 5.463771355553902
# torch.float64 torch.float64
# epoch 2796, loss 5.460124158639527
# torch.float64 torch.float64
# epoch 2797, loss 5.4564878147056834
# torch.float64 torch.float64
# epoch 2798, loss 5.452862290845132
# torch.float64 torch.float64
# epoch 2799, loss 5.449247554252688
# torch.float64 torch.float64
# epoch 2800, loss 5.445643572224876
# torch.float64 torch.float64
# epoch 2801, loss 5.442050312159653
# torch.float64 torch.float64
# epoch 2802, loss 5.438467741555951
# torch.float64 torch.float64
# epoch 2803, loss 5.4348958280135236
# torch.float64 torch.float64
# epoch 2804, loss 5.43133453923255
# torch.float64 torch.float64
# epoch 2805, loss 5.427783843013282
# torch.float64 torch.float64
# epoch 2806, loss 5.424243707255817
# torch.float64 torch.float64
# epoch 2807, loss 5.420714099959692
# torch.float64 torch.float64
# epoch 2808, loss 5.417194989223582
# torch.float64 torch.float64
# epoch 2809, loss 5.413686343245029
# torch.float64 torch.float64
# epoch 2810, loss 5.410188130320114
# torch.float64 torch.float64
# epoch 2811, loss 5.406700318843128
# torch.float64 torch.float64
# epoch 2812, loss 5.403222877306225
# torch.float64 torch.float64
# epoch 2813, loss 5.39975577429921
# torch.float64 torch.float64
# epoch 2814, loss 5.396298978509123
# torch.float64 torch.float64
# epoch 2815, loss 5.39285245872
# torch.float64 torch.float64
# epoch 2816, loss 5.389416183812531
# torch.float64 torch.float64
# epoch 2817, loss 5.385990122763762
# torch.float64 torch.float64
# epoch 2818, loss 5.382574244646825
# torch.float64 torch.float64
# epoch 2819, loss 5.379168518630507
# torch.float64 torch.float64
# epoch 2820, loss 5.375772913979172
# torch.float64 torch.float64
# epoch 2821, loss 5.372387400052219
# torch.float64 torch.float64
# epoch 2822, loss 5.3690119463038855
# torch.float64 torch.float64
# epoch 2823, loss 5.365646522282999
# torch.float64 torch.float64
# epoch 2824, loss 5.362291097632591
# torch.float64 torch.float64
# epoch 2825, loss 5.358945642089637
# torch.float64 torch.float64
# epoch 2826, loss 5.355610125484752
# torch.float64 torch.float64
# epoch 2827, loss 5.35228451774187
# torch.float64 torch.float64
# epoch 2828, loss 5.348968788878005
# torch.float64 torch.float64
# epoch 2829, loss 5.345662909002901
# torch.float64 torch.float64
# epoch 2830, loss 5.342366848318744
# torch.float64 torch.float64
# epoch 2831, loss 5.3390805771199155
# torch.float64 torch.float64
# epoch 2832, loss 5.335804065792635
# torch.float64 torch.float64
# epoch 2833, loss 5.332537284814714
# torch.float64 torch.float64
# epoch 2834, loss 5.329280204755277
# torch.float64 torch.float64
# epoch 2835, loss 5.326032796274388
# torch.float64 torch.float64
# epoch 2836, loss 5.322795030122854
# torch.float64 torch.float64
# epoch 2837, loss 5.319566877141932
# torch.float64 torch.float64
# epoch 2838, loss 5.316348308262922
# torch.float64 torch.float64
# epoch 2839, loss 5.313139294507115
# torch.float64 torch.float64
# epoch 2840, loss 5.309939806985243
# torch.float64 torch.float64
# epoch 2841, loss 5.30674981689736
# torch.float64 torch.float64
# epoch 2842, loss 5.303569295532524
# torch.float64 torch.float64
# epoch 2843, loss 5.300398214268515
# torch.float64 torch.float64
# epoch 2844, loss 5.297236544571564
# torch.float64 torch.float64
# epoch 2845, loss 5.294084257995975
# torch.float64 torch.float64
# epoch 2846, loss 5.2909413261839955
# torch.float64 torch.float64
# epoch 2847, loss 5.28780772086548
# torch.float64 torch.float64
# epoch 2848, loss 5.284683413857582
# torch.float64 torch.float64
# epoch 2849, loss 5.281568377064458
# torch.float64 torch.float64
# epoch 2850, loss 5.278462582477081
# torch.float64 torch.float64
# epoch 2851, loss 5.2753660021729205
# torch.float64 torch.float64
# epoch 2852, loss 5.272278608315636
# torch.float64 torch.float64
# epoch 2853, loss 5.269200373154831
# torch.float64 torch.float64
# epoch 2854, loss 5.266131269025792
# torch.float64 torch.float64
# epoch 2855, loss 5.263071268349205
# torch.float64 torch.float64
# epoch 2856, loss 5.260020343630893
# torch.float64 torch.float64
# epoch 2857, loss 5.256978467461557
# torch.float64 torch.float64
# epoch 2858, loss 5.253945612516452
# torch.float64 torch.float64
# epoch 2859, loss 5.2509217515551825
# torch.float64 torch.float64
# epoch 2860, loss 5.2479068574214
# torch.float64 torch.float64
# epoch 2861, loss 5.244900903042569
# torch.float64 torch.float64
# epoch 2862, loss 5.241903861429651
# torch.float64 torch.float64
# epoch 2863, loss 5.238915705676897
# torch.float64 torch.float64
# epoch 2864, loss 5.2359364089615585
# torch.float64 torch.float64
# epoch 2865, loss 5.232965944543611
# torch.float64 torch.float64
# epoch 2866, loss 5.230004285765474
# torch.float64 torch.float64
# epoch 2867, loss 5.227051406051885
# torch.float64 torch.float64
# epoch 2868, loss 5.224107278909409
# torch.float64 torch.float64
# epoch 2869, loss 5.221171877926399
# torch.float64 torch.float64
# epoch 2870, loss 5.218245176772587
# torch.float64 torch.float64
# epoch 2871, loss 5.21532714919896
# torch.float64 torch.float64
# epoch 2872, loss 5.2124177690373354
# torch.float64 torch.float64
# epoch 2873, loss 5.20951701020023
# torch.float64 torch.float64
# epoch 2874, loss 5.206624846680665
# torch.float64 torch.float64
# epoch 2875, loss 5.203741252551664
# torch.float64 torch.float64
# epoch 2876, loss 5.200866201966273
# torch.float64 torch.float64
# epoch 2877, loss 5.197999669157136
# torch.float64 torch.float64
# epoch 2878, loss 5.195141628436305
# torch.float64 torch.float64
# epoch 2879, loss 5.192292054194986
# torch.float64 torch.float64
# epoch 2880, loss 5.18945092090331
# torch.float64 torch.float64
# epoch 2881, loss 5.18661820311005
# torch.float64 torch.float64
# epoch 2882, loss 5.183793875442363
# torch.float64 torch.float64
# epoch 2883, loss 5.18097791260554
# torch.float64 torch.float64
# epoch 2884, loss 5.178170289382823
# torch.float64 torch.float64
# epoch 2885, loss 5.175370980635089
# torch.float64 torch.float64
# epoch 2886, loss 5.17257996130069
# torch.float64 torch.float64
# epoch 2887, loss 5.1697972063950814
# torch.float64 torch.float64
# epoch 2888, loss 5.167022691010642
# torch.float64 torch.float64
# epoch 2889, loss 5.1642563903164955
# torch.float64 torch.float64
# epoch 2890, loss 5.161498279558191
# torch.float64 torch.float64
# epoch 2891, loss 5.158748334057452
# torch.float64 torch.float64
# epoch 2892, loss 5.15600652921199
# torch.float64 torch.float64
# epoch 2893, loss 5.1532728404952435
# torch.float64 torch.float64
# epoch 2894, loss 5.150547243456085
# torch.float64 torch.float64
# epoch 2895, loss 5.147829713718715
# torch.float64 torch.float64
# epoch 2896, loss 5.1451202269822645
# torch.float64 torch.float64
# epoch 2897, loss 5.1424187590207
# torch.float64 torch.float64
# epoch 2898, loss 5.139725285682497
# torch.float64 torch.float64
# epoch 2899, loss 5.13703978289041
# torch.float64 torch.float64
# epoch 2900, loss 5.134362226641277
# torch.float64 torch.float64
# epoch 2901, loss 5.131692593005784
# torch.float64 torch.float64
# epoch 2902, loss 5.129030858128196
# torch.float64 torch.float64
# epoch 2903, loss 5.126376998226177
# torch.float64 torch.float64
# epoch 2904, loss 5.123730989590486
# torch.float64 torch.float64
# epoch 2905, loss 5.121092808584827
# torch.float64 torch.float64
# epoch 2906, loss 5.118462431645535
# torch.float64 torch.float64
# epoch 2907, loss 5.115839835281467
# torch.float64 torch.float64
# epoch 2908, loss 5.113224996073596
# torch.float64 torch.float64
# epoch 2909, loss 5.110617890675001
# torch.float64 torch.float64
# epoch 2910, loss 5.108018495810441
# torch.float64 torch.float64
# epoch 2911, loss 5.105426788276242
# torch.float64 torch.float64
# epoch 2912, loss 5.102842744940053
# torch.float64 torch.float64
# epoch 2913, loss 5.100266342740608
# torch.float64 torch.float64
# epoch 2914, loss 5.097697558687497
# torch.float64 torch.float64
# epoch 2915, loss 5.0951363698609615
# torch.float64 torch.float64
# epoch 2916, loss 5.09258275341165
# torch.float64 torch.float64
# epoch 2917, loss 5.090036686560428
# torch.float64 torch.float64
# epoch 2918, loss 5.087498146598101
# torch.float64 torch.float64
# epoch 2919, loss 5.084967110885263
# torch.float64 torch.float64
# epoch 2920, loss 5.082443556852042
# torch.float64 torch.float64
# epoch 2921, loss 5.079927461997906
# torch.float64 torch.float64
# epoch 2922, loss 5.077418803891377
# torch.float64 torch.float64
# epoch 2923, loss 5.074917560169878
# torch.float64 torch.float64
# epoch 2924, loss 5.07242370853951
# torch.float64 torch.float64
# epoch 2925, loss 5.069937226774797
# torch.float64 torch.float64
# epoch 2926, loss 5.067458092718543
# torch.float64 torch.float64
# epoch 2927, loss 5.064986284281512
# torch.float64 torch.float64
# epoch 2928, loss 5.0625217794423305
# torch.float64 torch.float64
# epoch 2929, loss 5.060064556247168
# torch.float64 torch.float64
# epoch 2930, loss 5.0576145928096325
# torch.float64 torch.float64
# epoch 2931, loss 5.055171867310418
# torch.float64 torch.float64
# epoch 2932, loss 5.052736357997247
# torch.float64 torch.float64
# epoch 2933, loss 5.050308043184534
# torch.float64 torch.float64
# epoch 2934, loss 5.047886901253332
# torch.float64 torch.float64
# epoch 2935, loss 5.045472910650881
# torch.float64 torch.float64
# epoch 2936, loss 5.043066049890597
# torch.float64 torch.float64
# epoch 2937, loss 5.040666297551897
# torch.float64 torch.float64
# epoch 2938, loss 5.038273632279747
# torch.float64 torch.float64
# epoch 2939, loss 5.035888032784735
# torch.float64 torch.float64
# epoch 2940, loss 5.033509477842664
# torch.float64 torch.float64
# epoch 2941, loss 5.031137946294452
# torch.float64 torch.float64
# epoch 2942, loss 5.0287734170458815
# torch.float64 torch.float64
# epoch 2943, loss 5.026415869067461
# torch.float64 torch.float64
# epoch 2944, loss 5.02406528139411
# torch.float64 torch.float64
# epoch 2945, loss 5.02172163312508
# torch.float64 torch.float64
# epoch 2946, loss 5.019384903423646
# torch.float64 torch.float64
# epoch 2947, loss 5.017055071516968
# torch.float64 torch.float64
# epoch 2948, loss 5.014732116695884
# torch.float64 torch.float64
# epoch 2949, loss 5.012416018314706
# torch.float64 torch.float64
# epoch 2950, loss 5.010106755790998
# torch.float64 torch.float64
# epoch 2951, loss 5.007804308605385
# torch.float64 torch.float64
# epoch 2952, loss 5.005508656301394
# torch.float64 torch.float64
# epoch 2953, loss 5.003219778485231
# torch.float64 torch.float64
# epoch 2954, loss 5.000937654825524
# torch.float64 torch.float64
# epoch 2955, loss 4.998662265053238
# torch.float64 torch.float64
# epoch 2956, loss 4.996393588961448
# torch.float64 torch.float64
# epoch 2957, loss 4.994131606405036
# torch.float64 torch.float64
# epoch 2958, loss 4.991876297300647
# torch.float64 torch.float64
# epoch 2959, loss 4.989627641626447
# torch.float64 torch.float64
# epoch 2960, loss 4.987385619421853
# torch.float64 torch.float64
# epoch 2961, loss 4.985150210787424
# torch.float64 torch.float64
# epoch 2962, loss 4.982921395884665
# torch.float64 torch.float64
# epoch 2963, loss 4.980699154935814
# torch.float64 torch.float64
# epoch 2964, loss 4.978483468223604
# torch.float64 torch.float64
# epoch 2965, loss 4.976274316091222
# torch.float64 torch.float64
# epoch 2966, loss 4.974071678941959
# torch.float64 torch.float64
# epoch 2967, loss 4.971875537239065
# torch.float64 torch.float64
# epoch 2968, loss 4.969685871505645
# torch.float64 torch.float64
# epoch 2969, loss 4.967502662324326
# torch.float64 torch.float64
# epoch 2970, loss 4.965325890337235
# torch.float64 torch.float64
# epoch 2971, loss 4.963155536245685
# torch.float64 torch.float64
# epoch 2972, loss 4.9609915808100435
# torch.float64 torch.float64
# epoch 2973, loss 4.958834004849507
# torch.float64 torch.float64
# epoch 2974, loss 4.956682789241985
# torch.float64 torch.float64
# epoch 2975, loss 4.95453791492392
# torch.float64 torch.float64
# epoch 2976, loss 4.952399362889921
# torch.float64 torch.float64
# epoch 2977, loss 4.950267114192899
# torch.float64 torch.float64
# epoch 2978, loss 4.9481411499435355
# torch.float64 torch.float64
# epoch 2979, loss 4.946021451310416
# torch.float64 torch.float64
# epoch 2980, loss 4.943907999519655
# torch.float64 torch.float64
# epoch 2981, loss 4.9418007758547375
# torch.float64 torch.float64
# epoch 2982, loss 4.939699761656394
# torch.float64 torch.float64
# epoch 2983, loss 4.937604938322416
# torch.float64 torch.float64
# epoch 2984, loss 4.935516287307415
# torch.float64 torch.float64
# epoch 2985, loss 4.933433790122741
# torch.float64 torch.float64
# epoch 2986, loss 4.931357428336236
# torch.float64 torch.float64
# epoch 2987, loss 4.929287183572013
# torch.float64 torch.float64
# epoch 2988, loss 4.927223037510431
# torch.float64 torch.float64
# epoch 2989, loss 4.925164971887751
# torch.float64 torch.float64
# epoch 2990, loss 4.923112968496093
# torch.float64 torch.float64
# epoch 2991, loss 4.921067009183189
# torch.float64 torch.float64
# epoch 2992, loss 4.919027075852221
# torch.float64 torch.float64
# epoch 2993, loss 4.916993150461629
# torch.float64 torch.float64
# epoch 2994, loss 4.914965215025019
# torch.float64 torch.float64
# epoch 2995, loss 4.912943251610886
# torch.float64 torch.float64
# epoch 2996, loss 4.910927242342493
# torch.float64 torch.float64
# epoch 2997, loss 4.908917169397749
# torch.float64 torch.float64
# epoch 2998, loss 4.906913015008913
# torch.float64 torch.float64
# epoch 2999, loss 4.904914761462544
# Mean squared error: 6.57
# Coefficient of determination: 1.00

# %%
with torch.no_grad(): # we don't need gradients in the testing phase
    if torch.cuda.is_available():
        y_surface = model(Variable(torch.from_numpy(X_surface).cuda())).cpu().data.numpy()
    else:
        y_surface = model(Variable(torch.from_numpy(X_surface))).data.numpy()
    # print(y_pred)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()

# %% [markdown]
# ## Régression Linéaire Multivariée avec Tensorflow
#
# Docs:
# - https://www.tensorflow.org/api_docs
# - https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb

# %%
from distutils.version import LooseVersion
from keras import __version__ as version
import pandas as pd
import tensorflow as tf

# Reshape y
y_train_ = y_train.reshape((y_train.shape[0],1))
y_test_ = y_test.reshape((y_test.shape[0],1))

l_rate=0.01
n_iter=500
batch_size=2

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=1))
optimizer = None
if LooseVersion(version) >= LooseVersion('3'):
    optimizer = tf.keras.optimizers.Adam(learning_rate=l_rate)
else:
    optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=l_rate)
model.compile(
    optimizer=optimizer,
    loss="mean_squared_error",
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )
history = model.fit(x=X_train, y=y_train, batch_size=batch_size, epochs=n_iter)
trained_weight = model.get_weights()[0]
trained_bias = model.get_weights()[1]
epochs = history.epoch
hist = pd.DataFrame(history.history)
rmse = hist["root_mean_squared_error"]

y_pred = model.predict(X_test)

# Display mse and r2 score
print("Mean squared error: %.2f" % mean_squared_error(y_test_, y_pred))
print("Coefficient of determination: %.2f" % r2_score(y_test_, y_pred))
# Out:
# Epoch 1/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step - loss: 12852.5830 - root_mean_squared_error: 113.0899
# Epoch 2/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 491us/step - loss: 11630.2627 - root_mean_squared_error: 107.6233
# Epoch 3/500
#  1/40 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26030.3320 - root_mean_squared_error: 161.3392
# /var/folders/2q/_q3vgn0d217gj990kgxmz3dm0000gn/T/ipykernel_58196/3193410709.py:17: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(version) >= LooseVersion('3'):
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 13133.3799 - root_mean_squared_error: 114.0501
# Epoch 4/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 12473.3467 - root_mean_squared_error: 111.6009
# Epoch 5/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 11303.7783 - root_mean_squared_error: 106.1330
# Epoch 6/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 11484.9385 - root_mean_squared_error: 106.5444
# Epoch 7/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 13687.5342 - root_mean_squared_error: 116.8078
# Epoch 8/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 11047.8203 - root_mean_squared_error: 104.7047
# Epoch 9/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 10417.8447 - root_mean_squared_error: 101.7472
# Epoch 10/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 10896.9238 - root_mean_squared_error: 104.0896
# Epoch 11/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 11114.9160 - root_mean_squared_error: 105.3002
# Epoch 12/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 9770.4473 - root_mean_squared_error: 98.6269
# Epoch 13/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 10894.1895 - root_mean_squared_error: 104.1855
# Epoch 14/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - loss: 9977.6553 - root_mean_squared_error: 99.0540
# Epoch 15/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 10179.9121 - root_mean_squared_error: 100.4367
# Epoch 16/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 11357.1035 - root_mean_squared_error: 106.4679
# Epoch 17/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 8027.3218 - root_mean_squared_error: 88.4882
# Epoch 18/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 13116.1992 - root_mean_squared_error: 114.0890
# Epoch 19/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 363us/step - loss: 8256.7070 - root_mean_squared_error: 90.3443
# Epoch 20/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 10917.7021 - root_mean_squared_error: 103.6427
# Epoch 21/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 9710.9668 - root_mean_squared_error: 98.4003
# Epoch 22/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 10550.2891 - root_mean_squared_error: 101.9881
# Epoch 23/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 11007.7324 - root_mean_squared_error: 104.6319
# Epoch 24/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 9378.6104 - root_mean_squared_error: 96.6929
# Epoch 25/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 8586.6973 - root_mean_squared_error: 92.1089
# Epoch 26/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 9969.1113 - root_mean_squared_error: 99.3180
# Epoch 27/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 368us/step - loss: 10107.0938 - root_mean_squared_error: 100.2412
# Epoch 28/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 10654.2256 - root_mean_squared_error: 102.8230
# Epoch 29/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 8579.3584 - root_mean_squared_error: 92.4305
# Epoch 30/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 11144.5049 - root_mean_squared_error: 105.3763
# Epoch 31/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 479us/step - loss: 9501.2588 - root_mean_squared_error: 97.3350
# Epoch 32/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - loss: 10286.8350 - root_mean_squared_error: 100.7733
# Epoch 33/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - loss: 8698.3193 - root_mean_squared_error: 93.0532
# Epoch 34/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 9569.1641 - root_mean_squared_error: 97.2411
# Epoch 35/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 9095.2090 - root_mean_squared_error: 95.0055
# Epoch 36/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 8147.5327 - root_mean_squared_error: 89.5853
# Epoch 37/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 7588.3008 - root_mean_squared_error: 86.4231
# Epoch 38/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 10624.0039 - root_mean_squared_error: 102.5022
# Epoch 39/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 8680.0234 - root_mean_squared_error: 92.9544
# Epoch 40/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 8997.8730 - root_mean_squared_error: 94.5010
# Epoch 41/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 8187.9995 - root_mean_squared_error: 90.2979
# Epoch 42/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 7814.3657 - root_mean_squared_error: 87.7878
# Epoch 43/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 9322.3418 - root_mean_squared_error: 96.1389
# Epoch 44/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 7890.6265 - root_mean_squared_error: 88.1758
# Epoch 45/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 8033.5249 - root_mean_squared_error: 89.2257
# Epoch 46/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 8012.3916 - root_mean_squared_error: 89.2371
# Epoch 47/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 9652.2178 - root_mean_squared_error: 97.9472
# Epoch 48/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 9127.7988 - root_mean_squared_error: 94.6138
# Epoch 49/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 7582.0986 - root_mean_squared_error: 86.7795
# Epoch 50/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 8035.1597 - root_mean_squared_error: 89.4678
# Epoch 51/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 8992.6123 - root_mean_squared_error: 94.6193
# Epoch 52/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 362us/step - loss: 8550.7725 - root_mean_squared_error: 91.5291
# Epoch 53/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 8629.4150 - root_mean_squared_error: 92.8087
# Epoch 54/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 7540.1118 - root_mean_squared_error: 86.6679
# Epoch 55/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 6931.3975 - root_mean_squared_error: 82.9339
# Epoch 56/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 7274.0571 - root_mean_squared_error: 84.7846
# Epoch 57/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 8676.8584 - root_mean_squared_error: 92.6184
# Epoch 58/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 9184.2705 - root_mean_squared_error: 95.4938
# Epoch 59/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 9395.9785 - root_mean_squared_error: 96.4384
# Epoch 60/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 7525.5415 - root_mean_squared_error: 86.6933
# Epoch 61/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 9669.2568 - root_mean_squared_error: 97.8786
# Epoch 62/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - loss: 6786.3701 - root_mean_squared_error: 82.0003
# Epoch 63/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 7793.1577 - root_mean_squared_error: 88.0124
# Epoch 64/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 7419.8203 - root_mean_squared_error: 85.6401
# Epoch 65/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 6866.9365 - root_mean_squared_error: 82.6066
# Epoch 66/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 7535.1338 - root_mean_squared_error: 86.3404
# Epoch 67/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step - loss: 7578.8784 - root_mean_squared_error: 86.0448
# Epoch 68/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 6168.5820 - root_mean_squared_error: 77.8631
# Epoch 69/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step - loss: 5947.1455 - root_mean_squared_error: 75.3791
# Epoch 70/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 6757.1479 - root_mean_squared_error: 81.7183
# Epoch 71/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 5986.6987 - root_mean_squared_error: 77.0521
# Epoch 72/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step - loss: 8259.0195 - root_mean_squared_error: 90.4098
# Epoch 73/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 7398.4897 - root_mean_squared_error: 85.3618
# Epoch 74/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 6009.0078 - root_mean_squared_error: 76.3786
# Epoch 75/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 8127.1426 - root_mean_squared_error: 89.8682
# Epoch 76/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 6643.4844 - root_mean_squared_error: 81.1176
# Epoch 77/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 6055.1572 - root_mean_squared_error: 77.5375
# Epoch 78/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 6433.3257 - root_mean_squared_error: 80.0333
# Epoch 79/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 4695.3149 - root_mean_squared_error: 67.6612
# Epoch 80/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 367us/step - loss: 5735.1396 - root_mean_squared_error: 75.5343
# Epoch 81/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 7347.4971 - root_mean_squared_error: 85.4212
# Epoch 82/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 6471.9956 - root_mean_squared_error: 80.2902
# Epoch 83/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 6975.0967 - root_mean_squared_error: 83.2449
# Epoch 84/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - loss: 6272.5483 - root_mean_squared_error: 78.7831
# Epoch 85/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 5655.8438 - root_mean_squared_error: 74.9895
# Epoch 86/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 356us/step - loss: 5147.4419 - root_mean_squared_error: 70.3420
# Epoch 87/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 5586.3076 - root_mean_squared_error: 74.1761
# Epoch 88/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 6366.1699 - root_mean_squared_error: 79.4009
# Epoch 89/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step - loss: 5925.1973 - root_mean_squared_error: 76.6500
# Epoch 90/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 380us/step - loss: 5586.8745 - root_mean_squared_error: 74.2741
# Epoch 91/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step - loss: 7549.4258 - root_mean_squared_error: 85.9184
# Epoch 92/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 6022.4263 - root_mean_squared_error: 76.9673
# Epoch 93/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 6732.4302 - root_mean_squared_error: 81.6465
# Epoch 94/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 4388.4673 - root_mean_squared_error: 65.2962
# Epoch 95/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 5646.1606 - root_mean_squared_error: 74.9254
# Epoch 96/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 4576.2026 - root_mean_squared_error: 66.7231
# Epoch 97/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 5963.4517 - root_mean_squared_error: 77.1182
# Epoch 98/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 5184.5190 - root_mean_squared_error: 71.1236
# Epoch 99/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 6353.7949 - root_mean_squared_error: 79.3156
# Epoch 100/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 6344.9512 - root_mean_squared_error: 79.3747
# Epoch 101/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 6245.6011 - root_mean_squared_error: 78.7815
# Epoch 102/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 5941.8130 - root_mean_squared_error: 76.9369
# Epoch 103/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 4519.5962 - root_mean_squared_error: 66.9538
# Epoch 104/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 373us/step - loss: 4637.6304 - root_mean_squared_error: 67.8533
# Epoch 105/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4938.5107 - root_mean_squared_error: 70.0833
# Epoch 106/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 4178.3262 - root_mean_squared_error: 64.0350
# Epoch 107/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 6062.2437 - root_mean_squared_error: 77.5642
# Epoch 108/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 3718.6614 - root_mean_squared_error: 60.1842
# Epoch 109/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 4201.3042 - root_mean_squared_error: 64.5864
# Epoch 110/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 5270.1445 - root_mean_squared_error: 72.4749
# Epoch 111/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 5131.2744 - root_mean_squared_error: 71.5265
# Epoch 112/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 4461.3589 - root_mean_squared_error: 65.8164
# Epoch 113/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 5321.0942 - root_mean_squared_error: 72.7168
# Epoch 114/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 4544.4980 - root_mean_squared_error: 67.0927
# Epoch 115/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 5115.1938 - root_mean_squared_error: 71.4184
# Epoch 116/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 4481.4824 - root_mean_squared_error: 66.7654
# Epoch 117/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 3576.7585 - root_mean_squared_error: 58.9818
# Epoch 118/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 4189.1294 - root_mean_squared_error: 64.5396
# Epoch 119/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 5206.9678 - root_mean_squared_error: 71.6621
# Epoch 120/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 4983.8486 - root_mean_squared_error: 70.2689
# Epoch 121/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 4534.0269 - root_mean_squared_error: 67.2591
# Epoch 122/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 3739.3511 - root_mean_squared_error: 60.9224
# Epoch 123/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 4085.0156 - root_mean_squared_error: 63.7863
# Epoch 124/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 4500.5415 - root_mean_squared_error: 66.9567
# Epoch 125/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 3688.0334 - root_mean_squared_error: 60.0232
# Epoch 126/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 3954.1511 - root_mean_squared_error: 62.6907
# Epoch 127/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step - loss: 4492.5708 - root_mean_squared_error: 66.9068
# Epoch 128/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 3640.7319 - root_mean_squared_error: 60.0568
# Epoch 129/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 4121.7114 - root_mean_squared_error: 63.9790
# Epoch 130/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - loss: 4820.8940 - root_mean_squared_error: 69.1190
# Epoch 131/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 381us/step - loss: 3377.9734 - root_mean_squared_error: 57.8456
# Epoch 132/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 4756.7080 - root_mean_squared_error: 68.8355
# Epoch 133/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - loss: 5414.1274 - root_mean_squared_error: 72.8251
# Epoch 134/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 383us/step - loss: 4895.3340 - root_mean_squared_error: 69.5186
# Epoch 135/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 4287.7549 - root_mean_squared_error: 65.3568
# Epoch 136/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 3229.5286 - root_mean_squared_error: 56.5985
# Epoch 137/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 3778.6738 - root_mean_squared_error: 61.3965
# Epoch 138/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 3481.8064 - root_mean_squared_error: 58.8612
# Epoch 139/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 3743.0044 - root_mean_squared_error: 61.0552
# Epoch 140/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 3630.3391 - root_mean_squared_error: 59.9753
# Epoch 141/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 3281.1836 - root_mean_squared_error: 57.0495
# Epoch 142/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 2752.1541 - root_mean_squared_error: 52.2121
# Epoch 143/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 3141.9055 - root_mean_squared_error: 55.6166
# Epoch 144/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 2897.4192 - root_mean_squared_error: 53.3551
# Epoch 145/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 2933.7092 - root_mean_squared_error: 53.7371
# Epoch 146/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 3582.3894 - root_mean_squared_error: 59.8001
# Epoch 147/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 3447.9055 - root_mean_squared_error: 58.6530
# Epoch 148/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 3503.9395 - root_mean_squared_error: 59.1057
# Epoch 149/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 3073.2524 - root_mean_squared_error: 55.2639
# Epoch 150/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 3787.2759 - root_mean_squared_error: 61.3924
# Epoch 151/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - loss: 3434.7830 - root_mean_squared_error: 58.4188
# Epoch 152/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 4004.6221 - root_mean_squared_error: 62.9990
# Epoch 153/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 3165.5825 - root_mean_squared_error: 56.1348
# Epoch 154/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 3141.8652 - root_mean_squared_error: 55.7726
# Epoch 155/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 3311.3230 - root_mean_squared_error: 57.4600
# Epoch 156/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 3795.8130 - root_mean_squared_error: 61.4882
# Epoch 157/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 2584.2830 - root_mean_squared_error: 50.4880
# Epoch 158/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 3107.9570 - root_mean_squared_error: 55.1855
# Epoch 159/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 3278.0046 - root_mean_squared_error: 57.1810
# Epoch 160/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 2323.3542 - root_mean_squared_error: 47.4777
# Epoch 161/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 3477.6921 - root_mean_squared_error: 58.8440
# Epoch 162/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - loss: 3021.3535 - root_mean_squared_error: 54.8998
# Epoch 163/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 2681.8711 - root_mean_squared_error: 51.5613
# Epoch 164/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 2973.3672 - root_mean_squared_error: 54.4151
# Epoch 165/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 2130.1172 - root_mean_squared_error: 45.9849
# Epoch 166/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 3302.3694 - root_mean_squared_error: 57.3158
# Epoch 167/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 2175.6646 - root_mean_squared_error: 46.4370
# Epoch 168/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 2917.4026 - root_mean_squared_error: 53.9365
# Epoch 169/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 2529.3047 - root_mean_squared_error: 49.9021
# Epoch 170/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 2938.8699 - root_mean_squared_error: 54.1523
# Epoch 171/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 2964.7976 - root_mean_squared_error: 53.9953
# Epoch 172/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 3235.6345 - root_mean_squared_error: 56.6254
# Epoch 173/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 2328.5361 - root_mean_squared_error: 47.6288
# Epoch 174/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 2524.9690 - root_mean_squared_error: 49.7059
# Epoch 175/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 2206.1011 - root_mean_squared_error: 46.8582
# Epoch 176/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 2542.4126 - root_mean_squared_error: 50.3210
# Epoch 177/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 1918.3391 - root_mean_squared_error: 43.0813
# Epoch 178/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 2895.0120 - root_mean_squared_error: 53.6530
# Epoch 179/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 2431.1758 - root_mean_squared_error: 49.1920
# Epoch 180/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 2323.5730 - root_mean_squared_error: 48.1076
# Epoch 181/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 1925.8370 - root_mean_squared_error: 43.1777
# Epoch 182/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 2338.9067 - root_mean_squared_error: 48.1876
# Epoch 183/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 1834.1171 - root_mean_squared_error: 42.6266
# Epoch 184/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 2374.5510 - root_mean_squared_error: 48.3261
# Epoch 185/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 2063.2571 - root_mean_squared_error: 44.9738
# Epoch 186/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 1988.2966 - root_mean_squared_error: 44.4638
# Epoch 187/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 2659.0869 - root_mean_squared_error: 51.1863
# Epoch 188/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 2357.6523 - root_mean_squared_error: 48.3102
# Epoch 189/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 2126.8977 - root_mean_squared_error: 45.9565
# Epoch 190/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 1879.7296 - root_mean_squared_error: 42.9765
# Epoch 191/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 2269.4097 - root_mean_squared_error: 47.0474
# Epoch 192/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 1757.2452 - root_mean_squared_error: 41.6990
# Epoch 193/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 2238.1738 - root_mean_squared_error: 47.2000
# Epoch 194/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 1878.5446 - root_mean_squared_error: 43.2946
# Epoch 195/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 1867.7465 - root_mean_squared_error: 43.1701
# Epoch 196/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 1847.7458 - root_mean_squared_error: 42.8443
# Epoch 197/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 1701.6937 - root_mean_squared_error: 40.9835
# Epoch 198/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 1690.7291 - root_mean_squared_error: 40.7347
# Epoch 199/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 1988.3436 - root_mean_squared_error: 44.5564
# Epoch 200/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 1372.7166 - root_mean_squared_error: 36.6691
# Epoch 201/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 1789.9036 - root_mean_squared_error: 42.2421
# Epoch 202/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 1562.3466 - root_mean_squared_error: 39.4357
# Epoch 203/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 2063.8335 - root_mean_squared_error: 45.2484
# Epoch 204/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 2122.5881 - root_mean_squared_error: 45.8784
# Epoch 205/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 1587.0271 - root_mean_squared_error: 39.7541
# Epoch 206/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 1753.4041 - root_mean_squared_error: 41.7875
# Epoch 207/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 1682.5359 - root_mean_squared_error: 40.8829
# Epoch 208/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 1614.8931 - root_mean_squared_error: 40.1423
# Epoch 209/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 1611.5858 - root_mean_squared_error: 39.9633
# Epoch 210/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 1562.0425 - root_mean_squared_error: 39.4381
# Epoch 211/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 1580.7588 - root_mean_squared_error: 39.6062
# Epoch 212/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 1342.6508 - root_mean_squared_error: 36.5433
# Epoch 213/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 1278.9629 - root_mean_squared_error: 35.6449
# Epoch 214/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 1438.4240 - root_mean_squared_error: 37.7086
# Epoch 215/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 1392.3425 - root_mean_squared_error: 37.2181
# Epoch 216/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 1345.6808 - root_mean_squared_error: 36.5004
# Epoch 217/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 1111.0265 - root_mean_squared_error: 33.0094
# Epoch 218/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 1447.8962 - root_mean_squared_error: 37.8927
# Epoch 219/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 1471.0879 - root_mean_squared_error: 38.3177
# Epoch 220/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 1381.3741 - root_mean_squared_error: 37.0711
# Epoch 221/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 1299.0360 - root_mean_squared_error: 35.9438
# Epoch 222/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 1471.8021 - root_mean_squared_error: 38.2058
# Epoch 223/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 1161.9429 - root_mean_squared_error: 33.9798
# Epoch 224/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 1110.8408 - root_mean_squared_error: 33.2678
# Epoch 225/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 1130.6167 - root_mean_squared_error: 33.3551
# Epoch 226/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 1230.8440 - root_mean_squared_error: 34.8960
# Epoch 227/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 992.6223 - root_mean_squared_error: 31.1730
# Epoch 228/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 1166.8854 - root_mean_squared_error: 34.0977
# Epoch 229/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 1088.5682 - root_mean_squared_error: 32.6573
# Epoch 230/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 1016.2990 - root_mean_squared_error: 31.6959
# Epoch 231/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 1005.2466 - root_mean_squared_error: 31.4685
# Epoch 232/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 1212.1406 - root_mean_squared_error: 34.7002
# Epoch 233/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 997.1356 - root_mean_squared_error: 31.3360
# Epoch 234/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 837.4096 - root_mean_squared_error: 28.5511
# Epoch 235/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 427us/step - loss: 894.5187 - root_mean_squared_error: 29.6023
# Epoch 236/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 891.8076 - root_mean_squared_error: 29.4057
# Epoch 237/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 1032.7683 - root_mean_squared_error: 32.0648
# Epoch 238/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 951.2864 - root_mean_squared_error: 30.5669
# Epoch 239/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - loss: 950.8046 - root_mean_squared_error: 30.7201
# Epoch 240/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 895.2218 - root_mean_squared_error: 29.8069
# Epoch 241/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 804.3799 - root_mean_squared_error: 28.0525
# Epoch 242/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 854.3262 - root_mean_squared_error: 28.8308
# Epoch 243/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 797.3659 - root_mean_squared_error: 27.9915
# Epoch 244/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 1188.5790 - root_mean_squared_error: 34.2228
# Epoch 245/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 795.3035 - root_mean_squared_error: 28.1416
# Epoch 246/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 909.7708 - root_mean_squared_error: 30.0879
# Epoch 247/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 778.9242 - root_mean_squared_error: 27.8457
# Epoch 248/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 805.2839 - root_mean_squared_error: 28.3529
# Epoch 249/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 598.9585 - root_mean_squared_error: 24.1643
# Epoch 250/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 747.5461 - root_mean_squared_error: 27.3212
# Epoch 251/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 655.6862 - root_mean_squared_error: 25.4589
# Epoch 252/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 756.0350 - root_mean_squared_error: 27.4196
# Epoch 253/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 749.6033 - root_mean_squared_error: 27.3452
# Epoch 254/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 587.2853 - root_mean_squared_error: 23.9969
# Epoch 255/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 708.4084 - root_mean_squared_error: 26.4905
# Epoch 256/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 771.3298 - root_mean_squared_error: 27.3243
# Epoch 257/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 528.5579 - root_mean_squared_error: 22.7327
# Epoch 258/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 649.4028 - root_mean_squared_error: 25.3313
# Epoch 259/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 535.6562 - root_mean_squared_error: 22.9163
# Epoch 260/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 564.7385 - root_mean_squared_error: 23.4905
# Epoch 261/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 583.6720 - root_mean_squared_error: 24.0406
# Epoch 262/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 675.7011 - root_mean_squared_error: 25.8476
# Epoch 263/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 577.4030 - root_mean_squared_error: 23.8993
# Epoch 264/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 584.4562 - root_mean_squared_error: 24.1178
# Epoch 265/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 572.2233 - root_mean_squared_error: 23.7784
# Epoch 266/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 536.6669 - root_mean_squared_error: 22.9814
# Epoch 267/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 466.5520 - root_mean_squared_error: 21.5362
# Epoch 268/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 520.8687 - root_mean_squared_error: 22.7268
# Epoch 269/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 525.7400 - root_mean_squared_error: 22.8898
# Epoch 270/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 421.8716 - root_mean_squared_error: 20.2762
# Epoch 271/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 419.3660 - root_mean_squared_error: 20.3045
# Epoch 272/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 443.1672 - root_mean_squared_error: 21.0312
# Epoch 273/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 453.6161 - root_mean_squared_error: 21.0704
# Epoch 274/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 398.3012 - root_mean_squared_error: 19.8154
# Epoch 275/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 445.5826 - root_mean_squared_error: 21.0254
# Epoch 276/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 416.6451 - root_mean_squared_error: 20.2209
# Epoch 277/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 417.1422 - root_mean_squared_error: 20.3661
# Epoch 278/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 359.5661 - root_mean_squared_error: 18.8732
# Epoch 279/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 374.4929 - root_mean_squared_error: 19.3064
# Epoch 280/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 416.1663 - root_mean_squared_error: 20.3483
# Epoch 281/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 331.0755 - root_mean_squared_error: 17.9561
# Epoch 282/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 311.3289 - root_mean_squared_error: 17.2442
# Epoch 283/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 293.4863 - root_mean_squared_error: 16.9636
# Epoch 284/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 367.7090 - root_mean_squared_error: 19.1531
# Epoch 285/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 390.8188 - root_mean_squared_error: 19.6729
# Epoch 286/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 284.8916 - root_mean_squared_error: 16.8351
# Epoch 287/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 285.4632 - root_mean_squared_error: 16.7403
# Epoch 288/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 254.9458 - root_mean_squared_error: 15.7709
# Epoch 289/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 260.9934 - root_mean_squared_error: 16.1047
# Epoch 290/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 376.2587 - root_mean_squared_error: 19.2584
# Epoch 291/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 255.3383 - root_mean_squared_error: 15.9195
# Epoch 292/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 304.7259 - root_mean_squared_error: 17.3436
# Epoch 293/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 191.8564 - root_mean_squared_error: 13.5557
# Epoch 294/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 259.3451 - root_mean_squared_error: 15.9219
# Epoch 295/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 236.6741 - root_mean_squared_error: 15.3323
# Epoch 296/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 241.1115 - root_mean_squared_error: 15.4712
# Epoch 297/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 214.0646 - root_mean_squared_error: 14.5545
# Epoch 298/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 214.7649 - root_mean_squared_error: 14.5501
# Epoch 299/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 222.2762 - root_mean_squared_error: 14.8955
# Epoch 300/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 172.2913 - root_mean_squared_error: 13.0693
# Epoch 301/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 174.5828 - root_mean_squared_error: 13.1046
# Epoch 302/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 188.9869 - root_mean_squared_error: 13.7109
# Epoch 303/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 205.3365 - root_mean_squared_error: 14.3218
# Epoch 304/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 211.3849 - root_mean_squared_error: 14.5014
# Epoch 305/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 172.7497 - root_mean_squared_error: 13.0997
# Epoch 306/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 209.4283 - root_mean_squared_error: 14.3913
# Epoch 307/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 191.2287 - root_mean_squared_error: 13.7592
# Epoch 308/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 177.3156 - root_mean_squared_error: 13.2728
# Epoch 309/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 160.5221 - root_mean_squared_error: 12.5812
# Epoch 310/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 146.0873 - root_mean_squared_error: 12.0112
# Epoch 311/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 131.9963 - root_mean_squared_error: 11.3252
# Epoch 312/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 160.3747 - root_mean_squared_error: 12.6352
# Epoch 313/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 153.9796 - root_mean_squared_error: 12.3890
# Epoch 314/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 130.4062 - root_mean_squared_error: 11.3056
# Epoch 315/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 140.2473 - root_mean_squared_error: 11.7995
# Epoch 316/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 118.8157 - root_mean_squared_error: 10.8594
# Epoch 317/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 133.2091 - root_mean_squared_error: 11.5137
# Epoch 318/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 99.2861 - root_mean_squared_error: 9.8393
# Epoch 319/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 112.4503 - root_mean_squared_error: 10.5832
# Epoch 320/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 107.1920 - root_mean_squared_error: 10.3376
# Epoch 321/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 126.4381 - root_mean_squared_error: 11.2077
# Epoch 322/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 109.5905 - root_mean_squared_error: 10.4248
# Epoch 323/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 91.2022 - root_mean_squared_error: 9.5163
# Epoch 324/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 94.7482 - root_mean_squared_error: 9.6654
# Epoch 325/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 94.3092 - root_mean_squared_error: 9.6458
# Epoch 326/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 88.1437 - root_mean_squared_error: 9.3723
# Epoch 327/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 96.3465 - root_mean_squared_error: 9.7685
# Epoch 328/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 77.5680 - root_mean_squared_error: 8.7301
# Epoch 329/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 53.7575 - root_mean_squared_error: 7.0574
# Epoch 330/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 75.2764 - root_mean_squared_error: 8.6474
# Epoch 331/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 78.0591 - root_mean_squared_error: 8.7588
# Epoch 332/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 65.7782 - root_mean_squared_error: 8.0674
# Epoch 333/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 53.9370 - root_mean_squared_error: 7.3054
# Epoch 334/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 72.1109 - root_mean_squared_error: 8.4607
# Epoch 335/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 47.9804 - root_mean_squared_error: 6.8254
# Epoch 336/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 47.0733 - root_mean_squared_error: 6.7147
# Epoch 337/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 75.7210 - root_mean_squared_error: 8.5978
# Epoch 338/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 41.7901 - root_mean_squared_error: 6.4178
# Epoch 339/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 43.0523 - root_mean_squared_error: 6.5444
# Epoch 340/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 51.7269 - root_mean_squared_error: 7.1747
# Epoch 341/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 48.9481 - root_mean_squared_error: 6.9776
# Epoch 342/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 417us/step - loss: 43.4001 - root_mean_squared_error: 6.5748
# Epoch 343/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 35.7649 - root_mean_squared_error: 5.8937
# Epoch 344/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 33.0268 - root_mean_squared_error: 5.7283
# Epoch 345/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 32.2893 - root_mean_squared_error: 5.6579
# Epoch 346/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 32.0471 - root_mean_squared_error: 5.6479
# Epoch 347/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 31.1865 - root_mean_squared_error: 5.5667
# Epoch 348/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step - loss: 33.7782 - root_mean_squared_error: 5.7995
# Epoch 349/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 31.8784 - root_mean_squared_error: 5.6351
# Epoch 350/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 28.0751 - root_mean_squared_error: 5.2795
# Epoch 351/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 22.0345 - root_mean_squared_error: 4.6442
# Epoch 352/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 20.7867 - root_mean_squared_error: 4.4980
# Epoch 353/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 28.9307 - root_mean_squared_error: 5.3089
# Epoch 354/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 25.3055 - root_mean_squared_error: 4.9917
# Epoch 355/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 23.5706 - root_mean_squared_error: 4.8320
# Epoch 356/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 21.0522 - root_mean_squared_error: 4.5745
# Epoch 357/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 17.5616 - root_mean_squared_error: 4.0935
# Epoch 358/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 408us/step - loss: 15.2942 - root_mean_squared_error: 3.8372
# Epoch 359/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 17.9356 - root_mean_squared_error: 4.1997
# Epoch 360/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 18.7613 - root_mean_squared_error: 4.3134
# Epoch 361/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 17.4682 - root_mean_squared_error: 4.1045
# Epoch 362/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 501us/step - loss: 17.4140 - root_mean_squared_error: 4.1634
# Epoch 363/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 15.3804 - root_mean_squared_error: 3.8913
# Epoch 364/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 13.1111 - root_mean_squared_error: 3.5992
# Epoch 365/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 10.4353 - root_mean_squared_error: 3.1693
# Epoch 366/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 13.2574 - root_mean_squared_error: 3.6339
# Epoch 367/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 12.7705 - root_mean_squared_error: 3.5523
# Epoch 368/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - loss: 9.6338 - root_mean_squared_error: 3.0727
# Epoch 369/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 10.1062 - root_mean_squared_error: 3.1696
# Epoch 370/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 9.6341 - root_mean_squared_error: 3.0474
# Epoch 371/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 10.6205 - root_mean_squared_error: 3.2197
# Epoch 372/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 10.5478 - root_mean_squared_error: 3.2310
# Epoch 373/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 8.3126 - root_mean_squared_error: 2.8590
# Epoch 374/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 9.2501 - root_mean_squared_error: 3.0252
# Epoch 375/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 9.8314 - root_mean_squared_error: 3.1055
# Epoch 376/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 8.4841 - root_mean_squared_error: 2.9055
# Epoch 377/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 7.8497 - root_mean_squared_error: 2.7853
# Epoch 378/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 413us/step - loss: 7.1755 - root_mean_squared_error: 2.6760
# Epoch 379/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 6.4601 - root_mean_squared_error: 2.5338
# Epoch 380/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 5.5882 - root_mean_squared_error: 2.3499
# Epoch 381/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 6.8513 - root_mean_squared_error: 2.5821
# Epoch 382/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 419us/step - loss: 7.2576 - root_mean_squared_error: 2.6899
# Epoch 383/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 7.6389 - root_mean_squared_error: 2.7395
# Epoch 384/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 5.7886 - root_mean_squared_error: 2.3618
# Epoch 385/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 7.0567 - root_mean_squared_error: 2.6322
# Epoch 386/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 5.3281 - root_mean_squared_error: 2.3036
# Epoch 387/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 5.4729 - root_mean_squared_error: 2.3176
# Epoch 388/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 5.5947 - root_mean_squared_error: 2.3565
# Epoch 389/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 5.1581 - root_mean_squared_error: 2.2343
# Epoch 390/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 5.8024 - root_mean_squared_error: 2.3822
# Epoch 391/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 5.2764 - root_mean_squared_error: 2.2940
# Epoch 392/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 4.8615 - root_mean_squared_error: 2.1987
# Epoch 393/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 5.5061 - root_mean_squared_error: 2.3230
# Epoch 394/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 5.2703 - root_mean_squared_error: 2.2759
# Epoch 395/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 4.3638 - root_mean_squared_error: 2.0554
# Epoch 396/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 4.9811 - root_mean_squared_error: 2.2212
# Epoch 397/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 5.7652 - root_mean_squared_error: 2.3947
# Epoch 398/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 6.1640 - root_mean_squared_error: 2.4683
# Epoch 399/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 3.4603 - root_mean_squared_error: 1.8470
# Epoch 400/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 3.8205 - root_mean_squared_error: 1.9390
# Epoch 401/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 5.3087 - root_mean_squared_error: 2.2924
# Epoch 402/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 4.7101 - root_mean_squared_error: 2.1446
# Epoch 403/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 3.7623 - root_mean_squared_error: 1.9361
# Epoch 404/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 4.4265 - root_mean_squared_error: 2.0905
# Epoch 405/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - loss: 6.2378 - root_mean_squared_error: 2.4599
# Epoch 406/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 397us/step - loss: 4.6240 - root_mean_squared_error: 2.1475
# Epoch 407/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 5.7005 - root_mean_squared_error: 2.3755
# Epoch 408/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 3.8217 - root_mean_squared_error: 1.9487
# Epoch 409/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 4.3126 - root_mean_squared_error: 2.0473
# Epoch 410/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - loss: 4.5277 - root_mean_squared_error: 2.1215
# Epoch 411/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 3.9927 - root_mean_squared_error: 1.9648
# Epoch 412/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step - loss: 4.4603 - root_mean_squared_error: 2.1001
# Epoch 413/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 395us/step - loss: 4.3958 - root_mean_squared_error: 2.0860
# Epoch 414/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 3.0932 - root_mean_squared_error: 1.7300
# Epoch 415/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 4.6461 - root_mean_squared_error: 2.1414
# Epoch 416/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 426us/step - loss: 4.0054 - root_mean_squared_error: 1.9750
# Epoch 417/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 414us/step - loss: 4.5223 - root_mean_squared_error: 2.1017
# Epoch 418/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 437us/step - loss: 3.5358 - root_mean_squared_error: 1.8664
# Epoch 419/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 3.6090 - root_mean_squared_error: 1.8813
# Epoch 420/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 3.6076 - root_mean_squared_error: 1.8794
# Epoch 421/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 3.8333 - root_mean_squared_error: 1.9529
# Epoch 422/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 4.0161 - root_mean_squared_error: 1.9938
# Epoch 423/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 4.7069 - root_mean_squared_error: 2.1585
# Epoch 424/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - loss: 4.1536 - root_mean_squared_error: 2.0283
# Epoch 425/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 5.0871 - root_mean_squared_error: 2.2326
# Epoch 426/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - loss: 3.5733 - root_mean_squared_error: 1.8805
# Epoch 427/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 3.1468 - root_mean_squared_error: 1.7666
# Epoch 428/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 3.9821 - root_mean_squared_error: 1.9757
# Epoch 429/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 3.5407 - root_mean_squared_error: 1.8726
# Epoch 430/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 3.7106 - root_mean_squared_error: 1.9184
# Epoch 431/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 4.2391 - root_mean_squared_error: 2.0543
# Epoch 432/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 4.2914 - root_mean_squared_error: 2.0639
# Epoch 433/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 3.8913 - root_mean_squared_error: 1.9619
# Epoch 434/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 3.7056 - root_mean_squared_error: 1.9218
# Epoch 435/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 4.1002 - root_mean_squared_error: 2.0185
# Epoch 436/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 4.1848 - root_mean_squared_error: 2.0429
# Epoch 437/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - loss: 5.1000 - root_mean_squared_error: 2.2465
# Epoch 438/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 3.7621 - root_mean_squared_error: 1.9338
# Epoch 439/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 3.9958 - root_mean_squared_error: 1.9873
# Epoch 440/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 386us/step - loss: 4.6925 - root_mean_squared_error: 2.1477
# Epoch 441/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 424us/step - loss: 4.5057 - root_mean_squared_error: 2.1063
# Epoch 442/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 3.6503 - root_mean_squared_error: 1.8988
# Epoch 443/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 4.7225 - root_mean_squared_error: 2.1684
# Epoch 444/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 4.4331 - root_mean_squared_error: 2.0814
# Epoch 445/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 2.8132 - root_mean_squared_error: 1.6381
# Epoch 446/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step - loss: 3.4144 - root_mean_squared_error: 1.8390
# Epoch 447/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 5.8686 - root_mean_squared_error: 2.3896
# Epoch 448/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 4.4782 - root_mean_squared_error: 2.1065
# Epoch 449/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 434us/step - loss: 4.0084 - root_mean_squared_error: 1.9917
# Epoch 450/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step - loss: 4.4787 - root_mean_squared_error: 2.1092
# Epoch 451/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 4.5831 - root_mean_squared_error: 2.1283
# Epoch 452/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 5.0949 - root_mean_squared_error: 2.2337
# Epoch 453/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 4.4951 - root_mean_squared_error: 2.0900
# Epoch 454/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 2.7164 - root_mean_squared_error: 1.6370
# Epoch 455/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - loss: 3.7976 - root_mean_squared_error: 1.9458
# Epoch 456/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 5.2015 - root_mean_squared_error: 2.2686
# Epoch 457/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 421us/step - loss: 4.5278 - root_mean_squared_error: 2.1039
# Epoch 458/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step - loss: 3.6844 - root_mean_squared_error: 1.9149
# Epoch 459/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 4.0769 - root_mean_squared_error: 2.0117
# Epoch 460/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 404us/step - loss: 4.5914 - root_mean_squared_error: 2.1379
# Epoch 461/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 4.3562 - root_mean_squared_error: 2.0733
# Epoch 462/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step - loss: 6.2877 - root_mean_squared_error: 2.4426
# Epoch 463/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 3.5042 - root_mean_squared_error: 1.8421
# Epoch 464/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 4.7395 - root_mean_squared_error: 2.1713
# Epoch 465/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - loss: 3.9057 - root_mean_squared_error: 1.9580
# Epoch 466/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 3.8377 - root_mean_squared_error: 1.9463
# Epoch 467/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 5.5824 - root_mean_squared_error: 2.3482
# Epoch 468/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 5.0198 - root_mean_squared_error: 2.2337
# Epoch 469/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 422us/step - loss: 4.6988 - root_mean_squared_error: 2.1576
# Epoch 470/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 382us/step - loss: 5.1240 - root_mean_squared_error: 2.2384
# Epoch 471/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 3.9780 - root_mean_squared_error: 1.9860
# Epoch 472/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 3.9685 - root_mean_squared_error: 1.9695
# Epoch 473/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 4.4040 - root_mean_squared_error: 2.0922
# Epoch 474/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - loss: 4.9300 - root_mean_squared_error: 2.2127
# Epoch 475/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 409us/step - loss: 4.1111 - root_mean_squared_error: 2.0238
# Epoch 476/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 4.0078 - root_mean_squared_error: 1.9940
# Epoch 477/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 3.8025 - root_mean_squared_error: 1.9338
# Epoch 478/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 4.0096 - root_mean_squared_error: 1.9925
# Epoch 479/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - loss: 3.9442 - root_mean_squared_error: 1.9784
# Epoch 480/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 3.7134 - root_mean_squared_error: 1.9154
# Epoch 481/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - loss: 4.4843 - root_mean_squared_error: 2.1043
# Epoch 482/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 3.5508 - root_mean_squared_error: 1.8732
# Epoch 483/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 4.2257 - root_mean_squared_error: 2.0522
# Epoch 484/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - loss: 3.7294 - root_mean_squared_error: 1.9171
# Epoch 485/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 390us/step - loss: 3.4724 - root_mean_squared_error: 1.8550
# Epoch 486/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 3.5261 - root_mean_squared_error: 1.8223
# Epoch 487/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 398us/step - loss: 3.9354 - root_mean_squared_error: 1.9643
# Epoch 488/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 393us/step - loss: 5.0624 - root_mean_squared_error: 2.2428
# Epoch 489/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 4.2575 - root_mean_squared_error: 2.0589
# Epoch 490/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 4.0147 - root_mean_squared_error: 1.9994
# Epoch 491/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 4.9745 - root_mean_squared_error: 2.2176
# Epoch 492/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step - loss: 4.7036 - root_mean_squared_error: 2.1538
# Epoch 493/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 401us/step - loss: 4.4192 - root_mean_squared_error: 2.0955
# Epoch 494/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - loss: 3.7600 - root_mean_squared_error: 1.9123
# Epoch 495/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 407us/step - loss: 3.7538 - root_mean_squared_error: 1.9281
# Epoch 496/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step - loss: 4.2223 - root_mean_squared_error: 2.0479
# Epoch 497/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 412us/step - loss: 4.8296 - root_mean_squared_error: 2.1873
# Epoch 498/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - loss: 4.3666 - root_mean_squared_error: 2.0782
# Epoch 499/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 391us/step - loss: 4.0368 - root_mean_squared_error: 1.9798
# Epoch 500/500
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 384us/step - loss: 4.6269 - root_mean_squared_error: 2.1487
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Mean squared error: 6.19
# Coefficient of determination: 1.00

# %%
y_surface = model.predict(X_surface)
y_surface = y_surface.reshape(x1_values.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_train[:,0], X_train[:,1], y_train, marker='o', c='r', label='Training Data')
ax.plot_surface(x1_values, x2_values, y_surface, alpha=0.5, color='b', label='Linear Regression Plane')
ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("y")
# ax.legend() # Genère une erreur dans Google Colab
plt.show()
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step
